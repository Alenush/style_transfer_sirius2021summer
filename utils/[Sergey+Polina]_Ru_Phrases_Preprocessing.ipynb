# %% [markdown]
# # Download data

# %%
#!g1.1
main_characters = ['ДЖОУИ', 'МОНИКА', 'РЕЙЧЕЛ', 'РОСС', 'ФИБИ', 'ЧЕНДЛЕР']
labels_to_chars = dict(enumerate(main_characters))
chars_to_labels = {v: k for k, v in labels_to_chars.items()}
labels_to_chars, chars_to_labels
# Out:
# ({0: 'ДЖОУИ', 1: 'МОНИКА', 2: 'РЕЙЧЕЛ', 3: 'РОСС', 4: 'ФИБИ', 5: 'ЧЕНДЛЕР'},
#  {'ДЖОУИ': 0, 'МОНИКА': 1, 'РЕЙЧЕЛ': 2, 'РОСС': 3, 'ФИБИ': 4, 'ЧЕНДЛЕР': 5})

# %%
#!g1.1
import torch

# If there's a GPU available...
if torch.cuda.is_available():    

    # Tell PyTorch to use the GPU.    
    device = torch.device("cuda")

    print('There are %d GPU(s) available.' % torch.cuda.device_count())

    print('We will use the GPU:', torch.cuda.get_device_name(0))

# If not...
else:
    print('No GPU available, using the CPU instead.')
    device = torch.device("cpu")
# Out:
# No GPU available, using the CPU instead.

# %%
#!g1.1
# !git clone https://github.com/Alenush/style_transfer_sirius2021summer.git
# Out:
# Cloning into 'style_transfer_sirius2021summer'...
# remote: Enumerating objects: 1801, done.
# remote: Counting objects: 100% (1801/1801), done.
# remote: Compressing objects: 100% (1135/1135), done.
# remote: Total 1801 (delta 814), reused 1619 (delta 639), pack-reused 0
# Receiving objects: 100% (1801/1801), 52.64 MiB | 12.22 MiB/s, done.
# Resolving deltas: 100% (814/814), done.
# Checking out files: 100% (657/657), done.

# %%
# %%bash
# cd style_transfer_sirius2021summer
# git checkout master
# git pull
# cd -
# Out:
# Branch 'master' set up to track remote branch 'master' from 'origin'.
# Already up to date.
# /content
# Switched to a new branch 'master'

# %%
# !pip install rusenttokenize
# Out:
# Collecting rusenttokenize
#   Downloading rusenttokenize-0.0.5-py3-none-any.whl (10 kB)
# Installing collected packages: rusenttokenize
# Successfully installed rusenttokenize-0.0.5

# %%
from rusenttokenize import ru_sent_tokenize

RUSSIAN_SCRIPTS_PATH = 'style_transfer_sirius2021summer/data/scripts/russian'
RUSSIAN_NAMES = [
    'ДЖОУИ',
    'РЕЙЧЕЛ',
    'ФИБИ',
    'МОНИКА',
    'РОСС',
    'ЧЕНДЛЕР'
]
SENTS_BY_NAME = { name : [] for name in RUSSIAN_NAMES }

for name in RUSSIAN_NAMES:
    with open(f'{RUSSIAN_SCRIPTS_PATH}/{name}.txt', 'r') as f:
        lines = f.readlines()[0]

    SENTS_BY_NAME[name] = ru_sent_tokenize(lines)

SENTS_BY_NAME
# Out:
# {'ДЖОУИ': ['Да ладно, ты встречаешься с этим парнем!',
#   'С ним должно быть что-то не так!',
#   'Вместо?',
#   'Никогда не видел этого сна.',
#   'Этот парень здоровается, я хочу убить себя.',
#   'А ты никогда не знал, что она лесбиянка.',
#   'Хорошо, Росс, смотри.',
#   'Вы сейчас чувствуете сильную боль.',
#   'Ты сердишься.',
#   'Тебе больно.',
#   'Могу я сказать вам ответ?',
#   'Ленточный стык!',
#   'Да ладно, ты один!',
#   'Есть гормоны!',
#   'Я говорю: столкните ее с лестницы.',
#   'Эй, тебе что-нибудь нужно, ты всегда можешь прийти к Джоуи.',
#   'Мы с Чендлером живем через холл.',
#   'И он много раз уезжает.',
#   'Что, вроде есть правило или что-то в этом роде?',
#   'Кто такой Пол?',
#   'Подождите.',
#   'Ваше "ненастоящее свидание" сегодня вечером с Полом Винным Парнем?',
#   'Привет, Фибс, хочешь помочь?',
#   'Что это?',
#   'С книжным шкафом покончено!',
#   'Росс, позвольте задать вам вопрос.',
#   'У нее есть мебель, стереосистема, хороший телевизор - что ты получил?',
#   'Вы облажались.',
#   'О чем ты говоришь?',
#   "'Одна женщина'?",
#   'Это все равно, что сказать, что для вас есть только один вкус мороженого.',
#   'Дай мне кое-что тебе сказать, Росс.',
#   'Есть много вкусов.',
#   'Есть Rocky Road, Cookie Dough и Bing!',
#   'Черри-ваниль.',
#   'Вы можете получить их с Джимми, орехами или взбитыми сливками!',
#   'Это лучшее, что с тобой когда-либо случалось!',
#   'Вы поженились, вам было восемь лет?',
#   'С возвращением в мир!',
#   'Схватить ложку!',
#   'Поздравляю.',
#   'А пока ты в ударе, если тебе кажется, что тебе нужно приготовить западный омлет или что-то в этом роде.',
#   'Хотя на самом деле я не так голоден.',
#   'Доброе утро, Пол.',
#   'Это было не настоящее свидание?!',
#   'Какого черта ты делаешь на настоящем свидании?',
#   'Ага, я актер.',
#   'Сомневаюсь.',
#   'В основном региональная работа.',
#   'Я не допущу этого оскорбления.',
#   'Конечно, строчка!',
#   'Не могу поверить, что вы не знали, что это строчка!',
#   'Не могу поверить в то, что я здесь слышу.',
#   'Да, верно!',
#   'Ты серьезно?',
#   'Мы все еще говорим о сексе?',
#   'Ага, извините, глотание меня замедлило.',
#   'Ага, успокойся.',
#   'Вы не увидите, чтобы Росс становился хаотичным и нервным каждый раз, когда они приходят.',
#   'Хорошо, а когда он был в последний раз?',
#   'Ну, это все равно испорчено, да?',
#   'Ваши люди действительно такие плохие, да?',
#   'Что мы должны здесь видеть?',
#   'Всегда.',
#   'Это как язык знакомств.',
#   'Знаешь, вроде "Это не ты" означает "Это ты".',
#   'Ага.',
#   'Снижает удар.',
#   '"Смотритель, через пять минут моя боль закончится.',
#   'Но тебе придется жить с осознанием того, что ты послал на смерть честного человека".',
#   'Спасибо!',
#   'Давайте продолжим.',
#   '"Я просто хочу вернуться в камеру.',
#   'Потому что в камере я могу курить".',
#   'Что?',
#   'Ух ты!',
#   'Привет!',
#   'Нет-нет-нет, я тебе сигарету не даю.',
#   'Пропустить?',
#   'Это смешно!',
#   'Хорошо, Фиби?',
#   'О чем ты говоришь?',
#   'Оставь это!',
#   'Так когда мы встретимся с этим парнем?',
#   'Давай, Росс.',
#   'Ты можешь войти, но твой приятель с фильтром должен оставаться снаружи!',
#   'Чендлер!',
#   'Он здесь!',
#   'Знаешь, что было классного?',
#   'Его улыбка была немного кривой.',
#   'Алан.',
#   'Хрипы костяшками пальцев всех беспокоят?',
#   'Ну, это немного раздражает, или это как, когда Фиби жует волосы?',
#   'А, "да, да"?',
#   'Уважаешь ли ты свое тело?',
#   'Что происходит?',
#   'Еще приятнее, когда все носят нижнее белье.',
#   'О, Боже!',
#   'И все?',
#   'Все кончено?',
#   'Просто так?',
#   'Хорошо!',
#   'Наверное, убью себя!',
#   'Эй, если Маленький Джоуи мертв, то у меня нет причин жить!',
#   'Вы?',
#   'Росс, извини.',
#   'Девяносто пять, девяносто шесть, девяносто семь.',
#   'Смотри, я же сказал!',
#   'Менее чем в сотне шагов от нашего дома до сюда.',
#   'Привет!',
#   'Вот именинник!',
#   'Росс, посмотри: хоккейные билеты, РейнджерсПингвины, сегодня вечером в Гардене, и мы тебя возьмем.',
#   'Мы любим тебя, мужик.',
#   'Итак?',
#   'Что не так с двадцатой?',
#   'К черту хоккей, давайте все так сделаем!',
#   'Давай, Росс!',
#   'О, вы в порядке, да, на первую работу.',
#   'Пиявка замечает Мессье в складке - вот и пропуск!',
#   'Что?',
#   'Персики?',
#   'Эй, у этой женщины задница как у Кэрол!',
#   'Какие?',
#   'Думал, мы пытаемся что-то найти.',
#   'Да ладно, присядьте.',
#   'Просто сядь, сядь.',
#   'Ну как думаете, как долго это будет длиться?',
#   'Он уже прав, хватит.',
#   'Что такого особенного сегодня?',
#   'Так ты впервые с ней переспал, ну и что?',
#   'После этого ты проспал с ней семь лет.',
#   'Что?',
#   'С Кэрол?',
#   'О. Ух ты, мальчик, хоккей был большой ошибкой!',
#   'Сегодня вечером мы могли бы сделать много всего!',
#   'Мужчина.',
#   'Можете ли вы поверить, что он занимался сексом только с одной женщиной?',
#   'Правда?',
#   'А, а-а, у ребенка есть.',
#   'Хорошо, знаешь, что меня взбесило?',
#   'Женщины могут видеть грудь в любое время.',
#   'Вы просто смотрите вниз, и вот они.',
#   'Я не понимаю, как вы выполняете какую-либо работу.',
#   'Никаких планов, а?',
#   'Почему вы с ней расстались?',
#   'Будь мужчиной, просто перестань звонить.',
#   'Боже мой, Анджела.',
#   'Нет, да, нет, хорошо, но пока нет.',
#   'Я не хочу казаться слишком нетерпеливым.',
#   'Один Миссисипи, два Миссисипи, три Миссисипи.',
#   'Это кажется довольно крутым.',
#   'Привет, Анджела.',
#   'Хорошо выглядишь.',
#   'Вы не говорите.',
#   'Боб?',
#   'Кто, черт возьми, такой Боб?',
#   'Да ладно, нам было здорово вместе.',
#   'И не только о забавных вещах, но и о разговорах.',
#   'Что?',
#   'Хорошо, хорошо, так почему бы нам четверым не пойти сегодня вечером пообедать вместе?',
#   'Вы знаете, как друзья?',
#   'Знаешь, ты и Боб, и я, и моя девушка, ммм, Моника.',
#   'Моника, я говорю тебе, этот парень идеально тебе подходит.',
#   'Давай.',
#   'Этот парень классный.',
#   'Его зовут Боб.',
#   'Он, брат Анджелы.',
#   'Он умен, он искушен, и у него настоящая работа.',
#   'Я хожу на три прослушивания в месяц и называю себя актером, но Боб.',
#   'Что?',
#   'Фу!',
#   'Послушайте, я прошу здесь об одолжении.',
#   'Если я сделаю это для ее брата, может быть, Анджела вернется ко мне.',
#   'Я знаю, но я совершил огромную ошибку.',
#   'Я никогда не должен был с ней расставаться.',
#   'Ты мне поможешь?',
#   'Пожалуйста?',
#   'Ага.',
#   'Что что?',
#   'Нет, но он.',
#   'Боже мой.',
#   'Мне вдруг показалось, что я падаю.',
#   'Но не я.',
#   'Итак, вы с Анжелой, а?',
#   'Ты счастливчик.',
#   'Знаешь, чего мне в ней не хватает больше всего?',
#   'Этот милый едкий звук, когда она ест.',
#   'Как счастливая белочка или ласка.',
#   'А, да, да, послушайте.',
#   'Да, но это ненадолго.',
#   'Она слишком много для меня в постели.',
#   'Сексуально.',
#   'Что?',
#   'Да ладно, они близки.',
#   'О, как будто вы никогда не бывали с Россом немного раздражительно.',
#   'Ну, а кто скажет, что правда?',
#   'То есть.',
#   'Ладно, слушай, я этим не горжусь, ладно?',
#   'Ну может я немного.',
#   'Ой!',
#   'Подожди, подожди, подожди.',
#   'Ты хочешь его, я хочу ее.',
#   'Ты ему нравишься.',
#   'Ага.',
#   'Я думаю, что если мы сложим головы вместе, между нами двумя, мы можем их разлучить.',
#   'Официант, сюда еще одна тарелка куриных крылышек.',
#   'Отлично.',
#   'Велл, Ева, мы отлично поработали здесь, и я должен сказать, ваша проблема довольно ясна.',
#   'Что думаете?',
#   'Да ладно, ребята, все было не так уж плохо.',
#   'Это было лучше, чем то, что я сделал с троллями, по крайней мере, ты должен увидеть мою голову.',
#   'Агентство талантов Эстель Леонард.',
#   'Ух ты, агентство оставило мне свою визитку!',
#   'Может, они захотят подписать меня!',
#   'Кто такой Рик?',
#   'Я не смог.',
#   'Когда я с женщиной, мне нужно знать, что я встречаюсь с большим количеством людей, чем она.',
#   'Ага.',
#   'Ага.',
#   'Боже мой!',
#   'Хорошо!',
#   'Хорошо, я буду там!',
#   'Это был мой агент.',
#   'Мой агент только что дал мне работу в новом фильме Аль Пачино!',
#   'Вы можете в это поверить?',
#   'Аль Пачино!',
#   'Этот парень стал причиной того, что я стал актером!',
#   '"Я не в порядке?',
#   'Пфии.',
#   'Вы вышли из строя!',
#   'Весь зал не в порядке!',
#   '"Как раз когда я подумал, что меня нет, меня снова втягивают!"',
#   'Я его.',
#   'Я его двойник.',
#   'Кей?',
#   'Я играю задницу Аль Пачино.',
#   'Хорошо?',
#   'Он идет в душ, а потом.',
#   'Я его задница.',
#   'Да ладно, ребята.',
#   'Это настоящий фильм, и в нем играет Аль Пачино, и это здорово!',
#   'Хорошо, хорошо, хорошо!',
#   'Шутите, мне плевать!',
#   'Для меня это большой прорыв!',
#   'Вот.',
#   'Мне нужно одолжить увлажняющий крем.',
#   'Что думаете?',
#   'Сегодня большой день!',
#   'Спасибо!',
#   'Послушайте, я просто хочу поблагодарить вас за эту прекрасную возможность.',
#   'Я?',
#   'Верно.',
#   'Хорошо.',
#   'Потеря халата.',
#   'И халат утерян.',
#   'Ну, я, я принимаю душ.',
#   'О. Ну, как я понимаю, парень здесь расстроен, понимаешь?',
#   'Я имею в виду, его жена мертва, его брат пропал.',
#   'Думаю, его задница здесь разозлится.',
#   'Я впадал в тихое отчаяние.',
#   'Но если вам нужно спросить.',
#   'Нет.',
#   'Меня уволили.',
#   'Да, они сказали, что я слишком много играл с этим.',
#   'Я всем об этом рассказал!',
#   'Теперь все пойдут в театр, ожидая меня увидеть, и…',
#   'Моя мама будет.',
#   'Понимаешь, я шесть лет ничего не делал, кроме дерьмовых пьес.',
#   'И я наконец получил свой шанс, и я провалил его!',
#   'Сложно сказать, я был голый.',
#   'Ага?',
#   'Это так мило!',
#   'Всем привет.',
#   'Что ж, старый сосед Чендлера по комнате был евреем, и это единственные свечи, которые у нас есть, так что счастливой Хануки всем!',
#   'Как дела, чувак?',
#   'Боже мой, он заперт в вестибюле банкомата с Джилл Гудакр.',
#   'Чендлер, слушай, слушай, хурм хур, хур, хур, хур, хур, хур.',
#   'Вперед.',
#   'Хорошо.',
#   'Ух-у-у-у!',
#   'Ладно, ладно, мое самое странное место, должно быть, бее, женская комната на втором этаже публичной библиотеки НьюЙорка.',
#   'Нет уж!',
#   'Нет, нет, нет.',
#   'Давай.',
#   'Давай.',
#   'У нас есть победитель!',
#   'Этого никогда не случится.',
#   'Ты и Рэйчел!',
#   'Потому что вы слишком долго ждали, чтобы сделать свой ход, и теперь вы в зоне друзей!',
#   'Нет, Росс, ваш мэр зоны!',
#   'Священство!',
#   'Послушай, Росс, я говорю тебе, что она понятия не имеет, о чем ты думаешь, и если ты не пригласишь ее в ближайшее время, ты застрянешь в зоне, навсегда!',
#   'Агаааа!',
#   'Что тебя испортило, вино, свечи, лунный свет, да, тебе просто нужно подойти к ней и сказать: "Посмотри, Рэйчел", я думаю.',
#   'Э-э, тише.',
#   'Ты собираешься это сделать?',
#   'Вы хотите, чтобы я помог?',
#   'Росс, Росс, удачи тебе.',
#   'Хорошо.',
#   'Эй, ты куда?',
#   'Нет-нет, тебе нельзя туда идти.',
#   'Эээ, причина.',
#   'Я, э, не могу тебе сказать.',
#   'Хорошо, послушай, ты должен обещать, что никогда не скажешь Россу, что я тебе сказал.',
#   'Он планирует твой день рождения.',
#   'А ты лучше удивляйся!',
#   'Эй, не смотри на меня, это дело Росса.',
#   'Что?',
#   'Ооо, извини, это воск.',
#   'Хорошо?',
#   'Эй, ар ар ар ар ар.',
#   'Э, Росс, наверное, сейчас не лучшее время, чтобы поднимать эту тему, но тебе нужно устроить вечеринку для Моники.',
#   'Не я.',
#   'Дважды?',
#   'Ребята, вы в порядке?',
#   'Вот видите, я не верю ни во что из этого.',
#   'Я думаю, что раз ты мертв, ты мертв!',
#   'Ты ушел!',
#   'Вы пища для червей!',
#   'Так Чендлер выглядит веселым, а?',
#   'Доброе утро.',
#   'Мы готовы к работе?',
#   'Что?',
#   'Послушайте, ГигантыКовбои.',
#   'Нет, это перед игрой.',
#   'Я буду смотреть это на ресепшене.',
#   'Просто, нарушение слуха.',
#   'Семнадцать-четырнадцать гигантов, три минуты до третьего.',
#   'Ох, смотрите, смотрите, смотрите, смотрите!',
#   'Я обнажил Монику!',
#   'Привет, привет.',
#   'Да, я.',
#   'На сегодняшний день я официально являюсь Джоуи Триббиани, актерской моделью.',
#   'Вы знаете эти плакаты городской бесплатной поликлиники?',
#   'Нет, я слышал, болезнь Лайма открыта, так что.',
#   'Спасибо.',
#   'Ага.',
#   'Да?',
#   'Привет.',
#   'Мы работали вместе.',
#   "Да, в Macy's.",
#   'Вы были девушкой-одержимостью, верно?',
#   'Я был парнем из Арамиса.',
#   'Арамис?',
#   'Арамис?',
#   'Я должен вам сказать.',
#   'Ты лучший в своем деле.',
#   'Я серьезно.',
#   'Ты удивительный.',
#   'Вы знаете, когда брызнуть, а когда лечь.',
#   'О, ты сегодня замечательно пахнешь.',
#   'Что на тебе надето?',
#   'Слушай, хочешь пойти выпить или что-то в этом роде?',
#   'Что случилось?',
#   'О. Какие?',
#   'Подожди, подожди, подожди!',
#   'Полагаю, вы все это видели.',
#   'Найдите другое место для Дня Благодарения.',
#   'Вся моя семья думает, что у меня венерический диабет.',
#   'Чендлер, ты уже войдешь?',
#   'Привет, Моника, у меня вопрос.',
#   'Я не вижу картошек.',
#   'Но мама всегда их делает.',
#   'Это как традиция.',
#   'Вы получите кусочек индейки на вилке, немного клюквенного соуса и детеныша!',
#   'Достаточно плохо, что я не могу быть со своей семьей из-за моей болезни.',
#   'Воздушный шар?',
#   'Подождите, подождите, у нас есть копия вашего ключа.',
#   'Этот тон не заставит меня двигаться быстрее.',
#   'Этот будет.',
#   'Нет, не тот.',
#   'Эй, у меня есть замочная скважина и около миллиона ключей.',
#   'Вы делаете математику.',
#   'Эй, у всех были планы получше.',
#   'Это был чей-то выбор.',
#   'Вы называете это восхитительным?',
#   'Я должен это увидеть.',
#   'Хорошо, уродливый голый парень!',
#   'Я буду.',
#   'Большая половина.',
#   'Аааа, я не получил работу.',
#   'Не знаю.',
#   'Какой-то толстяк спит с менеджером магазина.',
#   'Он даже не весёлый, это всё политическое.',
#   'А, я буду одним из его помощников.',
#   'Это просто пощечина, понимаешь?',
#   'Эй, этот парень идет домой не только с запиской!',
#   'Привет.',
#   'Привет, извини, я опоздал.',
#   'Хорошие туфли, а?',
#   'Вы знаете не одного Веселого Бобби?',
#   'Оооооо, молоку нет места!',
#   'Эээ, четыре.',
#   'Да, и я встретил в магазине эту очень горячую маму-одиночку.',
#   'Что делать эльфу?',
#   'Сэнди!',
#   'Привет!',
#   'Давай!',
#   'Вы привели своих детей.',
#   'Ух ты, это грязно.',
#   'Привет, детки.',
#   'Привет, Бобби!',
#   'Ого!',
#   'Кто умер?',
#   'Эй, ребята.',
#   'Вы видели Сэнди?',
#   'Похоже, с пактом о свидании ничего не вышло.',
#   'Нононо, ты не можешь целовать Росса, это твой брат.',
#   'Хорошо, хорошо, хорошо.',
#   'Там.',
#   'Я не могу поверить, что вы сказали ого-ого.',
#   'Я даже не говорю ого-ого.',
#   'Да ладно, она твоя мама!',
#   'Уххх.',
#   'Я просто пописаю на улице.',
#   'Ага.',
#   'Верно.',
#   'Ничего страшного.',
#   'В причудливом мире!',
#   'Вы нарушили код!',
#   'Ты не целуешь маму друга!',
#   'Сестры в порядке, может быть, симпатичная тетя, но не мама, никогда не мама!',
#   'Ну да ладно, рэкет у тебя нет.',
#   'Ага, ну вы не звонили и не указывали размер рукоятки.',
#   'Росс, как ты мог допустить это?',
#   'Ты не думаешь, что моя мама сексуальная?',
#   'Я хочу, чтобы вы знали, что Глория Триббиани была красивой женщиной в свое время, хорошо?',
#   'Ты думаешь, родить семерых детей легко?',
#   'Он забыл оставить размер захвата!',
#   'Так ты ему скажешь?',
#   'А как насчет того, что, если вы этого не сделаете, его мать может.',
#   'Эээээ, у него даже бандажа нет!',
#   'Э, знаешь, знания - штука непростая.',
#   'Эй, эй, эй, тебе повезло, что я поймал их, когда поймал, а то кто знает, что могло бы случиться.',
#   'Я тоже, знаешь что.',
#   'За что ты злишься на меня?!',
#   'Чендлер, я ее не целовал, он целовал!',
#   'Посмотрите, что произойдет, если вы взломаете код?',
#   'А!',
#   'Хм?',
#   'А вот фото моих мамы и отца в день их свадьбы.',
#   'Теперь ты говоришь мне, что она не нокаут.',
#   'Давай!',
#   'Просто представьте себе, что она не беременна, вот и все.',
#   'МамаЦелующаяся.',
#   'Я молчу.',
#   'Тсс.',
#   'Он сделал это.',
#   'Он отругал ее, и не только о поцелуе, но и обо всем.',
#   'Нет, нет.',
#   'Он сказал: "Когда ты вырастешь и станешь мамой?"',
#   'Потом она вернулась со словами: "Вопрос в том, когда ты вырастешь и поймешь, что у меня есть бомба?"',
#   'В этом больше смысла.',
#   'Не знаю, я стою здесь и объясняю вам!',
#   'Я ничего не слышу.',
#   'Ой, подожди, подожди.',
#   'Сложно сказать, они такие крошечные и перевернутые.',
#   'Подожди подожди.',
#   'Они уходят, они уходят.',
#   'Нет, нет, они идут прямо на нас!',
#   'Запустить!',
#   'Запустить!',
#   'Их обычно можно встретить на "поднимающихся зверях".',
#   'Росс, ты правда читал все эти детские книжки?',
#   'Эй, Росс, послушай, ты знаешь, что сейчас твой ребенок только такой большой?',
#   'Это твой ребенок.',
#   'Привет папа!',
#   'Я люблю младенцев с их башмачками, пальчиками на ногах и ручонками.',
#   'Нужен новый стол.',
#   'Это правило.',
#   'Как ты до этого добрался?',
#   'Вы знали об этом?',
#   'Ладно, ладно, а как насчет того, чтобы разделить?',
#   'Да.',
#   'Почему нет?',
#   'Почему вы съезжаете?',
#   'Вы бы сказали мне, если бы выезжали прямо.',
#   'Ой, я знаю о Кипе все!',
#   'Ну, позволь мне кое-что спросить, Кип был лучшим соседом по комнате, чем я?',
#   'Так что это будет?',
#   'Или дядя.',
#   'Привет, Чендлер, этот стол закрывается в 7, давай.',
#   'Эй, эй, завтра магазин откроется!',
#   'Феминистский вопрос.',
#   'Вот куда я пошел!',
#   'Выбери одну, только одну!',
#   'Вот, как насчет того?',
#   'И что, как будто люди будут заходить и думать: "Ой-ой, я снова на улице?"',
#   'Конечно!',
#   'Не знаю, птицы просто не говорят: "Привет, посиди здесь, поешь что-нибудь" Хорошо, а божьи коровки?',
#   'Ладно, птичек хочешь, птиц достать!',
#   'Да ладно, у раковины поедим!',
#   'Давай, поиграем!',
#   'Нет-нет, она надрала нам задницы.',
#   'Вы могли бы быть в олимпийской сборной.',
#   'Да, сейчас налетать!',
#   'Вы должны убедиться, что, когда Паоло выйдет оттуда, первым, кого увидит Рэйчел, будет вы.',
#   'Она должна знать, что вы все, чем он не является!',
#   'Ты вроде как антиПаоло!',
#   'Wha.',
#   'Привет!',
#   'Сейчас 2:30 утра!',
#   'Ага!',
#   'Привет, ребята!',
#   'Вы все знаете моего отца?',
#   'Папа!',
#   'Эээ.',
#   'Ууууххх!',
#   'Позволь сказать привет.',
#   'Привет, мама.',
#   'Послушайте, я назначил встречу с доктором Базетой, и, извините?',
#   'Вы знали, что это не Ма?',
#   'Конечно!',
#   'Итак, как долго вы.',
#   'С тех пор?',
#   'Не знаю.',
#   'Ха!',
#   'Ты один, чтобы поговорить!',
#   'Блин.',
#   'Пожалуйста, скажите мне, что одна из них - Ма!',
#   'Это как если бы ты однажды проснулся и обнаружил, что твой отец ведет эту двойную жизнь.',
#   'Он вроде как какой-то шпион, работает на ЦРУ.',
#   'Это было бы круто.',
#   'Это круто!',
#   'Что с Рогом?',
#   'Спокойной ночи, ребята.',
#   'Привет?',
#   'Можем ли мы вам помочь?',
#   'Я, я Джоуи Трибиани.',
#   'Привет, папа.',
#   'Хм.',
#   'Ронни здесь!',
#   'Ого!',
#   'Нет.',
#   'Если ты пойдешь в гостиницу, будешь заниматься делами.',
#   'Я хочу, чтобы ты был здесь, чтобы я мог за тобой присматривать.',
#   'Верно, мистер, и мне все равно, сколько вам лет, пока вы под моей крышей, вы будете жить по моим правилам.',
#   'А это значит, не спать со своей девушкой.',
#   'Теперь, папа, ты будешь в моей комнате, Ронни, эээ, можешь остаться в комнате Чендлера.',
#   'Хорошо.',
#   'Теперь это только на сегодня.',
#   'С завтрашнего дня вы должны внести изменения.',
#   'Шесть лет - это достаточно.',
#   'Ну или порвать с Ронни.',
#   'Тогда тебе придется расставаться с мамой!',
#   'Это неправильно!',
#   'Я не хочу это слышать!',
#   'А теперь иди в мою комнату!',
#   'Я просто пытаюсь устроиться поудобнее.',
#   'Я не могу спать в нижнем белье.',
#   'Я подумал.',
#   'Знаете, о том, как я всегда вижу девушек поверх девушек.',
#   'Вы понимаете, о чем я.',
#   'О том, как я всегда встречаюсь со всеми этими женщинами, и я всегда думал, что когда появится подходящая, я смогу быть стойким парнем и пройти дистанцию, понимаете.',
#   'Я смотрю на своего папу, думаю.',
#   'Нет.',
#   'Вы правда так думаете?',
#   'Ой!',
#   'Спасибо, Чендлер.',
#   'Привет!',
#   'Что с тобой?',
#   'Ма!',
#   'Что ты здесь делаешь?',
#   'Ой!',
#   'Большое кольцо!',
#   'Постойте.',
#   'Ты знал?',
#   'Тогда как ты мог, я имею в виду, как ты мог.',
#   'Ма, я не хочу показаться неуважительным, но о чем, черт возьми, ты говоришь?',
#   'Я, я имею в виду, что насчет тебя?',
#   'Я за тебя рада?',
#   'Ма.',
#   'Мне жаль.',
#   'Я, я только что сделал то, что, как я думал, ты хочешь.',
#   'Ага.',
#   'Ты в десять раз красивее, чем она.',
#   'С этим кольцом?',
#   'Нет конкурса!',
#   'Ага.',
#   'Он будет продолжать изменять моей маме, как она и хотела.',
#   'Моя мама будет продолжать притворяться, что она не знает, хотя она и знает, и моя младшая сестра Тина больше не может видеться со своим мужем, потому что он получил запретительный судебный приказ, который не имеет ничего общего, кроме того, что я обнаружил выходит сегодня.',
#   'Да, я думаю, это просто, вы знаете, они родители, после определенного момента вы должны отпустить.',
#   'Даже если вы знаете лучше, вы должны позволить им совершать собственные ошибки.',
#   'Расчистите пути для экспресса расплаты за болванов.',
#   'Следующая остановка, Рэйчел Грин.',
#   'Извините.',
#   'Неправильные олухи.',
#   'Я говорю тебе, Росс, ты ей нужен.',
#   'Вы в игре!',
#   'Извините, мы можем принести сюда яйцо, все еще в скорлупе?',
#   'Спасибо.',
#   'Да, ты подойдешь к ней и скажешь: "Вот тебе яйцо, я возвращаю тебе яйцо".',
#   'Думаешь, сработает?',
#   'Вообще-то, завтрашняя ночь вроде как зависит от того, как сегодня пойдет.',
#   'Нет, нет, нет, не смей бросить меня под залог.',
#   'Единственная причина, по которой она встречается со мной, это то, что я сказал, что могу привести друга для ее подруги.',
#   'Жалкий бардак?',
#   'Я знаю, но - давай, чувак, она нуждалась, она уязвима.',
#   'Я думаю, ч-цзин!',
#   'Спасибо.',
#   'Слушай, ты не встречался с женщиной со времен Дженис.',
#   'Ты делаешь это.',
#   'Как я выгляжу?',
#   'Нет, нет, не надо!',
#   'Я так долго ждал, чтобы встретиться с Лоррейн.',
#   'Просто успокойся.',
#   'Чендлер: Успокойтесь, успокойтесь?',
#   'Вы познакомили меня с женщиной, которую я бросил дважды за последние пять месяцев!',
#   'Вы можете перестать кричать?',
#   'Ты заставляешь меня нервничать, и я не могу пойти, когда нервничаю.',
#   'Молодец.',
#   'Э-э, четвертинки или рулоны четвертей?',
#   'Мы не можем этого сделать.',
#   'Могу я поговорить с вами минутку, там?',
#   'Мы можем уехать сейчас.',
#   'Она сказала, что хочет намазать мое тело чем-то, а потом слизать.',
#   'Я даже не уверен, что такое намазывание, но я определенно хочу быть его частью.',
#   'Вы правы, извините.',
#   'Ты прав.',
#   'Я ухожу отсюда.',
#   'Вот моя кредитная карта.',
#   'Ужин за меня.',
#   'Мне очень жаль, Чендлер.',
#   'Ого.',
#   'Не знаю.',
#   'Вы бросили ее на Новый год.',
#   'Если вы этого не сделаете, я сделаю это.',
#   'И что вы собираетесь делать?',
#   'А как насчет Тони?',
#   'Если вы можете закончить стейк весом 32 унции, это бесплатно.',
#   'Итак, обратно на свое место, ты думаешь, может быть, ага?',
#   'Я говорю вам, эта обезьяна - магнит для цыплят!',
#   'Она собирается взглянуть на его пушистое милое личико, и это решит сделку.',
#   'Мммм.',
#   'Хорошо.',
#   'Более сливочное.',
#   'Не знаю.',
#   'Мы говорим о взбитой рыбе, Моника.',
#   'Я просто счастлив, что сдерживаю это, понимаешь?',
#   'Ой-ой.',
#   'Вульва?',
#   'Ого!',
#   'Вы обнимались?',
#   'Сколько раз?',
#   'В чем дело?',
#   'Вы просто говорите то, что хотите с ней сделать.',
#   'Или что вы хотите, чтобы она с вами сделала.',
#   'Или о том, что, по вашему мнению, другие люди могут делать друг с другом.',
#   'Я скажу тебе что.',
#   'Попробуй что-нибудь на мне.',
#   'Почему нет?',
#   'Давай!',
#   'Закройте глаза и скажите, чем вы хотите заниматься прямо сейчас.',
#   'ага, что еще?',
#   'Ладно, слушай, я начну, ладно?',
#   'Давай.',
#   'Давай.',
#   'Хорошо, готово, смотрите!',
#   'О. Росс, ты меня так возбуждаешь.',
#   'Я хочу, чтобы твои губы были на мне сейчас.',
#   'Хорошо, теперь ты скажешь что-нибудь.',
#   'Давай!',
#   'Тебе нравится эта женщина, правда?',
#   'Ты хочешь снова ее увидеть?',
#   'Ну, если ты не можешь со мной грязно говорить, как ты собираешься с ней говорить грязно?',
#   'А теперь скажи, что хочешь ласкать мою задницу!',
#   'Хорошо, хорошо.',
#   'Я рядом.',
#   'Вперед, продолжать.',
#   'Ну вот!',
#   'Продолжать.',
#   'Продолжать!',
#   'Скажи это, скажи это!',
#   'Привет, Чендлер, пока ты спал, тот парень с твоей старой работы снова позвонил.',
#   'И снова, и снова, и снова.',
#   'Алло?',
#   'И опять.',
#   'Какой инструмент!',
#   'Итак, э, как все прошло с Селией?',
#   'Хорошо, Росс!',
#   'Ого!',
#   'И, ага?',
#   'Ты обнимался.',
#   'Да где он, черт возьми?',
#   'Есть официантка.',
#   'Простите, мисс.',
#   'Привет, мисс?',
#   'Нет, нет, как ты здесь работаешь?',
#   'Я говорю, что вижу разницу.',
#   'Мне все равно.',
#   'Фиби из Фиби.',
#   'Урсулы - горячо!',
#   'Привет, Фибс, угадай, кого мы сегодня видели.',
#   'Нет.',
#   'Нет.',
#   'Не с того места, где я стоял.',
#   'Я вернулся к Риффу.',
#   'Думаю, я нравлюсь Урсуле.',
#   'Я заказал только кофе, а она принесла мне плавленого тунца и четыре тарелки кудрявого картофеля фри.',
#   'Она такая горячая.',
#   'Фибс?',
#   'Думаешь, было бы нормально, если бы я спросил твою сестру?',
#   'Чтобы, если бы мы пошли на свидание, она была бы там.',
#   'Круто, спасибо.',
#   'Привет.',
#   'Фиби, не могли бы вы сделать мне одолжение?',
#   'Не могли бы вы примерить это?',
#   'Я просто хочу убедиться, что он подходит.',
#   'О, нет-нет-нет.',
#   'Это для Урсулы.',
#   'Я просто прикинул, понимаете, по размеру.',
#   'Ага.',
#   'Ice Capades.',
#   'Не знаю.',
#   'Знаешь, она мне нравится.',
#   'Она другая.',
#   'В ней есть что-то такое.',
#   'Привет, Фиби, я спросила тебя, и ты сказала, что все в порядке.',
#   'Ладно, может, теперь меня не устраивает, что это не нормально.',
#   'Вых.',
#   'Да.',
#   'Ну, не то чтобы это твое дело, но нет, мы не знаем, хорошо?',
#   'Вы имели в виду секс, верно?',
#   'У Тампа Бэй ужасная команда.',
#   'Он должен взять мешок?',
#   'Ага, Росс.',
#   'Вам и ребенку просто нужно лучше блокировать.',
#   'О, ребята, кто-нибудь из вас был когда-нибудь в Радужной комнате?',
#   'Это реально дорого?',
#   'Я заберу Урсулу сегодня вечером.',
#   'Это ее день рождения.',
#   'Когда это?',
#   'Ой, чувак.',
#   'Каковы шансы, что это произойдет?',
#   'Что я могу сделать?',
#   'Слушай, я не хочу ничего делать, чтобы облажаться с Урсулой.',
#   'Ну, если она мой друг, надеюсь, она поймет.',
#   'Я имею в виду, а вы, ребята?',
#   'Привет.',
#   'На днях твоя сестра меня подставила.',
#   'Два дня пытаюсь.',
#   'Когда я звоню в ресторан, они говорят, что она слишком занята, чтобы разговаривать.',
#   'Не могу поверить, что она меня взорвала.',
#   'Урс, что ты здесь делаешь?',
#   'Я пытался дозвониться до тебя.',
#   'Нет, нет, нет, не говори "слушай".',
#   'Я знаю, что "слушай".',
#   'Я сказал, что слушай.',
#   'Не понимаю.',
#   'Что случилось?',
#   'А что насчет всего, что вы сказали под мостом?',
#   'Ты не пьешь.',
#   'Урс.',
#   'Почему?',
#   'Это потому, что я дружу с Фиби?',
#   'Нет.',
#   'Нет, я не мог этого сделать.',
#   'Тогда, ну, тогда мне очень жаль.',
#   'Знаю.',
#   'Не знаю, это просто из-за того, что мы расстаемся или что-то в этом роде, но ты никогда не выглядела так красиво.',
#   'Фибс?',
#   'Мы только что получили сообщение.',
#   'Hola, amigos.',
#   'О нет, я уверен, что ксерокс несколько поймал.',
#   'Заткнись!',
#   'Спасибо.',
#   'На троих был шоколад.',
#   'Похоже на восьмерку, понятно?',
#   'Да, просто мы не знаем женщин, которые умеют играть в покер.',
#   'Стой, стой, стой, Моника, что ты делаешь?',
#   'Это игра в покер.',
#   'Вы не можете подавать еду, состоящую из более чем одного слога.',
#   'Это должно быть что-то вроде чипсов, или дипа, или кренделя .',
#   'О чем?',
#   'Хех.',
#   'Я блефовал.',
#   'Знаете что, ребята?',
#   'Это их первый раз, почему бы нам просто не забыть о деньгах, ладно?',
#   'Ага?',
#   'Нет, я так не думаю, посмотри на Росс, потому что я думаю, ты ее любишь.',
#   'А теперь послушайте, ребята, мы об этом говорили, и если вы не хотите играть, мы полностью понимаем.',
#   'Эй, спасибо, что научила нас Косоглазой Мэри.',
#   'Ребята, мы должны сыграть в это в нашей обычной игре.',
#   'Что?',
#   'Хорошо, я закажу пиццу.',
#   'Ничего страшного.',
#   'Я просто возьму крестики-нолики, чтобы удержать меня.',
#   'Э. Фиби?',
#   'Фиби?',
#   'Я тоже.',
#   'Хорошо, что есть.',
#   'Ааа, я складываюсь, как дешевая проститутка, которой толстый парень с язвами на лице ударил в живот.',
#   'О, я ухожу.',
#   'Послушайте, Рэйчел, мы не обязаны этого делать.',
#   'Проверить.',
#   'Ничего страшного, Росс, ты можешь меня спросить.',
#   'Какие?',
#   'Вот пять, пять.',
#   'Ааааа лежит ничего.',
#   'Знаешь, это сложная рука.',
#   'Ой!',
#   'Невыносимое подобие бытия!',
#   'Suckfest!',
#   'Привет.',
#   'Мне не нужно насилие, чтобы наслаждаться фильмом, пока есть немного наготы.',
#   'Я имел в виду женскую наготу!',
#   'Хорошо, мне не нужно видеть, как Лу Грант резвится!',
#   'Согласен.',
#   'Я как бы в недоумении.',
#   'Она правда это сказала?',
#   'Сегодня вечером, сегодня вечером?',
#   'Как вы могли его потерять?',
#   'Хорошо, хорошо, хорошо, ты обезьяна, ты болтаешься по городу.',
#   'Куда ты идешь?',
#   'Марсель?',
#   'Марсель?',
#   'Обезьяна.',
#   'Конечно, конечно.',
#   'Вы, эээ, вы пытались повернуть ручку в другую сторону?',
#   'А, тогда нет.',
#   'Э, разве мы не где-то здесь что-то среднее?',
#   'Не можем, ладно?',
#   'Ха, нам очень жаль.',
#   'Вы не представляете, как жаль, но мы обещали найти эту обезьяну.',
#   'Если вы его видите, он на высоте и соответствует имени Марсель, так что, если бы мы могли сфотографировать вас, вы действительно нам помогли бы!',
#   'Марсель!',
#   'Не знаю.',
#   'Я любил старшую школу.',
#   'четыре года вечеринок, свиданий и секса.',
#   'Ни в коем случае!',
#   'Мистер Солти моряк, да, он должен быть, Ее автоответчик?',
#   'А ты где был?',
#   'Чувак, нам нужно что-то с этим парнем сделать.',
#   'Сегодня утром.',
#   'Ты вырастешь?',
#   'Я не говорю о сексе, но, Да, тосты, овсянка, ничего, что брызгает.',
#   'Может, она так и не получила твоего сообщения.',
#   'Он вернулся!',
#   'Смотритель спиной!',
#   'Ложись!',
#   'Да?',
#   'Непослушный!',
#   'О боже.',
#   'Эй, а у нас телефон не работает?',
#   'Я пытался дозвониться до вас из кафе, но не было.',
#   'Послушайте, я перешел улицу и поговорил с.',
#   'Могу я воспользоваться вашим телефоном?',
#   'Да, Да, Сидни здесь?',
#   'Ах, это?',
#   'МОНИКА Сидни: Значит, она женщина!',
#   'И что?',
#   'Да.',
#   'Смотри, я живу через.',
#   'Да, сосед.',
#   'Да, брюнетка.',
#   'Да, сказала она.',
#   'в тот день ты выглядела как Ингрид Бергман.',
#   'Большой день.',
#   'Хорошо, я дам вам это, мистер Арахис одевается лучше.',
#   'Как кто-то мог узнать номер вашей кредитной карты?',
#   'Нет, все еще этнически.',
#   'Мой агент считает, что у меня должно быть более нейтральное имя.',
#   'Плюс, знаешь, я думаю, это должен быть Джо.',
#   'Знаешь, Джоуи заставляет меня звучать так, как будто я, я не знаю, такой большой.',
#   'А я нет.',
#   'Сталин.',
#   'Сталин, я знаю это имя?',
#   'Звучит знакомо.',
#   'Джо Сталин.',
#   'Знаете, это неплохо.',
#   'Иосиф Сталин.',
#   'Думаю, вы бы это запомнили!',
#   'Где ты был?',
#   'Привет!',
#   'Он победил тебя.',
#   'Не могу поверить, Росс.',
#   'Это отстой!',
#   'Разве вы не можете удержать его?',
#   'А как обезьяну попасть в зоопарк?',
#   'Ментов вызвали?',
#   'Вы знаете, что уже есть Иосиф Сталин?',
#   'Судя по всему, это был тот русский диктатор, который всех этих людей перебил.',
#   'Вы бы думали, что знали бы об этом!',
#   'Фиби.',
#   'Как ты думаешь, мне бы подошел хороший сценический псевдоним?',
#   'Мы, мы возвращаемся с прогулки и- телефон звонил.',
#   'Не знаю, что сказать, Росс.',
#   'Эээ, это обезьяна.',
#   'Марсель, я голоден.',
#   'Привет, я буду читать на роль Меркуцио.',
#   'Холден МакГроин.',
#   'Отличный счет мечты.',
#   'Не знаю.',
#   'Что на тебе надето?',
#   'Привет, привет, Чан.',
#   'Она могла бы работать на вас.',
#   'Зачем палеонтологу пейджер?',
#   'Насколько молод молодой Итан?',
#   'Молодой?',
#   'Ого!',
#   'Отпусти, Росс.',
#   'Это был просто сон.',
#   'Это не значит.',
#   'Хорошо, расслабься, расслабься.',
#   'Просто расслабься, просто расслабься.',
#   'Будь крутым, будь крутым.',
#   'Услуги?',
#   'О, услуги.',
#   'Привет, привет.',
#   'Как прошел первый день?',
#   'О. Да, знаешь.',
#   'Мои лепешки.',
#   'Хорошо.',
#   'Итак, расскажи.',
#   'Было ли это похоже на тебя и Чендлера, а потом на тебя и меня, или на тебя, меня и Чендлера?',
#   'Что?',
#   'Послушайте, в следующий раз, когда вы поговорите с ним, вы можете спросить его, какой из "Могучих рейнджеров" самый сильный?',
#   'Стегозавр!',
#   'А Андрь?',
#   'Они уже здесь?',
#   'Мм, влажно, ага.',
#   'Хорошо, хорошо.',
#   'На прогулку.',
#   'Хорошо, я иду.',
#   'Я ухожу.',
#   'Мы должны об этом знать?',
#   'Я буду в зале ожидания, раздавать сигары.',
#   'Стреляйте!',
#   'Стрелять!',
#   'Стрелять!',
#   'Стреляй или просто падай.',
#   'Это тоже хорошо.',
#   'Ага.',
#   'Послушайте, леди, эй.',
#   'Да?',
#   'А кто тебе нравится?',
#   'Селтикс?',
#   'Ха.',
#   'Они не могут попасть в лодку, если, подождать.',
#   'Они отстой, понятно?',
#   'Что?',
#   'Что.аа?',
#   'Дай мне отца.',
#   'Эй, нам нужен здесь отец!',
#   'Нам нужен отец!',
#   'Ой, ой, ой, прости.',
#   'А, ну ладно.',
#   'Прямо по этому пути.',
#   'Все остальные беременные, кажется, собираются сюда.',
#   'Привет, да, это я.',
#   'О нет, нет, мы просто друзья.',
#   'Да, я холост.',
#   '25. Актер.',
#   'Привет?',
#   'Да, так, ну, ну, что случилось с этим отцом, я имею в виду, если бы кто-то где-то забрал моего ребенка, я бы хотел знать об этом, понимаете?',
#   'Ладно, послушайте, может мне просто пойти.',
#   'Удачи и береги себя, а?',
#   'Вы знаете, в чем проблема "Селтикс"?',
#   'Они позволяют игрокам управлять командой.',
#   'Да, это так.',
#   'Это так.',
#   'Фу!',
#   'Что это такое?',
#   'Что-то взорвалось!',
#   'Разрушение воды, что вы имеете в виду?',
#   'Что это, разрушение воды?',
#   'Давай, Лидия, ты справишься.',
#   'Толкать!',
#   'Вытолкни их, вытолкни, сильнее, сильнее.',
#   'Вытолкните их, вытолкните их, выходите!',
#   'Давай возьмем этот мяч и начнем двигаться, эй, эй, хо, хо.',
#   'Давай.',
#   'Я просто, да, верно.',
#   'Толкать!',
#   'Толкать!',
#   'Ой, только что родила.',
#   'Расслабьтесь.',
#   'У тебя всего девять сантиметров.',
#   'И ребенок на нулевой станции.',
#   'Бен, Бен, привет Бен.',
#   'Ничего такого.',
#   'Не думаю, что его зовут.',
#   'Он мало что делает?',
#   'Привет, Чан, ты можешь мне помочь?',
#   'Обещаю, что верну тебе деньги.',
#   'Я, правда.',
#   'Я заплачу тебе на этот раз.',
#   'Ну.',
#   'Я помогаю в Медицинской школе НьюЙоркского университета с некоторыми, исследованиями.',
#   'Ой, ну ну, наука.',
#   'Это исследование фертильности.',
#   'Ладно, ребята, это не так уж важно.',
#   'На самом деле.',
#   'То есть, я просто хожу туда через день и, делаю свой вклад в проект.',
#   'Эй, эй, но через две недели я получаю семьсот долларов.',
#   'Разводим огонь.',
#   'Готовьте мясо.',
#   'Ладно.',
#   'Не знаю, она, эээ, она очень классная.',
#   'Что, ты думаешь, я скажу девушке, что мне нравится, что я тоже вижу чашку?',
#   ...],
#  'МОНИКА': ['Рассказывать нечего!',
#   'Он просто парень, с которым я работаю!',
#   'Хорошо, расслабьтесь.',
#   'Это даже не свидание.',
#   'Просто два человека идут на ужин и не занимаются сексом.',
#   'Ты в порядке, милая?',
#   'Кэрол сегодня вывезла свои вещи.',
#   'Позвольте мне принести вам кофе.',
#   'Нет.',
#   'Рэйчел?!',
#   'De-caff.',
#   'Ладно, все, это Рэйчел, еще одна выжившая в Линкольнской школе.',
#   'Это все, это Чендлер, Фиби и Джоуи, и, вы помните моего брата Росса?',
#   'Так ты хочешь сказать нам сейчас, или мы ждем четырех мокрых подружек невесты?',
#   'Кого не пригласили на свадьбу.',
#   'Теперь я предполагаю, что он купил ей большой орган, и она действительно не в восторге от этого.',
#   'Ну, я думаю, мы установили, кто здесь с Моникой.',
#   'Просто дыши, дыши, вот и все.',
#   'Просто попробуйте думать о приятных спокойных вещах.',
#   'Ладно, послушайте, наверное, это к лучшему, понимаете?',
#   'Независимость.',
#   'Взять под контроль свою жизнь.',
#   'Джоуи, хватит к ней приставать!',
#   'Сегодня день ее свадьбы!',
#   'Займи его!',
#   'Может быть.',
#   'Да!',
#   'Рэйч, подожди, я могу отменить.',
#   'Ты в порядке?',
#   'Я имею в виду, ты хочешь, чтобы я остался?',
#   'Правда?',
#   'Привет, заходи!',
#   'Пол, это, все, все, это Пол.',
#   'Две секунды.',
#   'Боже мой!',
#   'Мой брат сейчас через это переживает, он такой бардак.',
#   'Как ты это пережил? лега?',
#   'Вы действительно ее часы сломали?',
#   'Что?.',
#   'Что, ты хочешь объяснить это лапшой?',
#   'Ну что, будет пятое свидание?',
#   'Да, да, думаю, есть.',
#   'Что ты собирался сказать?',
#   'О боже, о боже, прости, прости.',
#   'Плевать, наверное, сейчас не то, что тебе нужно.',
#   'Гм, как долго?',
#   'Ух ты!',
#   'Я рада, что ты разбил ей часы!',
#   'Ага.',
#   'Да, люблю.',
#   'Прошлой ночью я отлично провел время.',
#   'Поговорим позже.',
#   'Заткнись и верни мне столик.',
#   'Да, у всех есть работа.',
#   'Видите, вот как мы покупаем вещи.',
#   'Погодите, если только вам не довелось увидеть постановку "Пиноккио" Рерунов.',
#   'Как у тебя сегодня дела?',
#   'Вы хорошо спали?',
#   'Поговорите с Барри?',
#   'Я не могу перестать улыбаться.',
#   'Я знаю, он такой, так что.',
#   'Ты помнишь тебя и Тони ДеМарко?',
#   'Ну это так.',
#   'С чувствами.',
#   'Хорошо.',
#   'Хорошо.',
#   'Я просто собираюсь встать, пойти на работу и не думать о нем весь день.',
#   'Или я просто встану и пойду на работу.',
#   'Зачем?',
#   'С возвращением!',
#   'Как было во Флориде?',
#   'Как ты это делаешь?',
#   'Вы знаете Павла?',
#   'Вы хотите сказать, что знаете Пола так же, как я?',
#   'Почему?!',
#   'Почему?',
#   'Почему, зачем кому-то такое делать?',
#   'Это я?',
#   'Это похоже на то, что у меня есть какой-то маяк, который могут слышать только собаки и люди с серьезными эмоциональными проблемами?',
#   'Я просто подумала, что он милый, понимаешь?',
#   'Как вы за них заплатили?',
#   'А кто за это платит?',
#   'Да ладно, ты не можешь жить на родителей всю жизнь.',
#   'Готовы?',
#   'Добро пожаловать в реальный мир!',
#   'Это отстой.',
#   'Тебе это понравится!',
#   'Ну вот и все.',
#   'Все в порядке?',
#   'Это часы Павла.',
#   'Вы просто кладете его туда, где нашли.',
#   'О, парень.',
#   'Хорошо.',
#   'Всем спокойной ночи.',
#   'Увидимся.',
#   'Погодите, что с вами?',
#   'Что?',
#   'Я сказал, что у вас.',
#   'Вы бы остановились?',
#   'Вы, ребята, не понимаете, что для нас поцелуй так же важен, как и любая его часть.',
#   'Совершенно верно.',
#   'Вы с этим справились?',
#   'Чей это бумажник?!',
#   'Слушайте, извините, ребята, я просто не хочу давать им боеприпасов больше, чем у них есть.',
#   'Потому что, что касается моих родителей, Росс не может ошибаться.',
#   'Понимаете, он принц.',
#   'Видимо, перед моим рождением у них была большая церемония.',
#   'Что?',
#   'Easy Rach, мы его найдем.',
#   'Не так ли!',
#   'Не злились.',
#   'Я дал вам одну работу!',
#   'Я просто, не могу этого сделать.',
#   'Ух ты.',
#   'Это не счастливый привет.',
#   'Ww-wh.',
#   'wha.',
#   'www.',
#   'Что она подразумевает под "вовлеченной"?',
#   'Карри.',
#   'Прости, почему эта девочка мне звонит?',
#   'Нет, мама, у меня ресторана нет, я работаю в ресторане.',
#   'Росс, не могли бы вы прийти и помочь мне со спагетти, пожалуйста?',
#   'Я знаю, это прозвучит невероятно эгоистично, но вы планировали поднимать вопрос о детях и лесбиянках?',
#   'Потому что я думаю, это может отнять у меня немного тепла.',
#   'Что это значит?',
#   'Нет, это не так.',
#   'Итак, Росс, что с тобой происходит?',
#   'Есть истории?',
#   'Нет новостей, нет анекдотов, которыми можно поделиться с людьми?',
#   'Мальчик, я знаю, они говорят, что ты не можешь изменить своих родителей, мальчик, если бы ты мог.',
#   'Я бы хотел твоих.',
#   'Чендлер, ты ведь единственный ребенок?',
#   'У тебя этого нет.',
#   'Мммм.',
#   'Нет.',
#   'Нет!',
#   'Да заткнись!',
#   'Угу, нет.',
#   'В вольном переводе "Мы должны сделать это снова" означает "Ты никогда не увидишь меня голым".',
#   'Эээ, Росс.',
#   'Нет, нет, нет.',
#   'Говорят, это то же самое, что и расстояние от кончика большого пальца парня до кончика указательного пальца.',
#   'Что они с тобой сделали?',
#   'Мы с тобой.',
#   'Мы сделали это.',
#   'Привет.',
#   'Что ты делаешь?',
#   'Хорошо.',
#   'Я пойду переодеться, у меня свидание.',
#   'Все хорошо, понимаешь?',
#   'Это хорошо, и мы весело проводим время.',
#   'Посмотрим, сегодня понедельник.',
#   'Никогда.',
#   'Нет.',
#   'Не после того, что случилось со Стивом.',
#   'Послушайте, я еще даже не знаю, как к нему отношусь.',
#   'Просто дай мне шанс разобраться в этом.',
#   'Нет.',
#   'Шорри.',
#   'В смысле, почему я должна позволять им встречаться с ним?',
#   'Я имею в виду, я привожу парня домой, и через пять минут они все вокруг него.',
#   'Я имею в виду, они похожи на койотов, отстреливающих слабых членов стада.',
#   'Знаю.',
#   'Я просто хочу, чтобы однажды я привел домой парня, который им действительно понравился.',
#   'Вы все обещаете?',
#   'Чендлер?',
#   'Вы обещаете быть хорошим?',
#   'Привет.',
#   'Это он.',
#   'Кто это?',
#   'Хорошо, пожалуйста, будьте добры, пожалуйста.',
#   'Просто помните, как сильно я вам нравлюсь.',
#   'Привет.',
#   'Алан, это все.',
#   'Все, это Алан.',
#   'Спасибо.',
#   'Я позвоню тебе завтра.',
#   'Хорошо.',
#   'Ладно, давайте начнем избиение Аланов.',
#   'Кто сделает первый выстрел, а?',
#   'Давай!',
#   'Погодите!',
#   'Мы говорим о ком-то, с кем я встречаюсь?',
#   'Действительно!',
#   'Привет, как игра?',
#   'Потрясающе!',
#   'У меня один вопрос: как это возможно?',
#   'Могу я задать вам вопрос?',
#   'Вы когда-нибудь думали, что Алан может быть, иногда.',
#   'Незнаю, Алан тоже немножко?',
#   'А почему это несправедливо?',
#   'Вы когда-нибудь встречались с парнем, который очень нравился вашим друзьям?',
#   'Ладно.',
#   'Ну, я иду гулять с парнем, который очень нравится моим друзьям.',
#   'Вы можете в это поверить?.',
#   'Знаешь что?',
#   'Я просто не чувствую этого.',
#   'Я имею в виду, они это чувствуют, а я не чувствую.',
#   'Я знаю, будет очень тяжело.',
#   'Нет, с ним все будет хорошо.',
#   'Меня беспокоят остальные пять.',
#   'Привет.',
#   'Где Джои?',
#   'Спасибо.',
#   'Ничего.',
#   'Я просто думаю, что это хорошо, когда мы все здесь вместе.',
#   'Хорошо.',
#   'Ребята, давайте поговорим.',
#   'Хорошо, поговорим.',
#   'Хорошо.',
#   'Это об Алане.',
#   'Вы должны кое-что знать.',
#   'Я имею в виду, что на самом деле нет простого способа сказать это, э-э.',
#   'Я решил расстаться с Аланом.',
#   'Нет, нонононо, просто, все меняется.',
#   'Люди меняются.',
#   'Слушай, я- я могу продолжать притворяться.',
#   '- Но это было бы несправедливо по отношению ко мне, это было бы несправедливо по отношению к Алану- Это было бы несправедливо по отношению к тебе!',
#   'Прости.',
#   'Я еще с кем-нибудь встречусь.',
#   'Будут другие аланы.',
#   'Ребята, с вами все будет хорошо?',
#   'Понятно.',
#   'Мне очень жаль.',
#   'С облегчением?',
#   'Привет.',
#   'А знаешь.',
#   'Он сказал, что очень будет по вам скучать, ребята.',
#   'Хорошо.',
#   'Фиби?',
#   'Эй, Джоуи, что бы ты делал, будь ты всемогущим?',
#   'Простите?',
#   'Как она это делает?',
#   'Вы бы на нее посмотрели?',
#   'Она такая мирная.',
#   'Что с тобой творится?',
#   'Что ж, если хочешь, можешь остаться сегодня с Рэйчел и мной.',
#   'Ой, я надеялся, что ты не вспомнишь.',
#   'Ого, вы работали на шахте?',
#   'Да, да.',
#   'Клянусь, я видел, как птицы делали это в "Диком Королевстве".',
#   'Привет, Рэйч.',
#   'Как было с друзьями?',
#   'Хорошо!',
#   'Хотели бы вы Tiki Death Punch?',
#   'Ну, это ром, и.',
#   'Мы думали, раз уж Фиби осталась ночевать, у нас будет что-то вроде пижамной вечеринки.',
#   'У нас есть какие-то дрянные журналы, у нас есть тесто для печенья, у нас есть Твистер.',
#   'Эээ, Рэйч, это люди карты Visa.',
#   'Скажите, пожалуйста, о чем идет речь?.',
#   'Да, подожди.',
#   'Гм, они говорят, что в вашем аккаунте была необычная активность.',
#   'Это необычная деятельность.',
#   'Слушай, они просто хотят увидеть, в порядке ли ты.',
#   'Э-э…',
#   'Рэйчел вышла из здания, можете перезвонить?',
#   'Ты должен чувствовать себя прекрасно!',
#   'Ты делаешь эту удивительную независимость!',
#   'А, другой Джек.',
#   'Ну и что, вы не один такой.',
#   'Я имею в виду, что половину времени мы не знаем, куда идем.',
#   'Тебе просто нужно подумать, что в какой-то момент все это соберется вместе, и это будет просто, непонятно.',
#   'Фибы?',
#   'Нет, вы были правы.',
#   'У меня нет плана.',
#   'Фиби?',
#   'У вас есть план?',
#   'Постой!',
#   'Вы сказали "Г. Стефанопулос"?',
#   'Постой, а это был невысокий средиземноморский парень с удивительно умной внешностью?',
#   'На нем был потрясающий синий костюм?',
#   'Боже.',
#   'С ума сойти?!',
#   'У нас есть пицца Джорджа Стефанопулоса!',
#   'Я вижу пиццу!',
#   'Советник Белого дома?',
#   'Парень из предвыборной кампании Клинтона?',
#   'Тот, с великолепными волосами, сексуальной улыбкой, действительно милой попкой?',
#   'Скажите, пожалуйста, это его мама.',
#   'Да нет.',
#   'Свет все еще не горит?',
#   'О. Может, они, дремлют.',
#   'Я думаю, он стесняется.',
#   'Ага.',
#   'Я думаю, тебе нужно его вытащить.',
#   'А потом - когда вы это сделаете - он опрятное животное.',
#   'Хорошо.',
#   'Хорошо, у меня есть один.',
#   'Вы помните тот вегетарианский паштет, который я приготовил, который вы так любили?',
#   'Ну, разве что гусь овощ, ха-ха!',
#   'Что?!',
#   'Вы переспали с Джейсоном?',
#   'Ой, как мило!',
#   'Простите?!',
#   'Действительно.',
#   'Ну хоть "большие девочки" в седьмом классе не писают в штаны!',
#   'Где?',
#   'Ой, Джордж, детка, урони полотенце!',
#   'Мог бы поиграть в "Монополию", но неет.',
#   'Кто-нибудь еще чувствовал, что он просто хотел снять кожу с тела, чтобы чем-то заняться?',
#   'Ну, иди к ней!',
#   'Она ни с кем.',
#   'Ты справишься!',
#   'Ну да, да.',
#   'Как прошло ваше свидание, ЧандИрр?',
#   'О. Мне жаль, что не получилось.',
#   'Вы не слушали рассказ?',
#   'Я имею ввиду, это скручено!',
#   'Как ты мог быть связан с такой женщиной?',
#   'Что?',
#   'Так вы, ребята, не против встречаться с кем-то еще, кто встречается с кем-то еще?',
#   'Молодец, Джоуи.',
#   'Мы шутим.',
#   'Давай, расскажи нам!',
#   'Ой!',
#   'Я вижу, вы переместили зеленую оттоманку.',
#   'Как-как это случилось?',
#   'Да, да, интересно, ну знаете что?',
#   'Ради интереса, давайте посмотрим, как это выглядело на старом месте.',
#   'Хорошо, просто для сравнения.',
#   'Посмотрим.',
#   'Что ж, там тоже неплохо смотрится.',
#   'Давай просто оставим это на время.',
#   'Ребята, я не такой уж плохой!',
#   'Это так несправедливо!',
#   'Хорошо, я ответственен, я организован.',
#   'Но эй, я могу быть чудаком.',
#   'Почему бы и нет?',
#   'Могу.',
#   'Зачем кому-то это делать?!',
#   'Можно задаться вопросом.',
#   'ОСТАНОВИТЬ!Боже мой.',
#   'Это правда!',
#   'Кто я?',
#   'Ну что за роль?',
#   'Боже мой.',
#   'Хорошо, хорошо, хорошо.',
#   'За что?',
#   'Боже мой.',
#   'Ладно, иди в ванную, используй все, что хочешь, только никогда не говори мне, что ты там делал.',
#   'Он в ванной.',
#   'Я не думаю, что ты хочешь туда пойти!',
#   'Я вас предупреждал.',
#   'А у тебя всю ночь есть, а?',
#   'Конечно.',
#   'О, ммм, Чендлер?',
#   'Понимаешь, старая Моника напомнила бы тебе, чтобы ты протирал тефлоновую сковороду пластиковой щеткой.',
#   'Но я не собираюсь этого делать.',
#   'Эй, погоди, ты что, не тот парень, который играет задницу в новом фильме Аль Пачино?',
#   'Может быть, это был не твой выстрел.',
#   'Прости, Джоуи.',
#   'Я пойду спать, ребята.',
#   'Угу!',
#   'Да ладно, завтра куплю.',
#   'Или нет.',
#   'В любое время.',
#   'Если это вас так сильно беспокоит, просто выйди и купи туфли.',
#   'Нет, не делай этого.',
#   'Это глупо!',
#   'Мне не нужно ничего доказывать, я пойду за ними.',
#   'Но тогда все узнают.',
#   'Если только я их не получу, а потом проснусь очень рано и верну обратно!Мне нужна помощь!',
#   'Мама говорит, что это весь Манхэттен, части Бруклина и Квинса, и они понятия не имеют, когда он вернется.',
#   'Штаны и свитер, зачем маме, кого я встречу в блэкаут, парней из энергокомпании, подходящих мародеров, мы можем поговорить об этом позже?',
#   'ОК.',
#   'Здравствуйте.',
#   'Это Чендлер.',
#   'Ты в порядке?',
#   'Что?',
#   'Понятия не имею, что вы только что сказали.',
#   'Хорошо, пойду, пойду.',
#   'Окей, выпускник колледжа, на бильярдном столе!',
#   'Боже мой, что ты делал в библиотеке?',
#   'Вы не пошли, пошли.',
#   'Давай, расскажи.',
#   'Снаружи.',
#   'Почему бы и нет?',
#   'А что бы было?',
#   'Джоуи, что творится?',
#   'О чем?',
#   'Боже мой, я люблю его.',
#   'Моя вечеринка-сюрприз!',
#   'Ой, хватит!',
#   'Джои мне уже сказал.',
#   'Да нет, мы вам кое-что рассказываем.',
#   'Да, это просто Бактина, это не повредит.',
#   'Привет.',
#   'Привет.',
#   'Привет.',
#   'Хочешь, сделаю.',
#   'Спасибо!',
#   'Whoa ar ar ar.',
#   'Да.',
#   'Ладно, я-то знаю, ты-ты просто-у тебя качество есть.',
#   'Здравствуйте?',
#   'Привет?',
#   'Ой!',
#   'Рэйчел, это Паоло звонит из Рима.',
#   'Привет, папа, как дела?',
#   'О Боже.',
#   'Росс, это Нана.',
#   'Как дела, мама?',
#   'Что?',
#   'Ничего.',
#   'Она невероятная, наша мама.',
#   'Боже!',
#   'Пушистые мятные конфеты на дне сумочки.',
#   'Знаю.',
#   "G'bye, Nana.",
#   'Росс!',
#   'Мы проверили.',
#   'Много.',
#   'Папа!',
#   'Ты что?',
#   'Определите веселье.',
# ...
#   'Нет, достаточно просто знать, что ты будешь.',
#   'Ты поцеловал моего лучшего Росса!Или что-то в этом роде.',
#   'Действительно глупо.',
#   'Ага.',
#   'Нет.',
#   'Нет.',
#   'Да ладно.',
#   'Отличный сейв.',
#   'Привет.',
#   'А почему бы и нет.',
#   'Я сказал ей.',
#   'Ужасно.',
#   'Ужасный.',
#   'Хуже не могло быть.',
#   'Неплохо!',
#   'Я сказал ей.',
#   'Нет-нет-нет, мы закончили.',
#   'И с йогуртом покончено.',
#   'Ах, это просто выходные, большое дело!',
#   'Хорошо, тебе придется прекратить это навсегда!',
#   'Думаешь?',
#   'Ладно, значит, я должен купить новый только потому, что это был мой стол?',
#   'Какое правило?',
#   'Нет никаких правил, если уж на то пошло, ты должен мне столик!',
#   'Думаю, мебель была в порядке до твоего маленького приключенческого завтрака с Анжелой Дельвеккио.',
#   'Ну, скажем так, впечатления, сделанные вами на масле, мало что оставили воображению.',
#   'Что значит покупать вместе?',
#   'Думаешь, мы готовы к чему-то в этом роде?',
#   'Ну, это большое, это довольно большое обязательство, я имею в виду, что, если кто-то из нас захочет съехать?',
#   'Я не уезжаю.',
#   'Да, да, это то же самое с моим последним соседом по комнате Кипом.',
#   'Просто мы вместе купили хибачи, а потом он сбежал и женился, и все стало довольно некрасиво.',
#   'Ой, не делай этого.',
#   'Хорошо.',
#   'Еще кофе, пожалуйста!',
#   'И что ты собираешься делать?',
#   'О да, ты должен ей сказать.',
#   'Это садовая мебель!',
#   'Выбери одну.',
#   'Да ну, забудьте о птицах, но большие красные насекомые говорят о высокой кухне!',
#   'Не так, не буду!',
#   'Кипу бы понравились птицы!',
#   'Так что ты думаешь?',
#   'Знаю!',
#   'Что ты еще здесь делаешь?',
#   'Она только что рассталась с парнем, тебе пора налетать!',
#   'Мой друг-католик прав.',
#   'Она обезумела.',
#   'Ты рядом с ней.',
#   'Вы собираете осколки, и тогда вы вступаете в эпоху Росса!',
#   'Wha.',
#   'Привет!',
#   'Ага - уходи!',
#   'Еще одна игра?',
#   'Аааааа!',
#   'Мне жаль!',
#   'Мне жаль!',
#   'Прости!',
#   'Рэйчел.',
#   'Подожди подожди.',
#   'Могу я сказать одно?',
#   'Это относительно открытое плетение, и я все еще могу видеть, твои области сосков.',
#   'О да.',
#   'Могу ли я получить один из этих.',
#   'Ладно.',
#   'Нет.',
#   'Она все еще расстроена, потому что я видел ее олухи!',
#   'Это был несчастный случай.',
#   'Не то чтобы я был через улицу с телескопом и коробкой пончиков!',
#   'Знаешь, знаешь, я не знаю, почему ты так смущен.',
#   'Это были классные олухи.',
#   'Ладно.',
#   'Рок.',
#   'Твердое место.',
#   'Я!',
#   'Ого.',
#   'Ого.',
#   'Поднимитесь туда, Спарки.',
#   'Что вы имели в виду?',
#   'Ага.',
#   'Угу.',
#   'Откуда ты знал это?',
#   'Что?.',
#   'Что?',
#   'Знаешь, я этого не вижу.',
#   'Я не показываю тебе тату!',
#   'О, хорошо.',
#   'Рог здесь!',
#   'Да ничего.',
#   'Это просто мелочь.',
#   'Я ненавижу этого парня!',
#   'Послушайте, это та женщина, которую мы заказали.',
#   'Эээ, у Джои эмболия, но я бы пошел на закуску, понимаете.',
#   'Джоуи, если я пойду первым, я хочу искать свои ключи.',
#   'Итак!',
#   'Кто готов к большой игре в Ker-Plunk?',
#   'Давай, я покажу тебе свою комнату.',
#   'Это звучит так странно, когда за ним не следует "Нет, спасибо, уже поздно".',
#   'Привет!',
#   'Здорово!',
#   'Что делаешь?',
#   'Ну, ты собираешься!',
#   'Они встают впритык или высокие, как блины?',
#   'Эй, ты не он, ты сам.',
#   'Когда они были повсюду, чтобы заняться бизнесом вашего отца по арматуре труб, вы уступили?',
#   'Нет.',
#   'Вы решили заняться неработающим актерским бизнесом.',
#   'Это было непросто, но вы сделали это.',
#   'И мне хотелось бы верить, что когда появится подходящая женщина, у вас хватит смелости и смелости сказать: "Нет, спасибо.',
#   'Я женат".',
#   'Ага.',
#   'Я действительно так делаю.',
#   'Выходи!',
#   'Что-что?',
#   'Извини.',
#   'Моя вещь была там со мной!',
#   'Ага.',
#   'В основном мы просто чувствуем, что он.',
#   'Конечно, здесь, на горе Уолтон, все изменилось.',
#   'Если я стану родителями, то либо буду блондинкой-алкоголичкой, гоняющейся за двадцатилетними мальчиками, либо закончу, как моя мама!',
#   'Есть контакты?',
#   'Давай, Росс, тебе нужно вернуться в игру, хорошо?',
#   'Рэйчел не происходит, твоя бывшая жена лесбиянка - я не думаю, что нам нужна третья.',
#   'Думаю, это победа.',
#   'Ей это понравится.',
#   'Иди с яйцом, друг мой.',
#   'Нет, это самоубийство.',
#   'У мужчины есть яйцо.',
#   'Ой, послушай, примерно сегодня вечером.',
#   'Да, я знаю, но ее подруга звучит так.',
#   'Да!',
#   'Так держать, чувак!',
#   'Яйцо все еще есть, а?',
#   'Ой, мне все равно.',
#   'Хорошо, теперь помните, никакой торговли.',
#   'Ты получишь симпатичную, а я - беспорядок.',
#   'А что вы принесли?',
#   'Хорошо, я делаю перерыв, я выхожу в окно.',
#   'Прости, прости, ты прав.',
#   'Давай, сделай это, сделай это, давай, давай!',
#   'Ничего страшного.',
#   'Что?',
#   'Что ты не умеешь делать?',
#   'Скажи мне, что это мы "ты и я".',
#   'Ладно, ты не можешь со мной этого делать.',
#   'Надеюсь, тебя вырвет.',
#   'Итак.',
#   'Ах, какая дерьмовая ночь!',
#   'Простите.',
#   "Как у тебя дела'?",
#   'Джоуи мне не друг.',
#   'Он, глупый человек, который оставил нам свою кредитную карту.',
#   'Еще выпить?',
#   'Какой-нибудь десерт?',
#   'Телевизор с большим экраном?',
#   'Понял.',
#   'Хорошая женщина, можно нам бутылку вашего шампанского по завышенной цене?',
#   'Правильно, каждый.',
#   'Ах да, Роб Рой.',
#   'Всегда хотел знать.',
#   'Нет, нет!',
#   'И все же это произошло.',
#   'До свидания, Дженис.',
#   'Ладно, это было особенное.',
#   'Дженис сейчас уходит.',
#   'Хорошо, теперь Джои дома.',
#   'Как я могу бросить эту женщину в День святого Валентина?',
#   'Ой, мужик.',
#   'В следующей жизни я вернусь в качестве ершика для унитаза.',
#   'Привет, Дженис.',
#   'Он загружен?',
#   'О, маленькие конфетные сердечки.',
#   'Чан и Ян навсегда.',
#   'Хорошо, Дженис.',
#   'Дженис.',
#   'Привет, Дженис.',
#   'Послушайте, у меня нет возможности сказать вам это, по крайней мере, у меня нет нового способа сказать вам это.',
#   'Просто у меня ничего не получится.',
#   'Это?',
#   'О нет, правда.',
#   'Нет, не знаю.',
#   'Да, но.',
#   'Позвони мне!',
#   'Это невероятно.',
#   'Прошло около получаса.',
#   'Если бы это был мультфильм, вы бы сейчас выглядели как ветчина.',
#   'Это Фиби!',
#   'Привет!',
#   'Подожди, подожди!',
#   'Ч-что ты здесь делаешь?',
#   'Можно начать сначала?',
#   'Хорошо, а теперь посмотри на нее и скажи мне, что она не совсем похожа на свою сестру.',
#   'Они близнецы!',
#   'Ты знаешь это, когда мы с тобой разговариваем о разных вещах.',
#   'Давай больше не будем этого делать.',
#   'Твоя сестра Урсула.',
#   'Да, да, она работает в том месте.',
#   'Ага?',
#   'Потому что она сказала, что вы, ребята, не разговаривали столько лет.',
#   'Да, еще у меня есть Науки о Земле, но я поймаю тебя в спортзале.',
#   'И тебе, Хелен.',
#   'Ладно.',
#   'Пошлите ее.',
#   'Привет, Нина.',
#   'Заходите.',
#   'Да, да.',
#   'Да.',
#   'Я только что просмотрел ваши данные здесь, и мелочь, вы после датирования своих пятничных чисел.',
#   'Ну, это выводит мой ВЕНУС из строя.',
#   'ВЕНУС.',
#   'Еженедельная расчетная статистика чистого использования.',
#   'Дело не только в том, что она милая, ладно.',
#   'Просто она действительно очень милая.',
#   'Так скажи мне кое-что, оставление рождественских огней - часть твоего плана, чтобы мы веселились круглый год?',
#   'Эй, где ты был?',
#   'Оценка.',
#   'Ага, послушай.',
#   'Прежде чем вы сделаете что-нибудь в духе Джоуи, вы могли бы пробежаться по этому.',
#   'Мистер Д, как дела, сэр?',
#   'А?',
#   'Так что это значит?',
#   'Эй, послушай, я знаю, что пришел в конце прошлой недели, но спал смешно, а волосы у меня были очень-очень.',
#   'Нина?',
#   'Нина.',
#   'Нина.',
#   'Нина.',
#   'Да, да.',
#   'Послушайте, причина, по которой я позвал вас сюда сегодня, это, пожалуйста, не ненавидьте меня.',
#   'Хочешь как-нибудь поужинать?',
#   'Ну, вы еще не погасили рождественские гирлянды.',
#   'Я просто пытаюсь найти подходящий момент, понимаете?',
#   'Знаете, как только вы окажетесь внутри, вам больше не придется стучать.',
#   'Ого, это серьезно.',
#   'Я никогда не видел, чтобы вы платили деньги за какой-либо капад.',
#   'Вяжите, умница, вяжите, вяжите!',
#   'А вот и Крайслер-билдинг.',
#   'Да-да.',
#   'Разве я не напомнил тебе об этом?',
#   'Видите ли, после того, как я ее отпустил, мне позвонили ее психиатр, доктор Фл, доктор Фланен, доктор Флан, и он сообщил мне, что она довольно плохо восприняла эту новость.',
#   'Фактически, он упомянул слово "безумие".',
#   'О нет, нет.',
#   'Нина - она-у-у-у-у-у.',
#   'На самом деле, если бы вы спросили ее прямо сейчас, она бы вообще не помнила, чтобы ее уволили.',
#   'И все же правдоподобно.',
#   'Поэтому я решил не увольнять ее снова, пока я не буду уверен, что она не будет угрозой ни себе, ни другим.',
#   'Ну, наверное, поэтому они называют это психологией, сэр.',
#   'Знаешь, Росс, некоторые ученые сейчас говорят, что обезьяны и младенцы на самом деле разные.',
#   'Ну конечно, Нина.',
#   'Как дела?',
#   'Ну, может, это потому, что они завидуют нам.',
#   'Ну, может, это потому, что ты получаешь большое прибавление.',
#   'Конечно, а почему бы и нет?',
#   'Вы не знаете.',
#   'Хелен, не могли бы вы удостовериться, что мы оформим документы о повышении мисс Букбиндер?',
#   'Хелен пьет.',
#   'Ты выйдешь за меня?',
#   'Ну, я ей все рассказал.',
#   'Хорошо.',
#   'За исключением степлера.',
#   'Небольшой совет: если вы когда-нибудь окажетесь в подобной ситуации, никогда не кладите руку на стол.',
#   'Ты его не потеряешь.',
#   'Что ты с ума сошел?',
#   'Это ребенок!',
#   'Эй, у тебя все будет хорошо.',
#   'Вы один из самых заботливых и ответственных мужчин в Северной Америке.',
#   'Из тебя получится отличный папа.',
#   'Ну, только если заказывать.',
#   'Вот оно!',
#   'Так что ты собираешься делать?',
#   'А твоя подруга Фиби?',
#   'Чувак, если бы ты попробовал что-то подобное в мой день рождения, ты бы оказался в самом конце шипящего припадка.',
#   'Хорошо, что мы узнали на данный момент?',
#   'С днём рождения, Пии.',
#   'Вы видели Бетти?',
#   'Ладно, худший вариант.',
#   'Скажи, что никогда не чувствуешь себя отцом.',
#   'Скажите, что ваш сын никогда не чувствует себя связанным с вами как единое целое.',
#   'Скажем, это повлияло на все его отношения.',
#   'Знаешь, ты думаешь, я бы стал.',
#   'Что случилось с обезьяной?',
#   'Хорошо, а кто теперь?',
#   'Нет-нет, ты получил ноль баллов за "idney".',
#   'Марсель проглотил плитку Эрудита.',
#   'Мы думаем, он пытался объяснить "обезьяна".',
#   'Значит, ты еще не чувствуешь себя папой?',
#   'Эй, давай, ты прошел, ты сделал то, что должен был сделать.',
#   'Это очень папа.',
#   'Pudo haber sido el General Tso.',
#   'Вот и все!',
#   'Они ведь еще друзья?',
#   'Вы знаете, я не могу поверить, что мы вообще обсуждаем это.',
#   'Я имею в виду, ты не думаешь, что если бы что-то случилось с Рэйчел, они бы уже произошли?',
#   'Я не могу вспомнить, когда в последний раз я заставлял девушку позаботься о моей обезьяне.',
#   'Привет.',
#   'Вы знаете, что вам следует делать?',
#   'Вам следует вернуть ее в 1890-е годы, когда эта фраза использовалась в последний раз.',
#   'Рэйчел потеряла Марселя.',
#   'Ладно.',
#   'Это его первый визит, так что он, вероятно, захочет заняться туристическими делами.',
#   'Я пойду в Cats, а вы - в русскую чайную.',
#   'Марсель?',
#   'Марсель?',
#   'Эээ, у нас вроде как чрезвычайная ситуация, и мы… ээ… что-то искали.',
#   'Да.',
#   'Вы что-нибудь видели?',
#   'Ой, нет, подожди, нет, подожди, подожди.',
#   'Эээ, мы можем ничего не знать о радиаторах, как таковых, но у нас есть определенный опыт в области отопления и охлаждения.',
#   'Да, но эти женщины очень горячие, и им нужна наша помощь.',
#   'И они очень горячие!',
#   'Ладно.',
#   'С этого момента вы не можете разговаривать с другими людьми.',
#   'Марсель!',
#   'Вау.',
#   'Я думал, что это был алп!',
#   'Да, я ходил в школу-интернат с четырьмя сотнями мальчиков.',
#   'Любой секс, который у меня был, предполагал d главный выбор образа жизни!',
#   'Не могу поверить, что ты действительно так скажешь.',
#   'Я бы сильно.',
#   'Я чувствую себя оскорбленным.',
#   'И не в хорошем смысле.',
#   'Говорю тебе, через годы школьники будут.',
#   'Дай ей знать Я как она?',
#   'Ты что, ненормальный?',
#   'ДЕВУШКИ.',
#   'Что, кстати, настоящее угощение СанФранциско.',
#   'ЗВОНИТЕ.',
#   'Нет, что интересно, ее воздуходувка подняла.',
#   'О, нет, нет, нет.',
#   'В прошлый раз я оставил спонтанное сообщение.',
#   'По сути, так законопроект становится законом.',
#   'Привет, Рэйч!',
#   'Да!',
#   'У меня есть причины.',
#   'Ой, Даниэль!',
#   'Я не был.',
#   'Эй, я затачивал!',
#   'Ой.',
#   'Я хочу, чтобы она подумала, что я, наверное, в ресторане.',
#   'Что ты на меня смотришь?',
#   'Я этого не знал.',
#   'Могу я воспользоваться твоим телефоном?',
#   'Да, работает!',
#   'Почему она мне не перезванивает?',
#   'Не думаю, что это заставляет меня казаться немного.',
#   'А, вы явно видели мою личную рекламу.',
#   'Она ответила.',
#   'Я не буду с ней разговаривать, она, очевидно, получила мое сообщение.',
#   'Если это поможет, я могу соскользнуть.',
#   'Привет?',
#   'Привет?',
#   'Так как Минди?',
#   'В аду полно таких людей, как ты.',
#   'И буги!',
#   'Хорошо, я пойду в ванную.',
#   'Будете смотреть.',
#   'Эй, у нас не было второго свидания, ей нужно.',
#   'Я не могу ей позвонить, я оставил сообщение!',
#   'У меня есть гордость.',
#   'Нет!',
#   'Даниэль, привет!',
#   'Это, это Чендлер!',
#   'Мне.',
#   'Почему я танцую.',
#   'Кольцо, черт возьми, кольцо!',
#   'Что?!',
#   'Я выключил.',
#   'Богородица, мне исполнилось.',
#   'Ннгххх!',
#   'Даниэль!',
#   'Привет!',
#   'Эээ, все, это Даниэль, Даниэль, Что ты здесь делаешь?',
#   'Я, я в порядке.',
#   'Звучит неплохо.',
#   'Я тебе позвоню - или ты позвонишь мне, как угодно.',
#   'Хорошо.',
#   'Не знаю.',
#   'Ну, она вроде очень милая и все такое, но все это.',
#   'Ого, какой выродок.',
#   'Они потратили 69,95 доллара на швабру Wonder Mop.',
#   'Ну, вот что мы сказали про Джоуи.',
#   'А как насчет Джои.',
#   'Пеппони?',
#   'Джоуи.',
#   'Швейцария?',
#   'Джо.',
#   'Джо.',
#   'Джо.',
#   'Сталин?',
#   'Ну, мне это не звонит.',
#   'Может, попробуем Джозефа.',
#   'О да!',
#   'Пока, Берди, в главной роли Иосиф Сталин.',
#   'Иосиф Сталин - скрипач на крыше.',
#   'Она ведь не заставит тебя надеть один из тех больших пластиковых конусов?',
#   'Так что это значит?',
#   'Я не понимаю, я имею ввиду, ты только что его поймала.',
#   'Как он может быть уже взрослым?',
#   'Я знаю этого!',
#   'Нет, это Папа в Фольксваген.',
#   'Да, но это где-то в двух кварталах от пляжа.',
#   'Я имею в виду, это настоящий зоопарк для вечеринок.',
#   'Что?',
#   'Ага.',
#   'Ваш собственный бренд линчевателя правосудия.',
#   'Снимите шляпы!',
#   'Ты шутишь.',
#   'Знаешь, ты думаешь, я бы так и поступил.',
#   'Он пришел.',
#   'Ладно, пока, чемпион.',
#   'Я знаю, что в СанДиего будет много малышек, но помни, есть чему поучиться.',
#   'Что?',
#   'Ну давай, расскажи.',
#   'Я мог бы использовать другую причину, почему женщины не смотрят на меня.',
#   'Ух ты!',
#   'Что еще важнее, я был хорош?',
#   'Интересно, потому что в моих снах я всегда на удивление неадекватен.',
#   'С тобой все в порядке?',
#   'Извините, это было разовое мероприятие.',
#   'Я был очень пьян и был чужим подсознанием.',
#   'Привет, Рэйчел.',
#   'Опять пираты?',
#   'Спасибо, Джоуи, это хорошая идея.',
#   'Ну, моя секретарша уезжает на пару недель.',
#   'У нее уменьшилась одна из ее грудей.',
#   'Это целая история с большими сиськами.',
#   'Ну, ты же знаешь Фибса.',
#   'Я не знаю, нравится ли это тебе, потому что это требует большого количества нормального поведения.',
#   'На большую часть дня.',
#   'Классный номер телефона и возможное имя для ребенка.',
#   'Когда были?',
#   'А у этого ребенка нет проблем с тем, сколько тебе лет?',
#   'Вы это слышите?',
#   'Смотри, это прекратится, когда ты возьмешь трубку.',
#   'Я не на встрече.',
#   'Я прав.',
#   'Упс.',
#   'Что?',
#   'А!',
#   'Ну, теперь мне пора работать.',
#   'Хорошо.',
#   'Пока-пока.',
#   'Ой.',
#   'Видишь ли, стоит узнать человека, который носит мои туфли.',
#   'Мне.',
#   'Почему нет?',
#   'Что?',
#   'Нохо.',
#   'Почему я им не нравлюсь?',
#   'О чем ты говоришь?',
#   'Не могу в это поверить.',
#   'Меня?',
#   'Не похоже.',
#   'Ладно, я так не говорю.',
#   'Это совсем не так.',
#   'Это не так.',
#   'Это не так.',
#   'Это.',
#   'Ой, заткнись!',
#   ...]}

# %%
import pandas as pd
import numpy as np
from tqdm import tqdm

tqdm.pandas()

# %%
data = [[], []]

for name in RUSSIAN_NAMES:
    data[0].extend([name] * len(SENTS_BY_NAME[name]))
    data[1].extend(SENTS_BY_NAME[name])

columns = ['Character', 'Phrase']
df_ = pd.DataFrame(data, index=columns).T
# df_ = df_[df_.Phrase.apply(lambda x: len(x.split()) > 3)]
df_.shape
# Out:
# (85356, 2)

# %%
df = df_.sample(frac=1).reset_index(drop=True)
df
# Out:
#       Character                                             Phrase
# 0        МОНИКА                               Хорошо, я тебя знаю.
# 1          РОСС                                            Мне 29.
# 2          ФИБИ                               О. Ой, Боже, это он!
# 3       ЧЕНДЛЕР                                               Ага!
# 4        РЕЙЧЕЛ                                      Привет, Фиби!
# ...         ...                                                ...
# 85351     ДЖОУИ  Погодите, прежде чем вы мне скажете, что это т...
# 85352      РОСС   Тебя взволновала твоя первая ночь вдали от Эммы?
# 85353     ДЖОУИ        Это было так круто, когда я был там раньше.
# 85354      ФИБИ                                                Ох.
# 85355      РОСС  Я думал, вы согласны с тем, что они просили у ...
#
# [85356 rows x 2 columns]

# %% [markdown]
# # Preprocessing

# %%
# !pip install natasha pymorphy2
# Out:
# Collecting natasha
#   Downloading natasha-1.4.0-py3-none-any.whl (34.4 MB)
#      |████████████████████████████████| 34.4 MB 31 kB/s
# Collecting pymorphy2
#   Downloading pymorphy2-0.9.1-py3-none-any.whl (55 kB)
#      |████████████████████████████████| 55 kB 4.4 MB/s
# Collecting yargy>=0.14.0
#   Downloading yargy-0.15.0-py3-none-any.whl (41 kB)
#      |████████████████████████████████| 41 kB 146 kB/s
# Collecting ipymarkup>=0.8.0
#   Downloading ipymarkup-0.9.0-py3-none-any.whl (14 kB)
# Collecting slovnet>=0.3.0
#   Downloading slovnet-0.5.0-py3-none-any.whl (49 kB)
#      |████████████████████████████████| 49 kB 7.0 MB/s
# Collecting razdel>=0.5.0
#   Downloading razdel-0.5.0-py3-none-any.whl (21 kB)
# Collecting navec>=0.9.0
#   Downloading navec-0.10.0-py3-none-any.whl (23 kB)
# Collecting intervaltree>=3
#   Downloading intervaltree-3.1.0.tar.gz (32 kB)
# Requirement already satisfied: sortedcontainers<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from intervaltree>=3->ipymarkup>=0.8.0->natasha) (2.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from navec>=0.9.0->natasha) (1.19.5)
# Requirement already satisfied: docopt>=0.6 in /usr/local/lib/python3.7/dist-packages (from pymorphy2) (0.6.2)
# Collecting pymorphy2-dicts-ru<3.0,>=2.4
#   Downloading pymorphy2_dicts_ru-2.4.417127.4579844-py2.py3-none-any.whl (8.2 MB)
#      |████████████████████████████████| 8.2 MB 46.4 MB/s
# Collecting dawg-python>=0.7.1
#   Downloading DAWG_Python-0.7.2-py2.py3-none-any.whl (11 kB)
# Building wheels for collected packages: intervaltree
#   Building wheel for intervaltree (setup.py) ... done
#   Created wheel for intervaltree: filename=intervaltree-3.1.0-py2.py3-none-any.whl size=26119 sha256=5d65c5f0717e0d1dba8d5db27252dfc5e4b21250f84fe3e7d539772ae20381c9
#   Stored in directory: /root/.cache/pip/wheels/16/85/bd/1001cbb46dcfb71c2001cd7401c6fb250392f22a81ce3722f7
# Successfully built intervaltree
# Installing collected packages: pymorphy2-dicts-ru, dawg-python, razdel, pymorphy2, navec, intervaltree, yargy, slovnet, ipymarkup, natasha
#   Attempting uninstall: intervaltree
#     Found existing installation: intervaltree 2.1.0
#     Uninstalling intervaltree-2.1.0:
#       Successfully uninstalled intervaltree-2.1.0
# Successfully installed dawg-python-0.7.2 intervaltree-3.1.0 ipymarkup-0.9.0 natasha-1.4.0 navec-0.10.0 pymorphy2-0.9.1 pymorphy2-dicts-ru-2.4.417127.4579844 razdel-0.5.0 slovnet-0.5.0 yargy-0.15.0

# %%
import numpy as np

# %%
import re
from natasha import (
    Segmenter,
    MorphVocab,
    
    NewsEmbedding,
    NewsMorphTagger,
    NewsSyntaxParser,
    NewsNERTagger,
    
    PER,

    Doc
)

import pymorphy2
morph = pymorphy2.MorphAnalyzer()

segmenter = Segmenter()
emb = NewsEmbedding()
ner_tagger = NewsNERTagger(emb)

def remove_by_indices(x, indices):
    new_str = ""
    curr_index = 0
    end = 0
    for start, end in indices:
        while curr_index < start:
            new_str += x[curr_index]
            curr_index += 1
        curr_index = end + 1
    new_str += x[end:]
    return new_str

def lemmatize(text):
    words = text.split() # разбиваем текст на слова
    res = list()
    for word in words:
        p = morph.parse(word)[0]
        res.append(p.normal_form)

    return res

def base_form(text: str) -> str:
    char_only = re.sub('[^а-яА-Я ]', '', text) 
    new_str = str(re.sub(' +', ' ', char_only))
    #print(new_str)
    doc = Doc(new_str)
    doc.segment(segmenter)
    doc.tag_ner(ner_tagger)
    #return new_str.strip()
    indices = []
    for span in doc.spans:
        if span.type == "PER":
            indices.append((span.start, span.stop))
    without_names = remove_by_indices(new_str, indices)
    new_str = str(re.sub(' +', ' ', without_names))
    lemmatized = ' '.join(lemmatize(new_str))
    return lemmatized.lower().strip()

text = "Миссис Уоллес, я доктор Дрейк Рамори, нейрохирург вашей сестры."
base_form(text)
# Out:
# 'я доктор нейрохирург ваш сестра'

# %%
df_["Base_Phrase"] = df_["Phrase"].progress_apply(base_form)
# Out:
# 100%|██████████| 85356/85356 [07:00<00:00, 202.84it/s]

# %%
df_
# Out:
#       Character  ...                                        Base_Phrase
# 0         ДЖОУИ  ...              да ладный ты встречаться с это парень
# 1         ДЖОУИ  ...                    с они должный быть чтоть не так
# 2         ДЖОУИ  ...                                             вместо
# 3         ДЖОУИ  ...                          никогда не видеть это сон
# 4         ДЖОУИ  ...        этот парень здороваться я хотеть убить себя
# ...         ...  ...                                                ...
# 85351   ЧЕНДЛЕР  ...  но что ещё важный изз контроль за арендный пла...
# 85352   ЧЕНДЛЕР  ...                                             ладный
# 85353   ЧЕНДЛЕР  ...                                    всё быть хорошо
# 85354   ЧЕНДЛЕР  ...                                            конечно
# 85355   ЧЕНДЛЕР  ...                                                где
#
# [85356 rows x 3 columns]

# %%
suspisious_phrases = set(df_["Base_Phrase"].value_counts()[df_["Base_Phrase"].value_counts() > 1].index)
len(suspisious_phrases)
# Out:
# 3543

# %%
phrase_to_character = dict()
to_del = set()

for index, row in df_.iterrows():
    phrase = row["Base_Phrase"]
    hero = row["Character"]
    if phrase in suspisious_phrases:
        if phrase in phrase_to_character:
            if hero not in phrase_to_character[phrase]:
                phrase_to_character[phrase].append(hero)
        else:
            phrase_to_character[phrase] = [hero]

phrase_to_character
# Out:
# {'смотреть': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'ты больно': ['ДЖОУИ', 'РЕЙЧЕЛ'],
#  'кто такой': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'подождать': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'что это': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'о чем ты говорить': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  '': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'поздравлять': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'добрый утро': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'РОСС', 'ЧЕНДЛЕР'],
#  'сомневаться': ['ДЖОУИ', 'ЧЕНДЛЕР'],
#  'не мочь поверить в то что я здесь слышать': ['ДЖОУИ', 'ФИБИ'],
#  'да верно': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'ты серьёзно': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'ЧЕНДЛЕР'],
#  'всегда': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС'],
#  'ага': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'спасибо': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'что': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'ух ты': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'привет': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'пропустить': ['ДЖОУИ', 'ЧЕНДЛЕР'],
#  'это смешно': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'РОСС', 'ЧЕНДЛЕР'],
#  'хорошо': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'давать росс': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'ЧЕНДЛЕР'],
#  'он здесь': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'РОСС'],
#  'что происходить': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'о бог': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'и всё': ['ДЖОУИ', 'МОНИКА'],
#  'всё конченый': ['ДЖОУИ', 'ФИБИ', 'РОСС', 'ЧЕНДЛЕР'],
#  'вы': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'смотреть я же сказать': ['ДЖОУИ', 'РОСС'],
#  'итак': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'какой': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'мужчина': ['ДЖОУИ', 'РЕЙЧЕЛ', 'РОСС'],
#  'правда': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'бог мой': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'хорошо выглядеть': ['ДЖОУИ', 'МОНИКА', 'ЧЕНДЛЕР'],
#  'вы не говорить': ['ДЖОУИ', 'ФИБИ'],
#  'кто черта взять такой': ['ДЖОУИ', 'РОСС', 'ЧЕНДЛЕР'],
#  'давать': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'он звать': ['ДЖОУИ', 'ФИБИ'],
#  'фу': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'ты я помочь': ['ДЖОУИ', 'МОНИКА', 'ЧЕНДЛЕР'],
#  'пожалуйста': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'что что': ['ДЖОУИ', 'ФИБИ', 'РОСС'],
#  'но не я': ['ДЖОУИ', 'РЕЙЧЕЛ'],
#  'сексуально': ['ДЖОУИ', 'РОСС'],
#  'то есть': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'ой': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'подождать подождать подождать': ['ДЖОУИ', 'РЕЙЧЕЛ'],
#  'отлично': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'что думать': ['ДЖОУИ', 'МОНИКА', 'РОСС'],
#  'хорошо я быть там': ['ДЖОУИ', 'ФИБИ', 'РОСС'],
#  'вы мочь в это поверить': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС'],
#  'я не в порядок': ['ДЖОУИ', 'МОНИКА'],
#  'я он': ['ДЖОУИ'],
#  'кей': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'ЧЕНДЛЕР'],
#  'я играть задница': ['ДЖОУИ'],
#  'он идти в душа а потом': ['ДЖОУИ'],
#  'я он задница': ['ДЖОУИ'],
#  'да ладный ребята': ['ДЖОУИ', 'РЕЙЧЕЛ', 'МОНИКА'],
#  'это настоящий фильм и в немой играть и это здорово': ['ДЖОУИ'],
#  'хорошо хорошо хорошо': ['ДЖОУИ',
#   'РЕЙЧЕЛ',
#   'ФИБИ',
#   'МОНИКА',
#   'РОСС',
#   'ЧЕНДЛЕР'],
#  'шутить я плевать': ['ДЖОУИ'],
#  'для я это большой прорыв': ['ДЖОУИ'],
#  'вот': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'я': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'верно': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'нет': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'я уволить': ['ДЖОУИ', 'РЕЙЧЕЛ', 'РОСС'],
#  'это так мило': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА'],
#  'весь привет': ['ДЖОУИ', 'ФИБИ', 'МОНИКА', 'РОСС'],
#  'вперёд': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'нет уж': ['ДЖОУИ', 'РЕЙЧЕЛ'],
#  'нет нет нет': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'у мы есть победитель': ['ДЖОУИ'],
#  'это никогда не случиться': ['ДЖОУИ', 'РОСС'],
#  'ты и': ['ДЖОУИ', 'МОНИКА'],
#  'ты собираться это сделать': ['ДЖОУИ', 'ФИБИ'],
#  'удача ты': ['ДЖОУИ', 'РЕЙЧЕЛ'],
#  'не я': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ЧЕНДЛЕР'],
#  'дважды': ['ДЖОУИ', 'РОСС'],
#  'я обнажить': ['ДЖОУИ'],
#  'привет привет': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'РОСС', 'ЧЕНДЛЕР'],
#  'да я': ['ДЖОУИ', 'РЕЙЧЕЛ', 'РОСС', 'ЧЕНДЛЕР'],
#  'да': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'я серьёзно': ['ДЖОУИ', 'РЕЙЧЕЛ', 'РОСС'],
#  'ты удивительный': ['ДЖОУИ', 'МОНИКА'],
#  'что на ты надеть': ['ДЖОУИ'],
#  'что случиться': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'у я вопрос': ['ДЖОУИ', 'МОНИКА', 'РОСС'],
#  'нет не тот': ['ДЖОУИ'],
#  'я быть': ['ДЖОУИ', 'РЕЙЧЕЛ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'не знать': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'привет извинить я опоздать': ['ДЖОУИ', 'ЧЕНДЛЕР'],
#  'сэнди': ['ДЖОУИ', 'РОСС'],
#  'привет ребёночек': ['ДЖОУИ', 'ЧЕНДЛЕР'],
#  'ого': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'эй ребята': ['ДЖОУИ', 'ФИБИ'],
#  'вы видеть': ['ДЖОУИ', 'МОНИКА', 'ЧЕНДЛЕР'],
#  'там': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'ничего страшный': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'а': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'хм': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'он сделать это': ['ДЖОУИ', 'ФИБИ'],
#  'нет нет': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'я ничего не слышать': ['ДЖОУИ', 'МОНИКА'],
#  'запустить': ['ДЖОУИ', 'ФИБИ', 'МОНИКА', 'ЧЕНДЛЕР'],
#  'привет папа': ['ДЖОУИ', 'РЕЙЧЕЛ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'вы знать о это': ['ДЖОУИ', 'РОСС'],
#  'почему нет': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'РОСС', 'ЧЕНДЛЕР'],
#  'так что это быть': ['ДЖОУИ', 'ФИБИ'],
#  'вопрос': ['ДЖОУИ', 'РОСС', 'ЧЕНДЛЕР'],
#  'конечно': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'давать поиграть': ['ДЖОУИ'],
#  'сейчас утро': ['ДЖОУИ', 'РОСС'],
#  'привет ребята': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'папа': ['ДЖОУИ', 'РЕЙЧЕЛ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'эээ': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'привет мама': ['ДЖОУИ', 'МОНИКА', 'РОСС'],
#  'ха': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'ЧЕНДЛЕР'],
#  'блин': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'это круто': ['ДЖОУИ', 'РОСС', 'ЧЕНДЛЕР'],
#  'что с': ['ДЖОУИ'],
#  'я я': ['ДЖОУИ', 'ФИБИ', 'МОНИКА'],
#  'здесь': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'это неправильно': ['ДЖОУИ', 'МОНИКА', 'ЧЕНДЛЕР'],
#  'я подумать': ['ДЖОУИ', 'РЕЙЧЕЛ'],
#  'вы понимать о чем я': ['ДЖОУИ', 'ЧЕНДЛЕР'],
#  'вы правда так думать': ['ДЖОУИ', 'РЕЙЧЕЛ', 'РОСС'],
#  'что с ты': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'ма': ['ДЖОУИ'],
#  'что ты здесь делать': ['ДЖОУИ',
#   'РЕЙЧЕЛ',
#   'ФИБИ',
#   'МОНИКА',
#   'РОСС',
#   'ЧЕНДЛЕР'],
#  'постоять': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС'],
#  'ты знать': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'я жаль': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'извинить': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'как я выглядеть': ['ДЖОУИ', 'ЧЕНДЛЕР'],
#  'нет нет не надо': ['ДЖОУИ', 'РОСС'],
#  'просто успокоиться': ['ДЖОУИ', 'РЕЙЧЕЛ'],
#  'успокоиться': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ'],
#  'мы не мочь это сделать': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ЧЕНДЛЕР'],
#  'вы правый извинить': ['ДЖОУИ', 'РЕЙЧЕЛ', 'МОНИКА', 'РОСС'],
#  'ты право': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'я очень жаль': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'если вы это не сделать я сделать это': ['ДЖОУИ', 'РЕЙЧЕЛ'],
#  'а как насчёт': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'РОСС', 'ЧЕНДЛЕР'],
#  'в чем дело': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'я сказать ты что': ['ДЖОУИ', 'ЧЕНДЛЕР'],
#  'хорошо хорошо': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'вперёд продолжать': ['ДЖОУИ'],
#  'ну вот': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'продолжать': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'я всё равно': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'о нетнетнуть': ['ДЖОУИ', 'РЕЙЧЕЛ', 'РОСС', 'ЧЕНДЛЕР'],
#  'это для': ['ДЖОУИ', 'МОНИКА'],
#  'что я мочь сделать': ['ДЖОУИ', 'МОНИКА', 'ЧЕНДЛЕР'],
#  'не понимать': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС'],
#  'почему': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'нет я не мочь это сделать': ['ДЖОУИ', 'ФИБИ'],
#  'знать': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'заткнуться': ['ДЖОУИ', 'РЕЙЧЕЛ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'о чем': ['ДЖОУИ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'фиби': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'я тоже': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'проверить': ['ДЖОУИ'],
#  'куда ты идти': ['ДЖОУИ', 'РЕЙЧЕЛ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'марсель': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'обезьяна': ['ДЖОУИ', 'МОНИКА'],
#  'конечно конечно': ['ДЖОУИ', 'РЕЙЧЕЛ', 'РОСС', 'ЧЕНДЛЕР'],
#  'мы очень жаль': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ЧЕНДЛЕР'],
#  'ни в кой случай': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'РОСС'],
#  'он вернуться': ['ДЖОУИ', 'ЧЕНДЛЕР'],
#  'и что': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС'],
#  'а я нет': ['ДЖОУИ', 'ФИБИ', 'МОНИКА', 'РОСС'],
#  'сталин': ['ДЖОУИ', 'ЧЕНДЛЕР'],
#  'где ты быть': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'ЧЕНДЛЕР'],
#  'не мочь поверить': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'это отстой': ['ДЖОУИ', 'РЕЙЧЕЛ', 'МОНИКА', 'ЧЕНДЛЕР'],
#  'не знать что сказать': ['ДЖОУИ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'я голодный': ['ДЖОУИ', 'ФИБИ'],
#  'молодой': ['ДЖОУИ', 'ЧЕНДЛЕР'],
#  'хорошо расслабиться расслабиться': ['ДЖОУИ', 'РОСС'],
#  'они уже здесь': ['ДЖОУИ', 'ФИБИ'],
#  'хорошо я идти': ['ДЖОУИ', 'ФИБИ', 'РОСС'],
#  'я уходить': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'стрелять': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС'],
#  'актёр': ['ДЖОУИ', 'ФИБИ'],
#  'да это так': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'это так': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'РОСС'],
#  'что это такой': ['ДЖОУИ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'толкать': ['ДЖОУИ'],
#  'расслабиться': ['ДЖОУИ', 'РЕЙЧЕЛ', 'МОНИКА'],
#  'ничего такой': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'ты мочь я помочь': ['ДЖОУИ', 'МОНИКА'],
#  'я правда': ['ДЖОУИ', 'РЕЙЧЕЛ'],
#  'ну': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'на сам дело': ['ДЖОУИ', 'РОСС'],
#  'ладный': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'страна': ['ДЖОУИ'],
#  'о нет': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'двигаться далёкий': ['ДЖОУИ', 'РЕЙЧЕЛ'],
#  'я любить ты чувак': ['ДЖОУИ'],
#  'не очень хорошо': ['ДЖОУИ', 'ФИБИ', 'РОСС', 'ЧЕНДЛЕР'],
#  'что вы иметь в вид': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'РОСС', 'ЧЕНДЛЕР'],
#  'ничего подобный': ['ДЖОУИ', 'РЕЙЧЕЛ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'знать что': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'о это быть потрясающе': ['ДЖОУИ', 'РЕЙЧЕЛ', 'РОСС'],
#  'это быть потрясающе': ['ДЖОУИ', 'МОНИКА', 'ЧЕНДЛЕР'],
#  'это как': ['ДЖОУИ', 'ФИБИ'],
#  'ты что ненормальный': ['ДЖОУИ', 'ЧЕНДЛЕР'],
#  'эээ это': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ЧЕНДЛЕР'],
#  'здравствуйте': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'о привет': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'ЧЕНДЛЕР'],
#  'это': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'нет погодить': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС'],
#  'нет простить': ['ДЖОУИ', 'ФИБИ'],
#  'эй эй': ['ДЖОУИ', 'ФИБИ', 'РОСС', 'ЧЕНДЛЕР'],
#  'как дело': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'ни за что': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'ходить к этот парень год': ['ДЖОУИ'],
#  'ты он сказать': ['ДЖОУИ'],
#  'разве не так мерить штаны': ['ДЖОУИ'],
#  'это не': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'больно': ['ДЖОУИ', 'РЕЙЧЕЛ'],
#  'что ты делать': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'а что насчёт': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА'],
#  'биджан для мужчина': ['ДЖОУИ'],
#  'кто': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'привет как дело': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'совершенно верно': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'я не знать': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'думать ты право': ['ДЖОУИ', 'ФИБИ', 'МОНИКА'],
#  'я сделать это': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'утро': ['ДЖОУИ', 'РЕЙЧЕЛ', 'МОНИКА', 'ЧЕНДЛЕР'],
#  'это сводить я с ум': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА'],
#  'хороший': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'ну вот и всё': ['ДЖОУИ', 'РЕЙЧЕЛ', 'МОНИКА', 'РОСС'],
#  'быстрый': ['ДЖОУИ', 'МОНИКА', 'ЧЕНДЛЕР'],
#  'посмотреть': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'посмотреть посмотреть': ['ДЖОУИ'],
#  'ну не знать': ['ДЖОУИ', 'РЕЙЧЕЛ', 'МОНИКА', 'РОСС'],
#  'возможно': ['ДЖОУИ', 'ФИБИ', 'РОСС', 'ЧЕНДЛЕР'],
#  'не мочь ты поверить': ['ДЖОУИ', 'ФИБИ'],
#  'хорошо вот я идти вот я идти': ['ДЖОУИ'],
#  'видеть я идти починить копировальный аппарат я не мочь добраться до копировальный аппарат я думать что я делать что я делать так что я просто смотреть как они заниматься секс': ['ДЖОУИ'],
#  'а потом я говорить подождать вот мой очередь вы знать это плохо для лоток для бумага': ['ДЖОУИ'],
#  'парень блокировать я задница': ['ДЖОУИ'],
#  'вот я вот я вот я вот я вот я': ['ДЖОУИ'],
#  'за': ['ДЖОУИ', 'РЕЙЧЕЛ'],
#  'круто': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'РОСС', 'ЧЕНДЛЕР'],
#  'извинить извинить': ['ДЖОУИ', 'РОСС'],
#  'благотворительность': ['ДЖОУИ', 'МОНИКА'],
#  'ты в порядок': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'оно тот стоить': ['ДЖОУИ', 'РОСС', 'ЧЕНДЛЕР'],
#  'нет серьёзно': ['ДЖОУИ', 'РЕЙЧЕЛ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'что я ты сказать': ['ДЖОУИ'],
#  'убираться отсюда': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'РОСС', 'ЧЕНДЛЕР'],
#  'да конечно': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'ой подождать': ['ДЖОУИ', 'РЕЙЧЕЛ'],
#  'ааа': ['ДЖОУИ', 'РЕЙЧЕЛ', 'МОНИКА', 'РОСС'],
#  'ух': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'это безумие': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'хорошо вперёд': ['ДЖОУИ', 'РОСС'],
#  'позволить я уточнить': ['ДЖОУИ', 'ЧЕНДЛЕР'],
#  'язык': ['ДЖОУИ', 'МОНИКА'],
#  'а потом': ['ДЖОУИ', 'ФИБИ', 'ЧЕНДЛЕР'],
#  'послушать': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС'],
#  'он расстаться с': ['ДЖОУИ'],
#  'ну ради бог идти и обнять она': ['ДЖОУИ'],
#  'да знать': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'ЧЕНДЛЕР'],
#  'ты знать что хотеть': ['ДЖОУИ', 'РОСС'],
#  'удача': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'всё в порядок': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'это ты': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'нет но изз запах новый машина вы так и подумать': ['ДЖОУИ'],
#  'угу': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'а для мистер': ['ДЖОУИ'],
#  'вот вот': ['ДЖОУИ', 'ЧЕНДЛЕР'],
#  'мочь быть': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'ооо': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'она научить я весь как работать с камера и как действовать': ['ДЖОУИ'],
#  'как будто ты нужно так быстро выучить столько строка что иногда ты нужный минута чтобы вспомнить следующий': ['ДЖОУИ'],
#  'итак пока вы думать о это вы делать больший пауза когда выглядеть очень напряжённо знать вот так': ['ДЖОУИ'],
#  'вот мой сцена вот мой сцена': ['ДЖОУИ'],
#  'я доктор нейрохирург ваш сестра': ['ДЖОУИ'],
#  'бояться ситуация намного плохой чем мы ожидать': ['ДЖОУИ'],
#  'посмотреть кто встать': ['ДЖОУИ', 'ФИБИ'],
#  'у я есть': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ'],
#  'она идти': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'РОСС'],
#  'готовый': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'никто': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'ЧЕНДЛЕР'],
#  'заходить': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'я не': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'беречь себя': ['ДЖОУИ', 'РЕЙЧЕЛ', 'МОНИКА', 'РОСС'],
#  'это потрясающе': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'попасться': ['ДЖОУИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'забыть о это': ['ДЖОУИ', 'РЕЙЧЕЛ'],
#  'ну дать посмотреть': ['ДЖОУИ', 'ЧЕНДЛЕР'],
#  'мамочка': ['ДЖОУИ', 'РОСС', 'ЧЕНДЛЕР'],
#  'что ты сказать': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'не правда ли': ['ДЖОУИ', 'МОНИКА', 'РОСС'],
#  'почему у вы два': ['ДЖОУИ'],
#  'выходить': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'РОСС', 'ЧЕНДЛЕР'],
#  'я думать так': ['ДЖОУИ'],
#  'послушать мы приятель по браслет': ['ДЖОУИ'],
#  'отлично мистер': ['ДЖОУИ'],
#  'сметь': ['ДЖОУИ', 'ЧЕНДЛЕР'],
#  'да так': ['ДЖОУИ', 'ФИБИ'],
#  'я думать о это': ['ДЖОУИ', 'РЕЙЧЕЛ', 'РОСС'],
#  'нет всё в порядок': ['ДЖОУИ', 'РЕЙЧЕЛ', 'МОНИКА', 'ЧЕНДЛЕР'],
#  'хорошо вы на связь': ['ДЖОУИ', 'ФИБИ'],
#  'думать вот оно': ['ДЖОУИ', 'РОСС'],
#  'верно да': ['ДЖОУИ', 'ФИБИ'],
#  'около': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'хорошо я понять': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ЧЕНДЛЕР'],
#  'ну ладный': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'да да': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'хорошо вот и всё': ['ДЖОУИ', 'РЕЙЧЕЛ', 'РОСС', 'ЧЕНДЛЕР'],
#  'я нужный сок': ['ДЖОУИ', 'РОСС'],
#  'яйцо': ['ДЖОУИ', 'РОСС'],
#  'да ладный': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'ну да вроде как': ['ДЖОУИ', 'РОСС'],
#  'но вы знать что': ['ДЖОУИ', 'РЕЙЧЕЛ', 'РОСС'],
#  'нет не знать': ['ДЖОУИ', 'РЕЙЧЕЛ', 'МОНИКА', 'ЧЕНДЛЕР'],
#  'я собираться выпить кофе': ['ДЖОУИ'],
#  'я не быть это делать': ['ДЖОУИ', 'РОСС'],
#  'увидеться': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'ЧЕНДЛЕР'],
#  'это не мочь быть хорошо': ['ДЖОУИ', 'ФИБИ'],
#  'я не знать что я делать': ['ДЖОУИ', 'РЕЙЧЕЛ', 'РОСС'],
#  'ну и что': ['ДЖОУИ', 'РЕЙЧЕЛ', 'МОНИКА', 'РОСС'],
#  'я быть доктор': ['ДЖОУИ'],
#  'у я быть хороший день': ['ДЖОУИ'],
#  'я пойти': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'РОСС', 'ЧЕНДЛЕР'],
#  'не понять': ['ДЖОУИ', 'ФИБИ'],
#  'я не мочь это смотреть': ['ДЖОУИ', 'РЕЙЧЕЛ'],
#  'нет проблема': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'нет я в порядок': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ'],
#  'ладный ладный ладный': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ'],
#  'мы ребята': ['ДЖОУИ', 'ЧЕНДЛЕР'],
#  'странно': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'ты шутить': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'РОСС', 'ЧЕНДЛЕР'],
#  'что делать': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'как это': ['ДЖОУИ', 'РОСС', 'ЧЕНДЛЕР'],
#  'сложно сказать': ['ДЖОУИ', 'РЕЙЧЕЛ'],
#  'кроме': ['ДЖОУИ', 'МОНИКА', 'РОСС'],
#  'как мило': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'довольно хорошо': ['ДЖОУИ'],
#  'ой спасибо спасибо': ['ДЖОУИ', 'РОСС'],
#  'до свидание': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'в сам дело': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'лёгкий': ['ДЖОУИ', 'РОСС'],
#  'невероятно': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'в чем проблема': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ЧЕНДЛЕР'],
#  'да в это есть смысл': ['ДЖОУИ', 'ФИБИ'],
#  'я очень хотеть этот роль': ['ДЖОУИ'],
#  'ого вы хороший друг конечно прослушивание быть сегодня утром и я он не получить': ['ДЖОУИ'],
#  'но это быть адский поцелуй': ['ДЖОУИ'],
#  'очень везучий девочка': ['ДЖОУИ'],
#  'поцелуй она': ['ДЖОУИ'],
#  'чендлера и': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ'],
#  'милый': ['ДЖОУИ', 'РЕЙЧЕЛ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'вы помнить': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ЧЕНДЛЕР'],
#  'прохладный': ['ДЖОУИ', 'ФИБИ', 'РОСС'],
#  'нет ага': ['ДЖОУИ', 'ФИБИ'],
#  'не мочь': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС'],
#  'я в игра': ['ДЖОУИ', 'ФИБИ', 'ЧЕНДЛЕР'],
#  'я в немой': ['ДЖОУИ'],
#  'хорошо дружище': ['ДЖОУИ', 'ЧЕНДЛЕР'],
#  'ты прятать мой одежда я носить всё что у ты есть': ['ДЖОУИ'],
#  'посмотреть на я': ['ДЖОУИ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'мочь ли я носить ещё одежда': ['ДЖОУИ'],
#  'уф как жарко с весь этот ерунда': ['ДЖОУИ'],
#  'я ах я хороший не делать выпад я не знать': ['ДЖОУИ'],
#  'варение': ['ДЖОУИ', 'МОНИКА'],
#  'вы говорить с они': ['ДЖОУИ', 'РЕЙЧЕЛ'],
#  'вы с ум сойти': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'ох': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'куда идти': ['ДЖОУИ', 'ФИБИ'],
#  'звучать неплохо': ['ДЖОУИ', 'ЧЕНДЛЕР'],
#  'я понять': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'о ты сказать это': ['ДЖОУИ'],
#  'должный быть способ хороший': ['ДЖОУИ'],
#  'ого это просто': ['ДЖОУИ'],
#  'теперь я мочь есть молоко каждый день': ['ДЖОУИ'],
#  'ты не мочь это сделать': ['ДЖОУИ', 'РЕЙЧЕЛ'],
#  'положить трубка положить трубка': ['ДЖОУИ', 'ЧЕНДЛЕР'],
#  'обожать этот фильм': ['ДЖОУИ'],
#  'спасибо большой': ['ДЖОУИ', 'ФИБИ', 'РОСС', 'ЧЕНДЛЕР'],
#  'я любить вы': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'четыре': ['ДЖОУИ', 'РЕЙЧЕЛ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'вот ты где': ['ДЖОУИ', 'РЕЙЧЕЛ', 'МОНИКА', 'ЧЕНДЛЕР'],
#  'ждать': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'вы чтонибыть слышать': ['ДЖОУИ', 'ФИБИ', 'МОНИКА'],
#  'я в порядок': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'видеть': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'ладный стрелять': ['ДЖОУИ', 'РОСС'],
#  'а что ещё': ['ДЖОУИ', 'РЕЙЧЕЛ'],
#  'погодить': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'как насчёт ты': ['ДЖОУИ', 'ФИБИ', 'МОНИКА'],
#  'я идти к': ['ДЖОУИ', 'РОСС'],
#  'ничего': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'вот и всё': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'о привет мистер': ['ДЖОУИ', 'РЕЙЧЕЛ'],
#  'уф': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС'],
#  'да дерзить пари': ['ДЖОУИ', 'ФИБИ'],
#  'эй хотеть пиво': ['ДЖОУИ'],
#  'хорошо идти далёкий': ['ДЖОУИ', 'МОНИКА'],
#  'о это быть здорово': ['ДЖОУИ', 'РЕЙЧЕЛ', 'МОНИКА'],
#  'эй': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'хорошо отлично': ['ДЖОУИ', 'РЕЙЧЕЛ', 'МОНИКА', 'ЧЕНДЛЕР'],
#  'я не видеть': ['ДЖОУИ', 'ЧЕНДЛЕР'],
#  'вы держать пари': ['ДЖОУИ', 'ФИБИ', 'РОСС'],
#  'что за роль': ['ДЖОУИ', 'МОНИКА', 'РОСС'],
#  'это быть хорошо': ['ДЖОУИ', 'РЕЙЧЕЛ', 'РОСС'],
#  'простить простить простить': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ'],
#  'это он убить': ['ДЖОУИ', 'ЧЕНДЛЕР'],
#  'я не ошибаться': ['ДЖОУИ', 'МОНИКА'],
#  'я хотеть бы': ['ДЖОУИ', 'РЕЙЧЕЛ'],
#  'эй в чем дело': ['ДЖОУИ'],
#  'у ты всё нормально': ['ДЖОУИ', 'РЕЙЧЕЛ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'устойчивый': ['ДЖОУИ'],
#  'заправить нить в игла': ['ДЖОУИ', 'МОНИКА'],
#  'давать мужик': ['ДЖОУИ', 'РОСС'],
#  'понять': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'привет я': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'РОСС', 'ЧЕНДЛЕР'],
#  'думать да': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'а да это': ['ДЖОУИ', 'РОСС'],
#  'что черта взять с ты': ['ДЖОУИ', 'РЕЙЧЕЛ', 'РОСС'],
#  'после': ['ДЖОУИ', 'МОНИКА'],
#  'что ты собираться делать': ['ДЖОУИ',
#   'РЕЙЧЕЛ',
#   'ФИБИ',
#   'МОНИКА',
#   'РОСС',
#   'ЧЕНДЛЕР'],
#  'держать': ['ДЖОУИ', 'МОНИКА', 'ЧЕНДЛЕР'],
#  'хороший попытка': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'ЧЕНДЛЕР'],
#  'подождать минута': ['ДЖОУИ', 'РЕЙЧЕЛ', 'МОНИКА', 'РОСС'],
#  'у я отличный новость': ['ДЖОУИ', 'МОНИКА', 'РОСС'],
#  'не проблема': ['ДЖОУИ'],
#  'ладный вперёд': ['ДЖОУИ', 'ЧЕНДЛЕР'],
#  'понятно': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'мэрианджела': ['ДЖОУИ', 'РОСС'],
#  'это правда': ['ДЖОУИ', 'РЕЙЧЕЛ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'замечательный': ['ДЖОУИ', 'РЕЙЧЕЛ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'а вы': ['ДЖОУИ', 'РЕЙЧЕЛ', 'МОНИКА', 'РОСС'],
#  'она прямо там': ['ДЖОУИ', 'МОНИКА'],
#  'ладный всё': ['ДЖОУИ', 'РЕЙЧЕЛ', 'МОНИКА', 'РОСС'],
#  'это я': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'я ещё не закончить': ['ДЖОУИ', 'ФИБИ'],
#  'пока': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'посмотреть на себя': ['ДЖОУИ', 'ФИБИ', 'МОНИКА', 'РОСС'],
#  'чем заниматься': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС'],
#  'умереть': ['ДЖОУИ'],
#  'ой мужик': ['ДЖОУИ', 'РЕЙЧЕЛ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'желать': ['ДЖОУИ', 'ЧЕНДЛЕР'],
#  'мы оба': ['ДЖОУИ', 'ЧЕНДЛЕР'],
#  'ах': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'и что ты собираться делать': ['ДЖОУИ',
#   'РЕЙЧЕЛ',
#   'МОНИКА',
#   'РОСС',
#   'ЧЕНДЛЕР'],
#  'не отвечать на это': ['ДЖОУИ', 'ЧЕНДЛЕР'],
#  'ужасно': ['ДЖОУИ', 'РЕЙЧЕЛ', 'МОНИКА', 'ЧЕНДЛЕР'],
#  'ужасный': ['ДЖОУИ', 'ЧЕНДЛЕР'],
#  'она быть ничто по сравнение с ты': ['ДЖОУИ'],
#  'почему бы и нет': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'да всё быть хорошо': ['ДЖОУИ', 'РЕЙЧЕЛ', 'МОНИКА'],
#  'отлично на следующий выходной': ['ДЖОУИ'],
#  'хорошо готовый': ['ДЖОУИ', 'ФИБИ', 'МОНИКА'],
#  'аа': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'РОСС', 'ЧЕНДЛЕР'],
#  'тут смешной': ['ДЖОУИ'],
#  'твой хороший друг': ['ДЖОУИ', 'РОСС'],
#  'она классный': ['ДЖОУИ'],
#  'доктор': ['ДЖОУИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'день наш жизнь': ['ДЖОУИ'],
#  'я ненавидеть она': ['ДЖОУИ'],
#  'ну почему бы ты не сказать я кто ты должный быть': ['ДЖОУИ'],
#  'потому что я черта взять не мочь это понять': ['ДЖОУИ'],
#  'эй а как насчёт это': ['ДЖОУИ'],
#  'хотеть чашка кофе': ['ДЖОУИ', 'ФИБИ'],
#  'давать детка не уходить': ['ДЖОУИ'],
#  'что ты говорить': ['ДЖОУИ', 'РЕЙЧЕЛ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'хорошо пока': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'ага привет': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА'],
#  'открыть это': ['ДЖОУИ', 'РЕЙЧЕЛ', 'МОНИКА'],
#  'как она': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'РОСС', 'ЧЕНДЛЕР'],
#  'я нужно расслабиться': ['ДЖОУИ', 'РЕЙЧЕЛ'],
#  'это ужасно': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'ЧЕНДЛЕР'],
#  'вы уверить': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС'],
#  'что получить': ['ДЖОУИ', 'РЕЙЧЕЛ', 'РОСС'],
#  'два': ['ДЖОУИ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'всё это': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС'],
#  'вы знать что вы следовать делать': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ЧЕНДЛЕР'],
#  'классно': ['ДЖОУИ', 'РОСС'],
#  'спокойный ночь': ['ДЖОУИ', 'РЕЙЧЕЛ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'где': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'я идти': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'РОСС'],
#  'происходить': ['ДЖОУИ', 'РЕЙЧЕЛ', 'МОНИКА', 'РОСС'],
#  'минутка': ['ДЖОУИ', 'РЕЙЧЕЛ', 'МОНИКА'],
#  'да наверное': ['ДЖОУИ', 'РЕЙЧЕЛ', 'МОНИКА', 'ЧЕНДЛЕР'],
#  'но когда я вернуться через год ты уже не быть': ['ДЖОУИ'],
#  'но я совсем не постарелый': ['ДЖОУИ'],
#  'так что сказать свой правнучка найти я потому что детка я хотеть с она встретиться': ['ДЖОУИ'],
#  'что это быть': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'ну что это': ['ДЖОУИ', 'РЕЙЧЕЛ', 'МОНИКА', 'РОСС'],
#  'посмотреть на это': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'ЧЕНДЛЕР'],
#  'веер': ['ДЖОУИ'],
#  'о да': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'ЧЕНДЛЕР'],
#  'хорошо расслабиться': ['ДЖОУИ', 'МОНИКА'],
#  'я видеть это на канал': ['ДЖОУИ'],
#  'верно я подойти': ['ДЖОУИ'],
#  'она мой друг и она нужный быть помощь': ['ДЖОУИ'],
#  'и если бы я тоже я бы пописать на любой из вы': ['ДЖОУИ'],
#  'так себя': ['ДЖОУИ', 'МОНИКА'],
#  'что не так': ['ДЖОУИ', 'РЕЙЧЕЛ', 'РОСС', 'ЧЕНДЛЕР'],
#  'красиво': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'я сказать': ['ДЖОУИ', 'РЕЙЧЕЛ', 'РОСС', 'ЧЕНДЛЕР'],
#  'он пообещать что не взять стул': ['ДЖОУИ'],
#  'ну этот парень зайти посмотреть на блок и сказать что он недостаточно большой чтобы соответствовать взрослый мужчина': ['ДЖОУИ'],
#  'я пытаться продать': ['ДЖОУИ'],
#  'о чувак если я когданибудь снова столкнуться с это парень ты знать что я быть делать': ['ДЖОУИ'],
#  'прямо здесь': ['ДЖОУИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'входить': ['ДЖОУИ', 'ФИБИ'],
#  'это очень мило': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ'],
#  'и': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'о чем ты хотеть поговорить': ['ДЖОУИ', 'МОНИКА'],
#  'увидеться поздний': ['ДЖОУИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'я попробовать': ['ДЖОУИ', 'МОНИКА'],
#  'что что это': ['ДЖОУИ', 'ФИБИ', 'РОСС'],
#  'мы сделать': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ'],
#  'сейчас': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'я угощать': ['ДЖОУИ'],
#  'сейчас вернуться': ['ДЖОУИ', 'МОНИКА'],
#  'я думать мы заключить сделка': ['ДЖОУИ', 'ЧЕНДЛЕР'],
#  'о я знать': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'РОСС', 'ЧЕНДЛЕР'],
#  'вау': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'РОСС', 'ЧЕНДЛЕР'],
#  'спасибо чувак': ['ДЖОУИ', 'РОСС', 'ЧЕНДЛЕР'],
#  'ой привет': ['ДЖОУИ', 'РОСС', 'ЧЕНДЛЕР'],
#  'дада': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'привет это я': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'РОСС', 'ЧЕНДЛЕР'],
#  'знать что я думать': ['ДЖОУИ', 'РОСС', 'ЧЕНДЛЕР'],
#  'как вы думать': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'ты знать почему': ['ДЖОУИ', 'ФИБИ', 'МОНИКА', 'РОСС'],
#  'ты с она спасть': ['ДЖОУИ', 'МОНИКА'],
#  'это ещё плохой': ['ДЖОУИ'],
#  'но это то же самый': ['ДЖОУИ'],
#  'да какой разница': ['ДЖОУИ', 'МОНИКА', 'РОСС'],
#  'за черта': ['ДЖОУИ'],
#  'линия для вы точка': ['ДЖОУИ'],
#  'пять год': ['ДЖОУИ', 'РОСС'],
#  'ты сделать': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'РОСС'],
#  'он в порядок': ['ДЖОУИ', 'РОСС'],
#  'хорошо смотреть': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ЧЕНДЛЕР'],
#  'да у мы всё быть хорошо': ['ДЖОУИ', 'ФИБИ'],
#  'хорошо увидеться ребята': ['ДЖОУИ', 'РОСС'],
#  'что вы ребята здесь делать': ['ДЖОУИ', 'РЕЙЧЕЛ'],
#  'послать': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'ну что развлекаться': ['ДЖОУИ', 'МОНИКА'],
#  'слава бог': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'да я знать': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'ЧЕНДЛЕР'],
#  'подождать секунда': ['ДЖОУИ', 'РОСС', 'ЧЕНДЛЕР'],
#  'ты собираться я уволить': ['ДЖОУИ'],
#  'ох ох': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС'],
#  'действительно': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'доллар': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'проверить это': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'нет не совсем': ['ДЖОУИ', 'РЕЙЧЕЛ'],
#  'я сэкономить ты место': ['ДЖОУИ', 'МОНИКА'],
#  'как угодный': ['ДЖОУИ', 'ФИБИ'],
#  'я понимать': ['ДЖОУИ'],
#  'увидеться завтра': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ЧЕНДЛЕР'],
#  'я актёр': ['ДЖОУИ', 'ФИБИ'],
#  'шесть': ['ДЖОУИ', 'МОНИКА', 'ЧЕНДЛЕР'],
#  'серьёзно': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'всё относительно': ['ДЖОУИ', 'РЕЙЧЕЛ'],
#  'большой толстый вратарь': ['ДЖОУИ'],
#  'выходной у': ['ДЖОУИ', 'ЧЕНДЛЕР'],
#  'повседневный использование': ['ДЖОУИ'],
#  'гость': ['ДЖОУИ', 'МОНИКА'],
#  'ставка': ['ДЖОУИ', 'МОНИКА'],
#  'эй не сердиться на мы': ['ДЖОУИ'],
#  'никто не заставлять вы повышать ставка': ['ДЖОУИ'],
#  'привет пн': ['ДЖОУИ', 'РЕЙЧЕЛ', 'РОСС', 'ЧЕНДЛЕР'],
#  'хотеть блин': ['ДЖОУИ', 'РЕЙЧЕЛ'],
#  'идти сюда': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'как я это делать я смотреть на женщина с голова до нога и говорить как дело': ['ДЖОУИ'],
#  'что это за хрень': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'ЧЕНДЛЕР'],
#  'как всё пройти': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'плюс': ['ДЖОУИ', 'МОНИКА'],
#  'привет дружище': ['ДЖОУИ', 'ФИБИ', 'РОСС'],
#  'я здесь': ['ДЖОУИ', 'РОСС', 'ЧЕНДЛЕР'],
#  'интересно': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'ЧЕНДЛЕР'],
#  'нет нет погодить': ['ДЖОУИ', 'МОНИКА'],
#  'ага да': ['ДЖОУИ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'ах да': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС'],
#  'не хотеть': ['ДЖОУИ', 'РОСС'],
#  'вот так': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'я говорить ты': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ЧЕНДЛЕР'],
#  'да что происходить': ['ДЖОУИ', 'РОСС'],
#  'чточто ты делать': ['ДЖОУИ', 'РЕЙЧЕЛ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'о мама': ['ДЖОУИ', 'РОСС'],
#  'что я сделать': ['ДЖОУИ', 'РЕЙЧЕЛ'],
#  'беречься': ['ДЖОУИ', 'ФИБИ'],
#  'нет ничего': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ'],
#  'один': ['ДЖОУИ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'приятно': ['ДЖОУИ', 'ЧЕНДЛЕР'],
#  'звучать здорово': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС'],
#  'как насчёт': ['ДЖОУИ', 'РЕЙЧЕЛ', 'РОСС'],
#  'твой приятель': ['ДЖОУИ'],
#  'где всё': ['ДЖОУИ', 'ФИБИ', 'МОНИКА', 'РОСС'],
#  'вы издеваться': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС'],
#  'я любить это парень': ['ДЖОУИ', 'РОСС'],
#  'давать торговать': ['ДЖОУИ', 'ФИБИ'],
#  'ох я это нравиться': ['ДЖОУИ', 'ФИБИ'],
#  'что за игра': ['ДЖОУИ'],
#  'о ага': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'РОСС'],
#  'король': ['ДЖОУИ', 'РОСС'],
#  'хороший игра': ['ДЖОУИ', 'ЧЕНДЛЕР'],
#  'есть': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'ооо да': ['ДЖОУИ'],
#  'ничего не поделать': ['ДЖОУИ', 'РОСС'],
#  'ага ну': ['ДЖОУИ', 'РОСС', 'ЧЕНДЛЕР'],
#  'это не мой': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА'],
#  'в': ['ДЖОУИ', 'ЧЕНДЛЕР'],
#  'чувак': ['ДЖОУИ', 'РОСС', 'ЧЕНДЛЕР'],
#  'о знать что': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'ЧЕНДЛЕР'],
#  'мы он показать': ['ДЖОУИ', 'РОСС'],
#  'я это знать': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'так хороший': ['ДЖОУИ', 'ФИБИ', 'МОНИКА', 'ЧЕНДЛЕР'],
#  'а я': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ'],
#  'поздний': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'РОСС'],
#  'смотреть это': ['ДЖОУИ', 'МОНИКА'],
#  'о спасибо': ['ДЖОУИ', 'РЕЙЧЕЛ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'что я делать': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'я не понимать': ['ДЖОУИ', 'РЕЙЧЕЛ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'а если нет': ['ДЖОУИ', 'МОНИКА', 'ЧЕНДЛЕР'],
#  'вы не знать': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ЧЕНДЛЕР'],
#  'ой отлично': ['ДЖОУИ', 'РЕЙЧЕЛ'],
#  'нет это не так': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'он идти': ['ДЖОУИ', 'РЕЙЧЕЛ', 'РОСС'],
#  'поехать': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'ой извинить': ['ДЖОУИ', 'РЕЙЧЕЛ', 'РОСС'],
#  'нет не думать': ['ДЖОУИ', 'РОСС'],
#  'ой здорово': ['ДЖОУИ', 'РЕЙЧЕЛ', 'МОНИКА'],
#  'только что звонить': ['ДЖОУИ', 'ЧЕНДЛЕР'],
#  'я знать': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'как у ты дело': ['ДЖОУИ', 'ЧЕНДЛЕР'],
#  'а да': ['ДЖОУИ', 'РЕЙЧЕЛ', 'МОНИКА', 'РОСС'],
#  'он': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'миссис уолтема': ['ДЖОУИ', 'ФИБИ'],
#  'хорошо всё пройти хорошо': ['ДЖОУИ', 'ЧЕНДЛЕР'],
#  'эй как дело': ['ДЖОУИ', 'РЕЙЧЕЛ', 'МОНИКА'],
#  'мочь я вы кой о чем спросить': ['ДЖОУИ', 'РЕЙЧЕЛ', 'РОСС'],
#  'эй это я': ['ДЖОУИ'],
#  'ага я пойти за цыплёнок': ['ДЖОУИ'],
#  'хотеть немного': ['ДЖОУИ'],
#  'это эээ': ['ДЖОУИ', 'РОСС'],
#  'что черта побрать это быть': ['ДЖОУИ', 'РЕЙЧЕЛ'],
#  'ладный фибс': ['ДЖОУИ', 'РОСС'],
#  'мой': ['ДЖОУИ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'вставать': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ЧЕНДЛЕР'],
#  'или': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'ну мочь немного': ['ДЖОУИ', 'МОНИКА'],
#  'нет пока нет': ['ДЖОУИ', 'РЕЙЧЕЛ', 'РОСС', 'ЧЕНДЛЕР'],
#  'добро пожаловать': ['ДЖОУИ', 'МОНИКА', 'РОСС'],
#  'рад ты видеть': ['ДЖОУИ', 'ФИБИ', 'МОНИКА', 'ЧЕНДЛЕР'],
#  'ты уверенный': ['ДЖОУИ', 'РЕЙЧЕЛ', 'РОСС', 'ЧЕНДЛЕР'],
#  'моника': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'который сейчас час': ['ДЖОУИ', 'РОСС', 'ЧЕНДЛЕР'],
#  'ты это не понравиться': ['ДЖОУИ', 'ЧЕНДЛЕР'],
#  'я же сказать ты': ['ДЖОУИ', 'ЧЕНДЛЕР'],
#  'какой разница': ['ДЖОУИ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'ты': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'привет мистер': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'ЧЕНДЛЕР'],
#  'ох ох ох': ['ДЖОУИ', 'РЕЙЧЕЛ', 'РОСС', 'ЧЕНДЛЕР'],
#  'иа ты': ['ДЖОУИ'],
#  'как': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'когда': ['ДЖОУИ', 'РЕЙЧЕЛ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'в лондон': ['ДЖОУИ', 'РОСС', 'ЧЕНДЛЕР'],
#  'но это большой дело': ['ДЖОУИ'],
#  'я должный комунибудь рассказать': ['ДЖОУИ'],
#  'бог это невероятно': ['ДЖОУИ'],
#  'думать я собираться взлететь': ['ДЖОУИ', 'РЕЙЧЕЛ'],
#  'ты с это согласный': ['ДЖОУИ', 'ФИБИ'],
#  'что он делать': ['ДЖОУИ', 'ЧЕНДЛЕР'],
#  'я взять': ['ДЖОУИ', 'РЕЙЧЕЛ', 'РОСС', 'ЧЕНДЛЕР'],
#  'понимать что я говорить': ['ДЖОУИ', 'ФИБИ'],
#  'понимать о чем я': ['ДЖОУИ', 'РЕЙЧЕЛ', 'МОНИКА', 'ЧЕНДЛЕР'],
#  'не уверенный': ['ДЖОУИ'],
#  'хорошо извинить': ['ДЖОУИ', 'РЕЙЧЕЛ', 'МОНИКА'],
#  'улыбка': ['ДЖОУИ'],
#  'нет смотреть': ['ДЖОУИ', 'РЕЙЧЕЛ'],
#  'вроде': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ЧЕНДЛЕР'],
#  'что с это делать': ['ДЖОУИ'],
#  'мой бог': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС'],
#  'не так ли': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'он знать': ['ДЖОУИ', 'ФИБИ'],
#  'определённо': ['ДЖОУИ', 'ФИБИ'],
#  'чувак хватить болтать и приготовить мы чай': ['ДЖОУИ'],
#  'да ладный же': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'РОСС', 'ЧЕНДЛЕР'],
#  'я хотеть это услышать': ['ДЖОУИ', 'РЕЙЧЕЛ'],
#  'он застрять': ['ДЖОУИ'],
#  'я надеть он чтобы напугать': ['ДЖОУИ'],
#  'простить': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'сработать': ['ДЖОУИ', 'ФИБИ', 'МОНИКА'],
#  'я напугать ты': ['ДЖОУИ', 'ЧЕНДЛЕР'],
#  'ну я': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ'],
#  'слово': ['ДЖОУИ', 'ЧЕНДЛЕР'],
#  'ты что': ['ДЖОУИ', 'РЕЙЧЕЛ', 'МОНИКА'],
#  'да быть': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС'],
#  'не думать': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'РОСС', 'ЧЕНДЛЕР'],
#  'я это нравиться': ['ДЖОУИ', 'РЕЙЧЕЛ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'я иметь в вид давать': ['ДЖОУИ', 'РЕЙЧЕЛ'],
#  'просто': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС'],
#  'я просто': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС'],
#  'тип': ['ДЖОУИ', 'ФИБИ'],
#  'в это есть смысл': ['ДЖОУИ', 'РЕЙЧЕЛ', 'МОНИКА', 'РОСС'],
#  'эээ моника': ['ДЖОУИ'],
#  'зачем вы это делать': ['ДЖОУИ', 'РЕЙЧЕЛ', 'МОНИКА'],
#  'здравствуйте мистер': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА'],
#  'я не мочь это сделать': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'ЧЕНДЛЕР'],
#  'ты бы сделать это для я': ['ДЖОУИ'],
#  'конец': ['ДЖОУИ', 'ФИБИ', 'РОСС', 'ЧЕНДЛЕР'],
#  'год': ['ДЖОУИ', 'РЕЙЧЕЛ', 'РОСС', 'ЧЕНДЛЕР'],
#  'хорошо я позаботиться о это': ['ДЖОУИ'],
#  'да быть бы здорово': ['ДЖОУИ', 'РЕЙЧЕЛ', 'МОНИКА', 'РОСС'],
#  'с ты всё в порядок': ['ДЖОУИ',
#   'РЕЙЧЕЛ',
#   'ФИБИ',
#   'МОНИКА',
#   'РОСС',
#   'ЧЕНДЛЕР'],
#  'ой правда': ['ДЖОУИ', 'МОНИКА', 'РОСС'],
#  'здесь нет': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'я не хотеть знать': ['ДЖОУИ', 'РОСС'],
#  'ммм': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'вы чтонибыть знать': ['ДЖОУИ', 'РЕЙЧЕЛ'],
#  'что ты знать': ['ДЖОУИ', 'ФИБИ', 'ЧЕНДЛЕР'],
#  'вы знать': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС'],
#  'слушать': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'ладный пойти': ['ДЖОУИ', 'МОНИКА'],
#  'он подключиться': ['ДЖОУИ'],
#  'ладный подождать': ['ДЖОУИ', 'ФИБИ', 'ЧЕНДЛЕР'],
#  'это хорошо': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'он явно сойти с ум': ['ДЖОУИ'],
#  'черта побрать': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'вытащить участник из изолятор': ['ДЖОУИ'],
#  'и они выключить': ['ДЖОУИ'],
#  'судейский правило нарушение нет': ['ДЖОУИ'],
#  'а утка получать ореховый масло': ['ДЖОУИ'],
#  'правило судья наттербаттер': ['ДЖОУИ'],
#  'вы иметь в вид мой мужской сумка': ['ДЖОУИ'],
#  'сначала я подумать что это просто хорошо выглядеть но это тоже практично': ['ДЖОУИ'],
#  'в немой есть отделение для весь ваш вещь': ['ДЖОУИ'],
#  'ваш кошелёк': ['ДЖОУИ'],
#  'твой ключ': ['ДЖОУИ'],
#  'ваш адресный книга': ['ДЖОУИ'],
#  'это не кошелёк': ['ДЖОУИ', 'РЕЙЧЕЛ'],
#  'женщина': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'ЧЕНДЛЕР'],
#  'ребёнок': ['ДЖОУИ', 'РОСС'],
#  'хорошо увидеться': ['ДЖОУИ', 'ФИБИ', 'МОНИКА'],
#  'мы сделать это': ['ДЖОУИ', 'РЕЙЧЕЛ', 'МОНИКА', 'РОСС'],
#  'да но знать что': ['ДЖОУИ', 'РЕЙЧЕЛ'],
#  'неважно кто что знать': ['ДЖОУИ'],
#  'теперь достаточно из мы знать что мы мочь просто сказать они что знать': ['ДЖОУИ'],
#  'тогда всё ложь и секрет наконец закончиться бы': ['ДЖОУИ'],
#  'я они не говорить': ['ДЖОУИ'],
#  'я бы сказать вы но они заставить я пообещать не рассказывать': ['ДЖОУИ'],
#  'они знать что вы знать': ['ДЖОУИ'],
#  'вы ещё не закончить': ['ДЖОУИ'],
#  'ох ладный': ['ДЖОУИ', 'ФИБИ', 'РОСС'],
#  'показать он свой бюстгальтер': ['ДЖОУИ'],
#  'он бояться бюстгальтер': ['ДЖОУИ'],
#  'они не мочь работать': ['ДЖОУИ'],
#  'я не в первый раз': ['ДЖОУИ'],
#  'ну это всё': ['ДЖОУИ'],
#  'каждый знать': ['ДЖОУИ'],
#  'он прямо здесь': ['ДЖОУИ', 'РЕЙЧЕЛ'],
#  'итак вы готовый к работа': ['ДЖОУИ', 'МОНИКА'],
#  'совсем не смешно': ['ДЖОУИ', 'МОНИКА'],
#  'не совсем': ['ДЖОУИ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'это интересно': ['ДЖОУИ', 'РЕЙЧЕЛ', 'РОСС', 'ЧЕНДЛЕР'],
#  'но знать что': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА'],
#  'вот он': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'очень смешно': ['ДЖОУИ', 'РЕЙЧЕЛ', 'МОНИКА', 'ЧЕНДЛЕР'],
#  'хорошо поехать': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'РОСС', 'ЧЕНДЛЕР'],
#  'это сработать': ['ДЖОУИ', 'ФИБИ', 'РОСС'],
#  'о чувак': ['ДЖОУИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'проклятие': ['ДЖОУИ', 'РЕЙЧЕЛ'],
#  'она вернуться': ['ДЖОУИ'],
#  'черта': ['ДЖОУИ', 'РЕЙЧЕЛ', 'МОНИКА', 'ЧЕНДЛЕР'],
#  'привет девочка': ['ДЖОУИ', 'РЕЙЧЕЛ'],
#  'горячий девушка': ['ДЖОУИ'],
#  'я это не знать': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ЧЕНДЛЕР'],
#  'ты понять': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'РОСС'],
#  'ты смеяться': ['ДЖОУИ', 'РЕЙЧЕЛ', 'РОСС', 'ЧЕНДЛЕР'],
#  'ой это здорово': ['ДЖОУИ', 'РЕЙЧЕЛ'],
#  'всё': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'РОСС', 'ЧЕНДЛЕР'],
#  'сказать они': ['ДЖОУИ', 'МОНИКА'],
#  'хм суп': ['ДЖОУИ'],
#  'привет бен': ['ДЖОУИ', 'ФИБИ', 'МОНИКА', 'РОСС'],
#  'без проблема': ['ДЖОУИ', 'ФИБИ', 'МОНИКА', 'ЧЕНДЛЕР'],
#  'хм суп с лапша': ['ДЖОУИ'],
#  'правдивый история': ['ДЖОУИ', 'РЕЙЧЕЛ'],
#  'всё улыбаться': ['ДЖОУИ'],
#  'вот и я': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ЧЕНДЛЕР'],
#  'знать знать': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'РОСС'],
#  'что я собираться делать': ['ДЖОУИ', 'РЕЙЧЕЛ', 'РОСС', 'ЧЕНДЛЕР'],
#  'это папа': ['ДЖОУИ', 'РЕЙЧЕЛ', 'РОСС'],
#  'я выходить': ['ДЖОУИ', 'РОСС', 'ЧЕНДЛЕР'],
#  'прямо там': ['ДЖОУИ', 'ФИБИ', 'МОНИКА', 'ЧЕНДЛЕР'],
#  'а что': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'не так': ['ДЖОУИ', 'ФИБИ', 'МОНИКА', 'РОСС'],
#  'всё складываться': ['ДЖОУИ', 'РОСС'],
#  'я бы никогда это не сделать': ['ДЖОУИ', 'РОСС'],
#  'чувак что ты делать': ['ДЖОУИ', 'РОСС'],
#  'эй а сколько сейчас время': ['ДЖОУИ', 'ЧЕНДЛЕР'],
#  'вы понимать что мы бросать этот мяч не ронять он уже около час': ['ДЖОУИ'],
#  'я понять это около полчаса назад но не хотеть ничего говорить потому что не хотеть сглазить': ['ДЖОУИ'],
#  'ой я думать я впервые пропустить обед': ['ДЖОУИ'],
#  'да штаны у я немного болтаться': ['ДЖОУИ'],
#  'это не кошка': ['ДЖОУИ'],
#  'я нужно в туалет': ['ДЖОУИ', 'РЕЙЧЕЛ'],
#  'мой тоже': ['ДЖОУИ', 'РЕЙЧЕЛ', 'МОНИКА'],
#  'это быть невероятно': ['ДЖОУИ', 'РЕЙЧЕЛ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'привет дружище как дело': ['ДЖОУИ', 'ЧЕНДЛЕР'],
#  'вы готовый к работа': ['ДЖОУИ', 'РОСС'],
#  'я стать миллионер': ['ДЖОУИ'],
#  'не верить': ['ДЖОУИ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'о чем ты': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА'],
#  'я это не нужно': ['ДЖОУИ', 'ЧЕНДЛЕР'],
#  'да вы шутить': ['ДЖОУИ', 'РЕЙЧЕЛ'],
#  'сколько': ['ДЖОУИ', 'МОНИКА', 'РОСС'],
#  'ой давать': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ЧЕНДЛЕР'],
#  'хорошо спасибо большой': ['ДЖОУИ', 'РОСС'],
#  'убить я': ['ДЖОУИ', 'ЧЕНДЛЕР'],
#  'я сейчас': ['ДЖОУИ', 'ЧЕНДЛЕР'],
#  'слушать мочь сделать я одолжение': ['ДЖОУИ', 'РОСС'],
#  'я слышать это': ['ДЖОУИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'не выходить сюда': ['ДЖОУИ'],
#  'она': ['ДЖОУИ', 'РЕЙЧЕЛ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'ребята': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'не смотреть на я': ['ДЖОУИ', 'РЕЙЧЕЛ'],
#  'ты мочь в это поверить': ['ДЖОУИ', 'ФИБИ', 'РОСС', 'ЧЕНДЛЕР'],
#  'вы не поверить': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА'],
#  'я найти свой идентичный близнец': ['ДЖОУИ'],
#  'мой идентичный близнец': ['ДЖОУИ'],
#  'у ты получиться': ['ДЖОУИ', 'МОНИКА'],
#  'я это большой не нужно': ['ДЖОУИ'],
#  'как поживать': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'воу воу': ['ДЖОУИ', 'РЕЙЧЕЛ'],
#  'вы не мочь это сделать': ['ДЖОУИ', 'РЕЙЧЕЛ', 'МОНИКА', 'РОСС'],
#  'торопиться': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС'],
#  'ну что ж': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'быть здорово': ['ДЖОУИ', 'МОНИКА'],
#  'это здорово': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'не говорить': ['ДЖОУИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'я большой не мочь это выносить': ['ДЖОУИ', 'МОНИКА', 'ЧЕНДЛЕР'],
#  'наземный контроль майор тот': ['ДЖОУИ', 'ЧЕНДЛЕР'],
#  'начинаться обратный отсчёт двигатель включить': ['ДЖОУИ', 'ЧЕНДЛЕР'],
#  'я так жаль': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'хорошо спасибо': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'это невероятно': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'до скорый': ['ДЖОУИ', 'РОСС'],
#  'бог': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'а вот и она': ['ДЖОУИ', 'РОСС'],
#  'или нет': ['ДЖОУИ', 'ФИБИ', 'МОНИКА', 'РОСС'],
#  'очень хорошо': ['ДЖОУИ', 'РЕЙЧЕЛ', 'МОНИКА', 'РОСС'],
#  'ой простить': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'РОСС', 'ЧЕНДЛЕР'],
#  'дать посмотреть': ['ДЖОУИ', 'МОНИКА', 'РОСС'],
#  'не мочь поверить в это': ['ДЖОУИ', 'ФИБИ', 'МОНИКА', 'РОСС'],
#  'ублюдок': ['ДЖОУИ', 'ЧЕНДЛЕР'],
#  'ну у я быть ослеплять боль в живот когда я поднимать тяжесть ранний потом я потерять сознание и с тот пора не мочь встать': ['ДЖОУИ'],
#  'но я не думать что это чтоть серьёзный': ['ДЖОУИ'],
#  'послушать если я прийтись пойти к врач изз чеготь это быть изз тот что этот штука торчать из мой живот': ['ДЖОУИ'],
#  'черта взять': ['ДЖОУИ', 'ФИБИ', 'ЧЕНДЛЕР'],
#  'у я для ты сюрприз': ['ДЖОУИ', 'РОСС', 'ЧЕНДЛЕР'],
#  'позаботиться о мамесын': ['ДЖОУИ'],
#  'неа': ['ДЖОУИ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'да я тоже': ['ДЖОУИ', 'ФИБИ', 'МОНИКА', 'ЧЕНДЛЕР'],
#  'как дело у': ['ДЖОУИ', 'РЕЙЧЕЛ'],
#  'я бы хотеть показать ты но я только что уложить она': ['ДЖОУИ'],
#  'она спать': ['ДЖОУИ', 'РЕЙЧЕЛ', 'МОНИКА'],
#  'эй два девушка не мочь бы вы пойти выпить': ['ДЖОУИ'],
#  'забыть это': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'РОСС', 'ЧЕНДЛЕР'],
#  'что далёкий': ['ДЖОУИ', 'ФИБИ'],
#  'вот оно': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'получать и': ['ДЖОУИ'],
#  'вы знать что я думать': ['ДЖОУИ', 'РОСС'],
#  'танцовщица': ['ДЖОУИ'],
#  'о бог да': ['ДЖОУИ', 'МОНИКА'],
#  'моника убить ты': ['ДЖОУИ', 'ЧЕНДЛЕР'],
#  'в чем твой секрет': ['ДЖОУИ', 'РОСС'],
#  'я милый': ['ДЖОУИ', 'РОСС'],
#  'я видеть что случиться': ['ДЖОУИ'],
#  'это потому что я пытаться оттолкнуть ты': ['ДЖОУИ'],
#  'поверьте вы бы почувствовать себя подругий если бы я он включить': ['ДЖОУИ'],
#  'хорошо ты право': ['ДЖОУИ', 'РЕЙЧЕЛ', 'МОНИКА', 'РОСС'],
#  'почему ты так сказать': ['ДЖОУИ'],
#  'это просто подло': ['ДЖОУИ'],
#  'это не то что вы сказать': ['ДЖОУИ'],
#  'вы так сказать': ['ДЖОУИ'],
#  'бог мой я женщина': ['ДЖОУИ'],
#  'так и должный быть': ['ДЖОУИ', 'ФИБИ', 'ЧЕНДЛЕР'],
#  'мочь я поговорить с вы на секунда': ['ДЖОУИ', 'ЧЕНДЛЕР'],
#  'я нравиться': ['ДЖОУИ', 'РОСС'],
#  'что не нравиться': ['ДЖОУИ', 'МОНИКА'],
#  'заварной крем': ['ДЖОУИ'],
#  'мясо': ['ДЖОУИ', 'ЧЕНДЛЕР'],
#  'это не большой дело': ['ДЖОУИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'ой ой': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'РОСС'],
#  'ага ладный': ['ДЖОУИ', 'ФИБИ', 'ЧЕНДЛЕР'],
#  'устать': ['ДЖОУИ', 'ФИБИ'],
#  'мля': ['ДЖОУИ', 'МОНИКА'],
#  'наверное': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'слизь': ['ДЖОУИ'],
#  'достаточно': ['ДЖОУИ', 'МОНИКА', 'РОСС'],
#  'они': ['ДЖОУИ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'я быть в порядок': ['ДЖОУИ', 'РЕЙЧЕЛ'],
#  'вы правый': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС'],
#  'знать что мы делать': ['ДЖОУИ', 'МОНИКА'],
#  'нет это': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС'],
#  'не очень': ['ДЖОУИ', 'РЕЙЧЕЛ', 'РОСС', 'ЧЕНДЛЕР'],
#  'я дочитать книга': ['ДЖОУИ', 'МОНИКА'],
#  'я не отвечать на это': ['ДЖОУИ', 'ЧЕНДЛЕР'],
#  'большой': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'это быть доллар': ['ДЖОУИ', 'РЕЙЧЕЛ'],
#  'с днм рождение ты': ['ДЖОУИ'],
#  'хотеть': ['ДЖОУИ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'это не хорошо': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ'],
#  'фильм': ['ДЖОУИ', 'ФИБИ'],
#  'назад': ['ДЖОУИ', 'РЕЙЧЕЛ'],
#  'здорово': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'это быть бы прекрасно': ['ДЖОУИ', 'РЕЙЧЕЛ', 'РОСС'],
#  'давать сделать это': ['ДЖОУИ',
#   'РЕЙЧЕЛ',
#   'ФИБИ',
#   'МОНИКА',
#   'РОСС',
#   'ЧЕНДЛЕР'],
#  'всегда приятно познакомиться с фанат': ['ДЖОУИ'],
#  'ну как дело': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'ЧЕНДЛЕР'],
#  'большой спасибо': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС'],
#  'с она всё быть в порядок': ['ДЖОУИ', 'РЕЙЧЕЛ'],
#  'очень жаль': ['ДЖОУИ', 'МОНИКА'],
#  'а как насчёт это': ['ДЖОУИ', 'РОСС'],
#  'ты хороший': ['ДЖОУИ', 'ФИБИ', 'МОНИКА'],
#  'четверг': ['ДЖОУИ'],
#  'понедельник один день': ['ДЖОУИ'],
#  'вторник два день': ['ДЖОУИ'],
#  'и эй': ['ДЖОУИ', 'РОСС'],
#  'не беспокоиться о это': ['ДЖОУИ', 'ФИБИ', 'МОНИКА', 'ЧЕНДЛЕР'],
#  'вы у': ['ДЖОУИ'],
#  'ладный не тратить зря я иметь ввиду это ещё еда': ['ДЖОУИ'],
#  'эй вот и всё': ['ДЖОУИ'],
#  'чт': ['ДЖОУИ', 'РЕЙЧЕЛ', 'МОНИКА', 'РОСС'],
#  'ах ах': ['ДЖОУИ', 'РЕЙЧЕЛ'],
#  'так близко': ['ДЖОУИ', 'РЕЙЧЕЛ'],
#  'сломаться холодильник': ['ДЖОУИ'],
#  'я должный есть всё': ['ДЖОУИ'],
#  'мясной ассорти мороженое лайм': ['ДЖОУИ'],
#  'большой нет': ['ДЖОУИ', 'МОНИКА', 'ЧЕНДЛЕР'],
#  'что черта взять я делать': ['ДЖОУИ'],
#  'просить прощение': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'ну что ты знать': ['ДЖОУИ', 'ЧЕНДЛЕР'],
#  'сломать': ['ДЖОУИ', 'РЕЙЧЕЛ', 'РОСС'],
#  'назвать это даже': ['ДЖОУИ', 'ЧЕНДЛЕР'],
#  'я быть здесь': ['ДЖОУИ', 'РОСС', 'ЧЕНДЛЕР'],
#  'да ладный вы ребята': ['ДЖОУИ', 'РЕЙЧЕЛ', 'РОСС'],
#  'хорошо я уходить отсюда': ['ДЖОУИ', 'РЕЙЧЕЛ'],
#  'я удача': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'ЧЕНДЛЕР'],
#  'не брать в голова': ['ДЖОУИ', 'РЕЙЧЕЛ', 'МОНИКА'],
#  'час': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ЧЕНДЛЕР'],
#  'я получить роль': ['ДЖОУИ', 'ФИБИ'],
#  'ладный извинить': ['ДЖОУИ', 'РЕЙЧЕЛ', 'МОНИКА'],
#  'значит': ['ДЖОУИ', 'ФИБИ', 'ЧЕНДЛЕР'],
#  'да ты право': ['ДЖОУИ', 'ФИБИ', 'МОНИКА', 'РОСС'],
#  'невероятный': ['ДЖОУИ', 'МОНИКА'],
#  'глупый': ['ДЖОУИ', 'ФИБИ'],
#  'я не мочь в это поверить': ['ДЖОУИ',
#   'РЕЙЧЕЛ',
#   'ФИБИ',
#   'МОНИКА',
#   'РОСС',
#   'ЧЕНДЛЕР'],
#  'ненавидеть ты': ['ДЖОУИ', 'РЕЙЧЕЛ'],
#  'что вы нужно': ['ДЖОУИ', 'ЧЕНДЛЕР'],
#  'сыр': ['ДЖОУИ', 'МОНИКА', 'ЧЕНДЛЕР'],
#  'ладный смотреть': ['ДЖОУИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'ты там': ['ДЖОУИ', 'РЕЙЧЕЛ', 'РОСС'],
#  'неужели': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'я это не делать': ['ДЖОУИ', 'ФИБИ', 'РОСС', 'ЧЕНДЛЕР'],
#  'я встречаться с она': ['ДЖОУИ', 'РОСС'],
#  'всё время': ['ДЖОУИ', 'ФИБИ'],
#  'мой задний карман': ['ДЖОУИ'],
#  'это быть весело': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'ЧЕНДЛЕР'],
#  'мочь я вы коечто сказать': ['ДЖОУИ', 'РОСС'],
#  'нравиться': ['ДЖОУИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'я тоже пойти': ['ДЖОУИ', 'ФИБИ'],
#  'я выиграть': ['ДЖОУИ', 'ФИБИ'],
#  'я угадать': ['ДЖОУИ', 'РОСС'],
#  'у я нет': ['ДЖОУИ', 'РЕЙЧЕЛ', 'МОНИКА', 'ЧЕНДЛЕР'],
#  'это мой': ['ДЖОУИ', 'МОНИКА', 'РОСС'],
#  'где ты черта взять быть': ['ДЖОУИ', 'РЕЙЧЕЛ', 'МОНИКА', 'РОСС'],
#  'нет не быть': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'РОСС', 'ЧЕНДЛЕР'],
#  'выбрать я': ['ДЖОУИ', 'РОСС', 'ЧЕНДЛЕР'],
#  'она уйти': ['ДЖОУИ', 'ФИБИ', 'РОСС'],
#  'я сделать': ['ДЖОУИ', 'РОСС', 'ЧЕНДЛЕР'],
#  'а можно ещё': ['ДЖОУИ'],
#  'мы умирать здесь': ['ДЖОУИ'],
#  'ого спасибо': ['ДЖОУИ', 'РЕЙЧЕЛ'],
#  'сегодня': ['ДЖОУИ', 'РЕЙЧЕЛ'],
#  'один раз': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ'],
#  'вот дерьмо': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС'],
#  'а она': ['ДЖОУИ', 'ФИБИ', 'РОСС'],
#  'хорошо я тоже': ['ДЖОУИ', 'РОСС'],
#  'хорошо я пойти': ['ДЖОУИ', 'ФИБИ'],
#  'а знать что': ['ДЖОУИ', 'РЕЙЧЕЛ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  'сделать': ['ДЖОУИ', 'РЕЙЧЕЛ', 'МОНИКА', 'РОСС'],
#  'это тело': ['ДЖОУИ', 'ЧЕНДЛЕР'],
#  'глаз': ['ДЖОУИ'],
#  'мочь': ['ДЖОУИ', 'ФИБИ', 'МОНИКА', 'РОСС', 'ЧЕНДЛЕР'],
#  ...}

# %%
df_vc = df_["Base_Phrase"].value_counts()
df_vc = df_vc[df_vc > 1]
vc = df_vc.to_dict()
vc
# Out:
# {'': 2584,
#  'хорошо': 1995,
#  'привет': 1990,
#  'ага': 1680,
#  'нет': 1205,
#  'что': 1063,
#  'ой': 734,
#  'бог мой': 602,
#  'да': 475,
#  'спасибо': 431,
#  'ух ты': 348,
#  'знать': 292,
#  'отлично': 282,
#  'в сам дело': 279,
#  'верно': 253,
#  'эй': 247,
#  'давать': 236,
#  'знать что': 219,
#  'почему': 218,
#  'это': 187,
#  'не знать': 181,
#  'конечно': 177,
#  'угу': 158,
#  'хм': 146,
#  'всё в порядок': 146,
#  'а': 142,
#  'какой': 136,
#  'ты знать': 134,
#  'простить': 131,
#  'ого': 130,
#  'здравствуйте': 128,
#  'я': 127,
#  'фиби': 116,
#  'пожалуйста': 108,
#  'о бог': 100,
#  'я тоже': 99,
#  'привет ребята': 94,
#  'ох': 94,
#  'ничего страшный': 94,
#  'ладный': 92,
#  'о нет': 92,
#  'итак': 88,
#  'да ладный': 86,
#  'что это': 86,
#  'как дело': 84,
#  'что случиться': 84,
#  'пока': 83,
#  'извинить': 78,
#  'я знать': 76,
#  'моника': 75,
#  'я жаль': 73,
#  'да конечно': 66,
#  'что происходить': 65,
#  'бог': 64,
#  'понятно': 63,
#  'нет нет': 63,
#  'я очень жаль': 63,
#  'подождать': 62,
#  'ничего': 58,
#  'видеть': 58,
#  'действительно': 57,
#  'до свидание': 56,
#  'что ты делать': 56,
#  'ура': 55,
#  'ну вот': 55,
#  'здесь': 55,
#  'хорошо хорошо': 53,
#  'ооо': 53,
#  'ну ладный': 52,
#  'готовый': 51,
#  'около': 51,
#  'идти': 51,
#  'совершенно верно': 51,
#  'погодить': 50,
#  'вот и всё': 47,
#  'ждать': 47,
#  'ладный ладный': 47,
#  'я в порядок': 44,
#  'о чем ты говорить': 43,
#  'да да': 43,
#  'прекратить': 42,
#  'почему бы и нет': 42,
#  'ты в порядок': 42,
#  'замечательный': 42,
#  'эээ': 41,
#  'нет нет нет': 41,
#  'просить прощение': 41,
#  'понять': 40,
#  'ну': 40,
#  'ребята': 39,
#  'это я': 39,
#  'ух': 38,
#  'где': 38,
#  'блин': 38,
#  'я понять': 37,
#  'фу': 37,
#  'неужели': 36,
#  'что ты здесь делать': 35,
#  'чувак': 34,
#  'я любить вы': 34,
#  'о да': 34,
#  'и': 33,
#  'не мочь': 33,
#  'чем заниматься': 32,
#  'ты': 32,
#  'кто': 31,
#  'да верно': 31,
#  'ах': 30,
#  'черта побрать': 30,
#  'я сделать это': 29,
#  'вы издеваться': 29,
#  'что с ты': 29,
#  'да ладный же': 28,
#  'думать да': 28,
#  'почему нет': 28,
#  'ха': 28,
#  'быть': 27,
#  'я всё равно': 27,
#  'что делать': 26,
#  'ой спасибо': 26,
#  'послать': 26,
#  'посмотреть': 26,
#  'спокойный ночь': 26,
#  'да это так': 26,
#  'вот так': 26,
#  'в чем дело': 26,
#  'поехать': 26,
#  'ты право': 25,
#  'марсель': 25,
#  'идти сюда': 25,
#  'я любить ты': 25,
#  'ты серьёзно': 25,
#  'не думать': 25,
#  'вот': 25,
#  'большой спасибо': 25,
#  'что я делать': 24,
#  'это здорово': 24,
#  'это безумие': 24,
#  'мочь быть': 23,
#  'удача': 23,
#  'добрый утро': 23,
#  'увидеться': 23,
#  'всё быть хорошо': 23,
#  'постоять': 23,
#  'вы уверить': 23,
#  'как поживать': 23,
#  'как': 23,
#  'ммм': 23,
#  'это оно': 23,
#  'привет милый': 23,
#  'я знать это': 23,
#  'большой': 23,
#  'как мило': 23,
#  'да знать': 22,
#  'не надо': 22,
#  'ничего такой': 22,
#  'ну да': 22,
#  'это хорошо': 22,
#  'ах да': 22,
#  'смотреть': 22,
#  'я просто': 21,
#  'всё': 21,
#  'ты шутить': 21,
#  'он': 21,
#  'не мочь поверить': 21,
#  'вау': 21,
#  'я не мочь в это поверить': 21,
#  'есть': 21,
#  'поздравлять': 21,
#  'ни за что': 21,
#  'я не знать': 20,
#  'что вы иметь в вид': 20,
#  'но': 20,
#  'садиться': 20,
#  'ну пожалуйста': 20,
#  'я не мочь': 20,
#  'кто такой': 20,
#  'сюда': 19,
#  'я не мочь это сделать': 19,
#  'правда': 18,
#  'не так ли': 18,
#  'ладный пока': 18,
#  'папа': 18,
#  'вы': 18,
#  'эй эй': 18,
#  'это так здорово': 18,
#  'я не': 18,
#  'кто это': 18,
#  'хорошо хорошо хорошо': 18,
#  'уф': 18,
#  'послушать': 18,
#  'с ты всё в порядок': 17,
#  'посмотреть на это': 17,
#  'нет это не так': 17,
#  'мы': 17,
#  'наверное': 17,
#  'вы с ум сойти': 17,
#  'милый': 17,
#  'серьёзно': 17,
#  'джо': 17,
#  'вперёд': 17,
#  'ааа': 17,
#  'как всё пройти': 17,
#  'или': 17,
#  'круто': 17,
#  'это быть': 17,
#  'всё нормально': 17,
#  'нет нет нет нет': 16,
#  'хорошо поехать': 16,
#  'хороший': 16,
#  'хорошо спасибо': 16,
#  'я так жаль': 16,
#  'помнить': 16,
#  'где ты быть': 16,
#  'вот оно': 16,
#  'два': 16,
#  'о': 16,
#  'выходить': 16,
#  'сейчас': 16,
#  'ладный поехать': 16,
#  'что это быть': 15,
#  'она': 15,
#  'это неправда': 15,
#  'чт': 15,
#  'подождать минута': 15,
#  'проверить это': 15,
#  'продолжать': 15,
#  'ой мужик': 15,
#  'это ты': 15,
#  'я мочь это сделать': 15,
#  'вы правый': 15,
#  'нет спасибо': 15,
#  'ой хорошо': 15,
#  'да я знать': 15,
#  'и что': 15,
#  'а ты': 14,
#  'здорово': 14,
#  'немного': 14,
#  'вот он': 14,
#  'погодить погодить': 14,
#  'а почему бы и нет': 14,
#  'черта': 14,
#  'заходить': 14,
#  'я уходить': 14,
#  'один': 14,
#  'дженис': 14,
#  'привет как дело': 14,
#  'я иметь в вид': 14,
#  'понимать': 13,
#  'ага да': 13,
#  'ладный знать что': 13,
#  'как вы думать': 13,
#  'это ужасно': 13,
#  'что ты собираться делать': 13,
#  'нет проблема': 13,
#  'думать': 13,
#  'верить': 13,
#  'а знать что': 13,
#  'вот ты где': 13,
#  'потому что': 13,
#  'слава бог': 13,
#  'дада': 12,
#  'о слава бог': 12,
#  'у ты всё нормально': 12,
#  'красиво': 12,
#  'ох ох': 12,
#  'мочь': 12,
#  'я серьёзно': 12,
#  'кей': 12,
#  'ну да ладный': 12,
#  'заткнуться': 12,
#  'то есть': 12,
#  'знать знать': 12,
#  'мой': 12,
#  'это смешно': 12,
#  'ой простить': 12,
#  'спасибо чувак': 12,
#  'ну что ж': 12,
#  'это всё': 12,
#  'хорошо знать что': 12,
#  'ну знать что': 12,
#  'неа': 12,
#  'это не': 12,
#  'понятие не иметь': 12,
#  'когда': 12,
#  'ой ой': 11,
#  'хотеть': 11,
#  'это невероятно': 11,
#  'стоп': 11,
#  'привет привет': 11,
#  'привет это': 11,
#  'да быть': 11,
#  'абсолютно': 11,
#  'гм': 11,
#  'не совсем': 11,
#  'о привет': 11,
#  'это правда': 11,
#  'это так мило': 11,
#  'так': 11,
#  'нет не мочь': 11,
#  'не мочь поверить в это': 11,
#  'что это такой': 11,
#  'сделать это': 11,
#  'я тоже ты любить': 11,
#  'я делать': 11,
#  'это не так': 11,
#  'вы серьёзно': 11,
#  'увидеться поздний': 11,
#  'нет не быть': 11,
#  'прямо там': 11,
#  'пн': 10,
#  'забыть это': 10,
#  'стрелять': 10,
#  'странно': 10,
#  'шутить': 10,
#  'очень хорошо': 10,
#  'всё хорошо': 10,
#  'давать давать': 10,
#  'подумать': 10,
#  'мой бог': 10,
#  'держать': 10,
#  'что ты сказать': 10,
#  'убираться отсюда': 10,
#  'хорошо пока': 10,
#  'доллар': 10,
#  'ну вот и всё': 10,
#  'кэти': 10,
#  'я быть': 10,
#  'попасться': 10,
#  'ещё нет': 10,
#  'просто': 10,
#  'о я знать': 10,
#  'что мы быть делать': 10,
#  'о спасибо': 10,
#  'ну конечно': 10,
#  'привет я': 10,
#  'мама': 10,
#  'торопиться': 10,
#  'а также': 9,
#  'о нетнетнуть': 9,
#  'невероятно': 9,
#  'хорошо смотреть': 9,
#  'да я тоже': 9,
#  'что ещё': 9,
#  'это нормально': 9,
#  'аа': 9,
#  'привет папа': 9,
#  'как она': 9,
#  'о ага': 9,
#  'вы парень': 9,
#  'приятно познакомиться': 9,
#  'поздний': 9,
#  'доктор': 9,
#  'нет погодить': 9,
#  'давать сделать это': 9,
#  'что ты говорить': 9,
#  'хорошо отлично': 9,
#  'ничего подобный': 9,
#  'давать росс': 9,
#  'обещать': 9,
#  'я идти': 9,
#  'никогда': 9,
#  'вставать': 9,
#  'это потрясающе': 9,
#  'о чем': 9,
#  'да это быть': 9,
#  'ой ой ой': 9,
#  'это отстой': 9,
#  'там': 9,
#  'всегда': 9,
#  'что это за хрень': 9,
#  'ужасно': 9,
#  'я росс': 9,
#  'не делать это': 9,
#  'отличный идея': 9,
#  'вы знать': 9,
#  'а что насчёт': 8,
#  'о нет нет нет': 8,
#  'хорошо я сделать это': 8,
#  'откуда ты знать': 8,
#  'смотреть смотреть': 8,
#  'нет не знать': 8,
#  'я скоро вернуться': 8,
#  'о бог мой': 8,
#  'ты что': 8,
#  'ладный давать': 8,
#  'не верить': 8,
#  'о знать что': 8,
#  'что я сказать': 8,
#  'какой разница': 8,
#  'ты уверенный': 8,
#  'помощь': 8,
#  'ой извинить': 8,
#  'с удовольствие': 8,
#  'эй что происходить': 8,
#  'о нет нет': 8,
#  'хороший идея': 8,
#  'привет это я': 8,
#  'я это нравиться': 8,
#  'куда ты идти': 8,
#  'ну что': 8,
#  'это не смешно': 8,
#  'забавно': 8,
#  'что ты иметь в вид': 8,
#  'не мочь в это поверить': 8,
#  'нравиться': 8,
#  'мужик': 8,
#  'вот она': 8,
#  'никто': 8,
#  'ты выйти за я замуж': 8,
#  'я право': 8,
#  'я не понимать': 8,
#  'вы мочь в это поверить': 8,
#  'ри': 8,
#  'да я': 8,
#  'я это знать': 8,
#  'интересно': 8,
#  'слушать': 8,
#  'конечно да': 8,
#  'конечно конечно': 8,
#  'да правда': 8,
#  'а почему': 8,
#  'весь привет': 8,
#  'да пожалуйста': 8,
#  'ага ладный': 8,
#  'и знать что': 8,
#  'всё это': 8,
#  'это быть весело': 8,
#  'здесь нет': 8,
#  'это просто': 8,
#  'не волноваться': 8,
#  'неважно': 7,
#  'что я собираться делать': 7,
#  'а что': 7,
#  'привет мистер': 7,
#  'происходить': 7,
#  'думать ты право': 7,
#  'да есть': 7,
#  'быть весело': 7,
#  'посмотреть на я': 7,
#  'да да да': 7,
#  'ни в кой случай': 7,
#  'хорошо я идти': 7,
#  'я пойти': 7,
#  'обожать': 7,
#  'а теперь': 7,
#  'да ничего страшный': 7,
#  'я так не думать': 7,
#  'я ты любить': 7,
#  'вроде': 7,
#  'она спать': 7,
#  'год': 7,
#  'я действительно так делать': 7,
#  'она мой': 7,
#  'что мы делать': 7,
#  'вы это видеть': 7,
#  'понимать о чем я': 7,
#  'он идти': 7,
#  'это так несправедливый': 7,
#  'это так увлекательно': 7,
#  'хорошо идти': 7,
#  'и ты': 7,
#  'упс': 7,
#  'с': 7,
#  'что это значит': 7,
#  'о это быть здорово': 7,
#  'спасибо ребята': 7,
#  'всё конченый': 7,
#  'перерыв': 7,
#  'не беспокоиться о это': 7,
#  'звучать здорово': 7,
#  'я здесь': 7,
#  'они': 7,
#  'ну нет': 7,
#  'это не мой': 7,
#  'помочь я': 7,
#  'ты это слышать': 7,
#  'ты тоже': 7,
#  'ой погодить': 7,
#  'вы видеть': 7,
#  'ой смотреть': 7,
#  'шутка в сторона': 7,
#  'быть бы здорово': 7,
#  'не говорить': 7,
#  'разве это не здорово': 7,
#  'расслабиться': 7,
#  'ну что ж посмотреть': 7,
#  'отлично выглядеть': 7,
#  'не быть': 7,
#  'это круто': 7,
#  'ну и что': 7,
#  'мелкий': 6,
#  'вот увидеть': 6,
#  'да нет': 6,
#  'ты сделать': 6,
#  'посмотреть на себя': 6,
#  'ну не знать': 6,
#  'секундочка': 6,
#  'случиться': 6,
#  'бежать': 6,
#  'что быть делать': 6,
#  'это и': 6,
#  'ну я': 6,
#  'да это': 6,
#  'оп': 6,
#  'о чем вы думать': 6,
#  'я пора': 6,
#  'а я': 6,
#  'утро': 6,
#  'дать я': 6,
#  'привет пн': 6,
#  'хорошо быть': 6,
#  'ага детка': 6,
#  'так что ты думать': 6,
#  'она идти': 6,
#  'да мочь быть': 6,
#  'она звать': 6,
#  'ребята что вы делать': 6,
#  'ой здорово': 6,
#  'о чувак': 6,
#  'сукин сын': 6,
#  'полностью': 6,
#  'здравствуйте мистер': 6,
#  'и что ты собираться делать': 6,
#  'а это': 6,
#  'да ничего': 6,
#  'это быть невероятно': 6,
#  'сколько': 6,
#  'да но': 6,
#  'берт': 6,
#  'я это не знать': 6,
#  'да ты право': 6,
#  'нет это': 6,
#  'четыре': 6,
#  'это не большой дело': 6,
#  'ты понять': 6,
#  'хорошо давать': 6,
#  'вы помнить': 6,
#  'мой глаз': 6,
#  'не уходить': 6,
#  'я взять': 6,
#  'забыть': 6,
#  'о хорошо': 6,
#  'чточто ты делать': 6,
#  'я любить она': 6,
#  'прямо здесь': 6,
#  'ты такой милый': 6,
#  'ой привет': 6,
#  'ладный до свидание': 6,
#  'это быть здорово': 6,
#  'достаточно': 6,
#  'мужчина': 6,
#  'неплохо': 6,
#  'помочь': 6,
#  'да спасибо': 6,
#  'простить простить': 6,
#  'нет всё в порядок': 6,
#  'вы это слышать': 6,
#  'ты здесь делать': 6,
#  'привет бен': 6,
#  'я тоже жаль': 6,
#  'да наверное': 6,
#  'ты должный я помочь': 6,
#  'с день рождение': 6,
#  'это интересно': 6,
#  'эй как дело': 6,
#  'чендлера и': 6,
#  'какой черта ты делать': 6,
#  'разве что': 6,
#  'у я есть': 6,
#  'ладный смотреть': 6,
#  'как ты себя чувствовать': 6,
#  'вот дерьмо': 6,
#  'ну ммм': 6,
#  'много': 6,
#  'не правда ли': 6,
#  'вето': 6,
#  'как ты': 6,
#  'я это видеть': 6,
#  'да уж': 6,
#  'ты хороший': 6,
#  'счастливый день благодарение': 6,
#  'я скучать по': 6,
#  'нет серьёзно': 6,
#  'нет я серьёзно': 6,
#  'да я уверенный': 6,
#  'что что': 6,
#  'она право': 6,
#  'не очень хорошо': 6,
#  'да это правда': 6,
#  'а как насчёт': 6,
#  'еда': 6,
#  'что сказать': 6,
#  'возможно': 6,
#  'это невозможно': 6,
#  'она уйти': 6,
#  'но вы знать что': 6,
#  'как это': 6,
#  'прекрасно': 6,
#  'да хорошо': 6,
#  'ну вообщеть': 6,
#  'это он': 6,
#  'это не сработать': 6,
#  'да хватить': 6,
#  'в это есть смысл': 5,
#  'хорошо ты право': 5,
#  'сделать': 5,
#  'это плохо': 5,
#  'не ты': 5,
#  'если только': 5,
#  'ой как мило': 5,
#  'это огромный': 5,
#  'ладный ладный ладный': 5,
#  'это не правильно': 5,
#  'действительно быть': 5,
#  'большой нет': 5,
#  'вы не мочь': 5,
#  'это так': 5,
#  'ладный всё': 5,
#  'нет не надо': 5,
#  'минутка': 5,
#  'хорошо извинить': 5,
#  'не знать не знать': 5,
#  'что у вы там': 5,
#  'он право': 5,
#  'я удача': 5,
#  'хорошо хорошо хорошо хорошо': 5,
#  'нет подождать': 5,
#  'ложка': 5,
#  'для что': 5,
#  'не понимать': 5,
#  'нет не совсем': 5,
#  'один секунда': 5,
#  'человек': 5,
#  'но знать что': 5,
#  'дать посмотреть': 5,
#  'до скорый': 5,
#  'успокоиться': 5,
#  'у я всё хорошо': 5,
#  'о мой бог': 5,
#  'это так сложно': 5,
#  'нет конечно': 5,
#  'вместе': 5,
#  'это кто': 5,
#  'я любить': 5,
#  'весь': 5,
#  'у мы быть перерыв': 5,
#  'ну что это': 5,
#  'не так': 5,
#  'ты псих': 5,
#  'это так странно': 5,
#  'пойти': 5,
#  'ты готовый': 5,
#  'да какой разница': 5,
#  'вверх': 5,
#  'ага знать что': 5,
#  'легко': 5,
#  'вы не знать': 5,
#  'а если нет': 5,
#  'я звать': 5,
#  'секс': 5,
#  'я любить это': 5,
#  'хорошо готовый': 5,
#  'точно': 5,
#  'спасибо большой': 5,
#  'в лондон': 5,
#  'прохладный': 5,
#  'запустить': 5,
#  'он такой милый': 5,
#  'ох ладный': 5,
#  'это весело': 5,
#  'посмотреть на он': 5,
#  'что не так': 5,
#  'о чем ты': 5,
#  'ты нравиться': 5,
#  'вопрос': 5,
#  'спасибо спасибо': 5,
#  'ладный подождать': 5,
#  'привет мама': 5,
#  'открыть это': 5,
#  'ничего не делать': 5,
#  'ты я нужный': 5,
#  'это быть потрясающе': 5,
#  'кто отец': 5,
#  'куда ты': 5,
#  'я должный идти': 5,
#  'вы не поверить': 5,
#  'отменить': 5,
#  'извинить я опоздать': 5,
#  'маленький': 5,
#  'я достать': 5,
#  'ой бог': 5,
#  'черта взять': 5,
#  'я не знать что я делать': 5,
#  'это мой': 5,
#  'ты знать почему': 5,
#  'или нет': 5,
#  'у я нет': 5,
#  'а да': 5,
#  'что за': 5,
#  'хороший попытка': 5,
#  'мы сделать это': 5,
#  'очень хороший': 5,
#  'ладный извинить': 5,
#  'так хороший': 5,
#  'без проблема': 5,
#  'у мы всё хорошо': 5,
#  'а я нет': 5,
#  'нет пока нет': 5,
#  'поиграть в': 5,
#  'о вот оно': 5,
#  'дать я это': 5,
#  'я это не делать': 5,
#  'нет я в порядок': 5,
#  'можно': 5,
#  'не знать что сказать': 5,
#  'ты мочь в это поверить': 5,
#  'да ладный ребята': 5,
#  'парень': 5,
#  'джошуа': 5,
#  'не очень': 5,
#  'клясться': 5,
#  'да быть бы здорово': 5,
#  'что вы делать': 5,
#  'ну как дело': 5,
#  'отдать': 5,
#  'где это': 5,
#  'очень смешно': 5,
#  'нет знать': 5,
#  'с кто': 5,
#  'не пойти': 5,
#  'это мой шутка': 5,
#  'беречь себя': 5,
#  'да ладный вы ребята': 5,
#  'ага привет': 5,
#  'о что': 5,
#  'мочь я вы кой о чем спросить': 5,
#  'вовсе нет': 5,
#  'эй погодить': 5,
#  'ладный ребята': 5,
#  'да всё быть хорошо': 5,
#  'подождать минутка': 5,
#  'ву': 5,
#  'ничего не мочь поделать': 4,
#  'клод': 4,
#  'он здесь': 4,
#  'я голодный': 4,
#  'уходить': 4,
#  'я пойти с ты': 4,
#  'бог мой это': 4,
#  'кто я': 4,
#  'вы правый извинить': 4,
#  'джудить': 4,
#  'вы уволить': 4,
#  'ты это нравиться': 4,
#  'рад ты видеть': 4,
#  'это не хорошо': 4,
#  'ты быть в порядок': 4,
#  'хороший замечание': 4,
#  'я найти это': 4,
#  'я я': 4,
#  'очень': 4,
#  'подождать секунда': 4,
#  'ладный хватить': 4,
#  'продолжать говорить': 4,
#  'вы я поймать': 4,
#  'я позвонить': 4,
#  'кто они такой': 4,
#  'опасность': 4,
#  'ава': 4,
#  'сука': 4,
#  'почему ты бы так поступить': 4,
#  'открыть': 4,
#  'как я выглядеть': 4,
#  'я слышать это': 4,
#  'где она': 4,
#  'не я': 4,
#  'конец': 4,
#  'привет мужик': 4,
#  'что получить': 4,
#  'этот': 4,
#  'звонить': 4,
#  'увидеться завтра': 4,
#  'вы правда так думать': 4,
#  'ты такой классный': 4,
#  'в чем проблема': 4,
#  'честно': 4,
#  'да всё хорошо': 4,
#  'ты не знать': 4,
#  'какой картина': 4,
#  'просто сделать это': 4,
#  'я полностью понимать': 4,
#  'эй стоить стоить': 4,
#  'тег': 4,
#  'привет эмма': 4,
#  'неправильно': 4,
#  'спасибо что прислать': 4,
#  'ты всё ещё любить я': 4,
#  'прикол': 4,
#  'можно с ты поговорить': 4,
#  'вы слышать': 4,
#  'как насчёт ты': 4,
#  'ты прекрасно выглядеть': 4,
#  'сегодня вечером': 4,
#  'прекратить печатать': 4,
#  'всё не так уж плохо': 4,
#  'я задолбаться': 4,
#  'сработать': 4,
#  'мы не мочь это сделать': 4,
#  'это быть бы прекрасно': 4,
#  'а можно': 4,
#  'фиби и': 4,
#  'это сводить я с ум': 4,
#  'ой бог мой': 4,
#  'выбрать я': 4,
#  'молодец': 4,
#  'понравиться': 4,
#  'и я нет': 4,
#  'как это быть': 4,
#  'я быть очень по ты скучать': 4,
#  'варение': 4,
#  'надо': 4,
#  'угадать что': 4,
#  'я хотеть бросить спортзал': 4,
#  'что значит': 4,
#  'не сейчас': 4,
#  'четверг': 4,
#  'не проблема': 4,
#  'это странно': 4,
#  'что черта взять ты делать': 4,
#  'я так ты гордиться': 4,
#  'ты победить': 4,
#  'сделка': 4,
#  'нет а почему': 4,
#  'сорок пять минута': 4,
#  'он сделать это': 4,
#  'э': 4,
#  'она быть хороший': 4,
#  'где ты это взять': 4,
#  'обязательно': 4,
#  'в ванная': 4,
#  'как насчёт': 4,
#  'это ещё не конец': 4,
#  'от я': 4,
#  'эм': 4,
#  'хорошо я пойти': 4,
#  'у я для ты сюрприз': 4,
#  'у я всё отлично': 4,
#  'сюрприз': 4,
#  'я сказать': 4,
#  'как пройти прослушивание': 4,
#  'однозначно': 4,
#  'вот посмотреть': 4,
#  'где всё': 4,
#  'за': 4,
#  'довольно': 4,
#  'о я': 4,
#  'быстрый': 4,
#  'я выигрывать': 4,
#  'он в порядок': 4,
#  'знать да': 4,
#  'что за фигня': 4,
#  'взять это': 4,
#  'вы всё испортить': 4,
#  'нет сэр': 4,
#  'сидеть': 4,
#  'эй ребята': 4,
#  'рассказать о это': 4,
#  'это быть хорошо': 4,
#  'да я в порядок': 4,
#  'вы не мочь это сделать': 4,
#  'угу нет': 4,
#  'хороший мальчик': 4,
#  'вот это смешно': 4,
#  'ничего не произойти': 4,
#  'если вы понимать о чем я': 4,
#  'хорошо увидеться': 4,
#  'у мы медовый месяц': 4,
#  'ненавидеть': 4,
#  'нет ничего': 4,
#  'я шутить': 4,
#  'привет спасибо': 4,
#  'да ладный ты': 4,
#  'простить что': 4,
#  'нет нельзя': 4,
#  'пока ребята': 4,
#  'ох ох ох': 4,
#  'каков шанс': 4,
#  'у ты': 4,
#  'но я': 4,
#  'можно вопрос': 4,
#  'что она сказать': 4,
#  'ни раз': 4,
#  'а вы': 4,
#  'я вернуться': 4,
#  'оставаться здесь': 4,
#  'добро пожаловать': 4,
#  'я выиграть': 4,
#  'я позвонить ты': 4,
#  'нет нет нет нет нет': 4,
#  'огромный спасибо': 4,
#  'что думать': 4,
#  'принести': 4,
#  'прямой': 4,
#  'привет ребёночек': 4,
#  'пора': 4,
#  'ладный как дело': 4,
#  'мой хороший друг и мой сестра': 4,
#  'мальчик': 4,
#  'дважды': 4,
#  'я хотеть': 4,
#  'я тоже по ты скучать': 4,
#  'она не': 4,
#  'беременный': 4,
#  'ты я пугать': 4,
#  'дума': 4,
#  'разве это не потрясающе': 4,
#  'я нравиться': 4,
#  'если': 4,
#  'она сказать да': 4,
#  'я иметь в вид что': 4,
#  'вы бы остановиться': 4,
#  'что что что': 4,
#  'хорошо я быть там': 4,
#  'который сейчас час': 4,
#  'нет ты': 4,
#  'ой спасибо спасибо': 4,
#  'это проблема': 4,
#  'здесь никто нет': 4,
#  'привет дружище': 4,
#  'осторожно': 4,
#  'о нет нет нет нет': 4,
#  'о ух ты': 4,
#  'нет извинить': 4,
#  'я актёр': 4,
#  'я очень жаль я очень жаль': 4,
#  'кот': 4,
#  'как ты это делать': 4,
#  'не мочь поверить что ты это сделать': 4,
#  'господь': 4,
#  'хорошо увидеться поздний ребята': 4,
#  'ты смеяться': 4,
#  'ты и': 4,
#  'хорошо вот и всё': 4,
#  'который из': 4,
#  'у я быть ребёнок': 4,
#  'это так круто': 4,
#  'женщина': 4,
#  'беречься': 4,
#  'чем мочь помочь': 4,
#  'оо': 4,
#  'остаться': 4,
#  'ужасный': 4,
#  'без причина': 4,
#  'зелёный': 4,
#  'биджан для мужчина': 4,
#  'так что ты собираться делать': 4,
#  'ладный итак': 4,
#  'мой сэндвич': 4,
#  'кто это быть': 4,
#  'мы делать': 4,
#  'для я': 4,
#  'с днм рождение': 4,
#  'ой нет': 4,
#  'ты идти': 4,
#  'нельзя': 4,
#  'счастливый рождество': 4,
#  'я нужно в туалет': 4,
#  'хорошо давать сделать это': 4,
#  'он уйти': 4,
#  'быть здорово': 4,
#  'ладный хорошо': 4,
#  'семь': 4,
#  'ага и знать что': 4,
#  'как долго': 4,
#  'лёгкий': 4,
#  'нет знать что': 4,
#  'давать мужик': 4,
#  'она твой': 4,
#  'эй ты': 4,
#  'что у ты': 4,
#  'мой ход': 4,
#  'ещё один толчок': 4,
#  'сумасшедший': 4,
#  'где ты черта взять быть': 4,
#  'это быть я': 4,
#  'что что это': 4,
#  'у я есть план': 4,
#  'хорошо я понять': 4,
#  'свобода': 3,
#  'я думать это': 3,
#  'ты там': 3,
#  'спереди и сзади': 3,
#  'это красиво': 3,
#  'ну это сложно': 3,
#  'это сделать': 3,
#  'невероятный': 3,
#  'не хотеть говорить': 3,
#  'ладный чувак': 3,
#  'это нелепо': 3,
#  ...}

# %%
df_vc = df_vc.reset_index()
df_vc.columns = ['Base_Phrase', 'Count']
df_vc
# Out:
#                                       Base_Phrase  Count
# 0                                                   2584
# 1                                          хорошо   1995
# 2                                          привет   1990
# 3                                             ага   1680
# 4                                             нет   1205
# ...                                           ...    ...
# 3538                        я только что спросить      2
# 3539                                    я повезти      2
# 3540                  я не знать что с это делать      2
# 3541                                 ужин готовый      2
# 3542  хорошо теперь ты верить что я она нравиться      2
#
# [3543 rows x 2 columns]

# %%
df_vc["Character"] = df_vc["Base_Phrase"].apply(lambda x: phrase_to_character[x])
df_vc
# Out:
#                                       Base_Phrase  ...                                     Character
# 0                                                  ...  [ДЖОУИ, РЕЙЧЕЛ, ФИБИ, МОНИКА, РОСС, ЧЕНДЛЕР]
# 1                                          хорошо  ...  [ДЖОУИ, РЕЙЧЕЛ, ФИБИ, МОНИКА, РОСС, ЧЕНДЛЕР]
# 2                                          привет  ...  [ДЖОУИ, РЕЙЧЕЛ, ФИБИ, МОНИКА, РОСС, ЧЕНДЛЕР]
# 3                                             ага  ...  [ДЖОУИ, РЕЙЧЕЛ, ФИБИ, МОНИКА, РОСС, ЧЕНДЛЕР]
# 4                                             нет  ...  [ДЖОУИ, РЕЙЧЕЛ, ФИБИ, МОНИКА, РОСС, ЧЕНДЛЕР]
# ...                                           ...  ...                                           ...
# 3538                        я только что спросить  ...                                [ФИБИ, МОНИКА]
# 3539                                    я повезти  ...                                      [РЕЙЧЕЛ]
# 3540                  я не знать что с это делать  ...                                [ФИБИ, МОНИКА]
# 3541                                 ужин готовый  ...                                      [МОНИКА]
# 3542  хорошо теперь ты верить что я она нравиться  ...                                     [ЧЕНДЛЕР]
#
# [3543 rows x 3 columns]

# %%
df_vc["Char_count"] = df_vc["Character"].apply(lambda x: len(x))
df_vc
# Out:
#                                       Base_Phrase  ...  Char_count
# 0                                                  ...           6
# 1                                          хорошо  ...           6
# 2                                          привет  ...           6
# 3                                             ага  ...           6
# 4                                             нет  ...           6
# ...                                           ...  ...         ...
# 3538                        я только что спросить  ...           2
# 3539                                    я повезти  ...           1
# 3540                  я не знать что с это делать  ...           2
# 3541                                 ужин готовый  ...           1
# 3542  хорошо теперь ты верить что я она нравиться  ...           1
#
# [3543 rows x 4 columns]

# %%
unconfident_phrases = df_vc[(df_vc.Count >= 4) & (df_vc.Char_count > 2)].reset_index(drop=True)
unconfident_phrases
# Out:
#                  Base_Phrase  ...  Char_count
# 0                             ...           6
# 1                     хорошо  ...           6
# 2                     привет  ...           6
# 3                        ага  ...           6
# 4                        нет  ...           6
# ..                       ...  ...         ...
# 860  где ты черта взять быть  ...           4
# 861               это быть я  ...           3
# 862              что что это  ...           3
# 863            у я есть план  ...           3
# 864          хорошо я понять  ...           3
#
# [865 rows x 4 columns]

# %%
bad_phr = list(unconfident_phrases["Base_Phrase"])
with open("unconfident_base_phrases.txt", "w") as f:
    f.write('\n'.join(bad_phr))

bad_phr
# Out:
# ['',
#  'хорошо',
#  'привет',
#  'ага',
#  'нет',
#  'что',
#  'ой',
#  'бог мой',
#  'да',
#  'спасибо',
#  'ух ты',
#  'знать',
#  'отлично',
#  'в сам дело',
#  'верно',
#  'эй',
#  'давать',
#  'знать что',
#  'почему',
#  'это',
#  'не знать',
#  'конечно',
#  'угу',
#  'хм',
#  'всё в порядок',
#  'а',
#  'какой',
#  'ты знать',
#  'простить',
#  'ого',
#  'здравствуйте',
#  'я',
#  'фиби',
#  'пожалуйста',
#  'о бог',
#  'я тоже',
#  'привет ребята',
#  'ох',
#  'ничего страшный',
#  'ладный',
#  'о нет',
#  'итак',
#  'да ладный',
#  'что это',
#  'как дело',
#  'что случиться',
#  'пока',
#  'извинить',
#  'я знать',
#  'моника',
#  'я жаль',
#  'да конечно',
#  'что происходить',
#  'бог',
#  'понятно',
#  'нет нет',
#  'я очень жаль',
#  'подождать',
#  'ничего',
#  'видеть',
#  'действительно',
#  'до свидание',
#  'что ты делать',
#  'ура',
#  'ну вот',
#  'здесь',
#  'хорошо хорошо',
#  'ооо',
#  'ну ладный',
#  'готовый',
#  'около',
#  'идти',
#  'совершенно верно',
#  'погодить',
#  'вот и всё',
#  'ждать',
#  'ладный ладный',
#  'я в порядок',
#  'о чем ты говорить',
#  'да да',
#  'прекратить',
#  'почему бы и нет',
#  'ты в порядок',
#  'замечательный',
#  'эээ',
#  'нет нет нет',
#  'просить прощение',
#  'понять',
#  'ну',
#  'ребята',
#  'это я',
#  'ух',
#  'где',
#  'блин',
#  'я понять',
#  'фу',
#  'неужели',
#  'что ты здесь делать',
#  'чувак',
#  'я любить вы',
#  'о да',
#  'и',
#  'не мочь',
#  'чем заниматься',
#  'ты',
#  'кто',
#  'да верно',
#  'ах',
#  'черта побрать',
#  'я сделать это',
#  'вы издеваться',
#  'что с ты',
#  'да ладный же',
#  'думать да',
#  'почему нет',
#  'ха',
#  'быть',
#  'я всё равно',
#  'что делать',
#  'ой спасибо',
#  'послать',
#  'посмотреть',
#  'спокойный ночь',
#  'да это так',
#  'вот так',
#  'в чем дело',
#  'поехать',
#  'ты право',
#  'марсель',
#  'идти сюда',
#  'я любить ты',
#  'ты серьёзно',
#  'не думать',
#  'вот',
#  'большой спасибо',
#  'что я делать',
#  'это здорово',
#  'это безумие',
#  'мочь быть',
#  'удача',
#  'добрый утро',
#  'увидеться',
#  'всё быть хорошо',
#  'постоять',
#  'вы уверить',
#  'как поживать',
#  'как',
#  'ммм',
#  'это оно',
#  'привет милый',
#  'я знать это',
#  'большой',
#  'как мило',
#  'да знать',
#  'не надо',
#  'ничего такой',
#  'ну да',
#  'это хорошо',
#  'ах да',
#  'смотреть',
#  'я просто',
#  'всё',
#  'ты шутить',
#  'он',
#  'не мочь поверить',
#  'вау',
#  'я не мочь в это поверить',
#  'есть',
#  'поздравлять',
#  'ни за что',
#  'я не знать',
#  'что вы иметь в вид',
#  'но',
#  'садиться',
#  'ну пожалуйста',
#  'я не мочь',
#  'кто такой',
#  'сюда',
#  'я не мочь это сделать',
#  'правда',
#  'не так ли',
#  'ладный пока',
#  'папа',
#  'вы',
#  'эй эй',
#  'это так здорово',
#  'я не',
#  'кто это',
#  'хорошо хорошо хорошо',
#  'уф',
#  'послушать',
#  'с ты всё в порядок',
#  'посмотреть на это',
#  'нет это не так',
#  'мы',
#  'наверное',
#  'вы с ум сойти',
#  'милый',
#  'серьёзно',
#  'джо',
#  'вперёд',
#  'ааа',
#  'как всё пройти',
#  'или',
#  'круто',
#  'это быть',
#  'всё нормально',
#  'нет нет нет нет',
#  'хорошо поехать',
#  'хороший',
#  'хорошо спасибо',
#  'я так жаль',
#  'помнить',
#  'где ты быть',
#  'вот оно',
#  'два',
#  'о',
#  'выходить',
#  'сейчас',
#  'ладный поехать',
#  'что это быть',
#  'она',
#  'это неправда',
#  'чт',
#  'подождать минута',
#  'проверить это',
#  'продолжать',
#  'ой мужик',
#  'это ты',
#  'я мочь это сделать',
#  'вы правый',
#  'нет спасибо',
#  'ой хорошо',
#  'да я знать',
#  'и что',
#  'а ты',
#  'здорово',
#  'немного',
#  'вот он',
#  'погодить погодить',
#  'а почему бы и нет',
#  'черта',
#  'заходить',
#  'я уходить',
#  'один',
#  'дженис',
#  'привет как дело',
#  'я иметь в вид',
#  'понимать',
#  'ага да',
#  'ладный знать что',
#  'как вы думать',
#  'это ужасно',
#  'что ты собираться делать',
#  'нет проблема',
#  'думать',
#  'верить',
#  'а знать что',
#  'вот ты где',
#  'потому что',
#  'слава бог',
#  'дада',
#  'о слава бог',
#  'у ты всё нормально',
#  'красиво',
#  'ох ох',
#  'мочь',
#  'я серьёзно',
#  'кей',
#  'ну да ладный',
#  'заткнуться',
#  'то есть',
#  'знать знать',
#  'мой',
#  'это смешно',
#  'ой простить',
#  'спасибо чувак',
#  'ну что ж',
#  'это всё',
#  'хорошо знать что',
#  'ну знать что',
#  'неа',
#  'это не',
#  'понятие не иметь',
#  'когда',
#  'ой ой',
#  'хотеть',
#  'это невероятно',
#  'стоп',
#  'привет привет',
#  'привет это',
#  'да быть',
#  'абсолютно',
#  'гм',
#  'не совсем',
#  'о привет',
#  'это правда',
#  'это так мило',
#  'так',
#  'нет не мочь',
#  'не мочь поверить в это',
#  'что это такой',
#  'сделать это',
#  'я тоже ты любить',
#  'я делать',
#  'это не так',
#  'увидеться поздний',
#  'нет не быть',
#  'прямо там',
#  'пн',
#  'забыть это',
#  'стрелять',
#  'странно',
#  'шутить',
#  'очень хорошо',
#  'всё хорошо',
#  'давать давать',
#  'подумать',
#  'мой бог',
#  'держать',
#  'что ты сказать',
#  'убираться отсюда',
#  'хорошо пока',
#  'доллар',
#  'ну вот и всё',
#  'я быть',
#  'попасться',
#  'ещё нет',
#  'просто',
#  'о я знать',
#  'что мы быть делать',
#  'о спасибо',
#  'ну конечно',
#  'привет я',
#  'мама',
#  'торопиться',
#  'а также',
#  'о нетнетнуть',
#  'невероятно',
#  'хорошо смотреть',
#  'да я тоже',
#  'что ещё',
#  'это нормально',
#  'аа',
#  'привет папа',
#  'как она',
#  'о ага',
#  'вы парень',
#  'приятно познакомиться',
#  'поздний',
#  'доктор',
#  'нет погодить',
#  'давать сделать это',
#  'что ты говорить',
#  'хорошо отлично',
#  'ничего подобный',
#  'давать росс',
#  'обещать',
#  'я идти',
#  'никогда',
#  'вставать',
#  'это потрясающе',
#  'о чем',
#  'да это быть',
#  'ой ой ой',
#  'это отстой',
#  'там',
#  'всегда',
#  'что это за хрень',
#  'ужасно',
#  'не делать это',
#  'отличный идея',
#  'вы знать',
#  'а что насчёт',
#  'о нет нет нет',
#  'хорошо я сделать это',
#  'откуда ты знать',
#  'смотреть смотреть',
#  'нет не знать',
#  'я скоро вернуться',
#  'о бог мой',
#  'ты что',
#  'ладный давать',
#  'не верить',
#  'о знать что',
#  'что я сказать',
#  'какой разница',
#  'ты уверенный',
#  'помощь',
#  'ой извинить',
#  'с удовольствие',
#  'эй что происходить',
#  'о нет нет',
#  'хороший идея',
#  'привет это я',
#  'я это нравиться',
#  'куда ты идти',
#  'ну что',
#  'это не смешно',
#  'забавно',
#  'что ты иметь в вид',
#  'не мочь в это поверить',
#  'нравиться',
#  'мужик',
#  'вот она',
#  'никто',
#  'ты выйти за я замуж',
#  'я право',
#  'я не понимать',
#  'вы мочь в это поверить',
#  'да я',
#  'я это знать',
#  'интересно',
#  'слушать',
#  'конечно да',
#  'конечно конечно',
#  'да правда',
#  'а почему',
#  'весь привет',
#  'да пожалуйста',
#  'ага ладный',
#  'и знать что',
#  'всё это',
#  'это быть весело',
#  'здесь нет',
#  'это просто',
#  'не волноваться',
#  'неважно',
#  'что я собираться делать',
#  'а что',
#  'привет мистер',
#  'происходить',
#  'думать ты право',
#  'да есть',
#  'быть весело',
#  'посмотреть на я',
#  'да да да',
#  'ни в кой случай',
#  'хорошо я идти',
#  'я пойти',
#  'обожать',
#  'а теперь',
#  'да ничего страшный',
#  'я так не думать',
#  'я ты любить',
#  'вроде',
#  'она спать',
#  'год',
#  'я действительно так делать',
#  'что мы делать',
#  'вы это видеть',
#  'понимать о чем я',
#  'он идти',
#  'это так несправедливый',
#  'это так увлекательно',
#  'хорошо идти',
#  'и ты',
#  'упс',
#  'с',
#  'что это значит',
#  'о это быть здорово',
#  'спасибо ребята',
#  'всё конченый',
#  'перерыв',
#  'не беспокоиться о это',
#  'звучать здорово',
#  'я здесь',
#  'они',
#  'ну нет',
#  'это не мой',
#  'помочь я',
#  'ты это слышать',
#  'ты тоже',
#  'ой погодить',
#  'вы видеть',
#  'ой смотреть',
#  'шутка в сторона',
#  'быть бы здорово',
#  'не говорить',
#  'разве это не здорово',
#  'расслабиться',
#  'ну что ж посмотреть',
#  'отлично выглядеть',
#  'не быть',
#  'это круто',
#  'ну и что',
#  'вот увидеть',
#  'да нет',
#  'ты сделать',
#  'посмотреть на себя',
#  'ну не знать',
#  'секундочка',
#  'случиться',
#  'бежать',
#  'что быть делать',
#  'это и',
#  'ну я',
#  'да это',
#  'оп',
#  'о чем вы думать',
#  'я пора',
#  'а я',
#  'утро',
#  'дать я',
#  'привет пн',
#  'хорошо быть',
#  'ага детка',
#  'она идти',
#  'да мочь быть',
#  'она звать',
#  'ребята что вы делать',
#  'ой здорово',
#  'о чувак',
#  'сукин сын',
#  'здравствуйте мистер',
#  'и что ты собираться делать',
#  'а это',
#  'да ничего',
#  'это быть невероятно',
#  'сколько',
#  'да но',
#  'я это не знать',
#  'да ты право',
#  'нет это',
#  'четыре',
#  'это не большой дело',
#  'ты понять',
#  'хорошо давать',
#  'вы помнить',
#  'не уходить',
#  'я взять',
#  'забыть',
#  'о хорошо',
#  'чточто ты делать',
#  'прямо здесь',
#  'ты такой милый',
#  'ой привет',
#  'ладный до свидание',
#  'это быть здорово',
#  'достаточно',
#  'мужчина',
#  'неплохо',
#  'помочь',
#  'да спасибо',
#  'простить простить',
#  'нет всё в порядок',
#  'вы это слышать',
#  'ты здесь делать',
#  'привет бен',
#  'я тоже жаль',
#  'да наверное',
#  'ты должный я помочь',
#  'с день рождение',
#  'это интересно',
#  'эй как дело',
#  'чендлера и',
#  'какой черта ты делать',
#  'разве что',
#  'у я есть',
#  'ладный смотреть',
#  'вот дерьмо',
#  'ну ммм',
#  'много',
#  'не правда ли',
#  'как ты',
#  'я это видеть',
#  'да уж',
#  'ты хороший',
#  'счастливый день благодарение',
#  'я скучать по',
#  'нет серьёзно',
#  'нет я серьёзно',
#  'да я уверенный',
#  'что что',
#  'она право',
#  'не очень хорошо',
#  'да это правда',
#  'а как насчёт',
#  'еда',
#  'что сказать',
#  'возможно',
#  'это невозможно',
#  'она уйти',
#  'но вы знать что',
#  'как это',
#  'прекрасно',
#  'да хорошо',
#  'это он',
#  'это не сработать',
#  'да хватить',
#  'в это есть смысл',
#  'хорошо ты право',
#  'сделать',
#  'это плохо',
#  'не ты',
#  'если только',
#  'это огромный',
#  'ладный ладный ладный',
#  'это не правильно',
#  'большой нет',
#  'это так',
#  'ладный всё',
#  'нет не надо',
#  'минутка',
#  'хорошо извинить',
#  'что у вы там',
#  'он право',
#  'я удача',
#  'хорошо хорошо хорошо хорошо',
#  'ложка',
#  'для что',
#  'не понимать',
#  'человек',
#  'но знать что',
#  'дать посмотреть',
#  'успокоиться',
#  'у я всё хорошо',
#  'это так сложно',
#  'нет конечно',
#  'вместе',
#  'это кто',
#  'я любить',
#  'весь',
#  'у мы быть перерыв',
#  'ну что это',
#  'не так',
#  'ты псих',
#  'это так странно',
#  'пойти',
#  'ты готовый',
#  'да какой разница',
#  'вверх',
#  'ага знать что',
#  'вы не знать',
#  'а если нет',
#  'я звать',
#  'секс',
#  'я любить это',
#  'хорошо готовый',
#  'точно',
#  'спасибо большой',
#  'в лондон',
#  'прохладный',
#  'запустить',
#  'он такой милый',
#  'ох ладный',
#  'это весело',
#  'посмотреть на он',
#  'что не так',
#  'о чем ты',
#  'ты нравиться',
#  'вопрос',
#  'спасибо спасибо',
#  'ладный подождать',
#  'привет мама',
#  'открыть это',
#  'ничего не делать',
#  'ты я нужный',
#  'это быть потрясающе',
#  'кто отец',
#  'куда ты',
#  'я должный идти',
#  'вы не поверить',
#  'маленький',
#  'черта взять',
#  'я не знать что я делать',
#  'это мой',
#  'ты знать почему',
#  'или нет',
#  'у я нет',
#  'а да',
#  'что за',
#  'хороший попытка',
#  'мы сделать это',
#  'очень хороший',
#  'ладный извинить',
#  'так хороший',
#  'без проблема',
#  'у мы всё хорошо',
#  'а я нет',
#  'нет пока нет',
#  'о вот оно',
#  'дать я это',
#  'я это не делать',
#  'нет я в порядок',
#  'можно',
#  'не знать что сказать',
#  'ты мочь в это поверить',
#  'да ладный ребята',
#  'парень',
#  'не очень',
#  'клясться',
#  'да быть бы здорово',
#  'что вы делать',
#  'ну как дело',
#  'отдать',
#  'где это',
#  'очень смешно',
#  'нет знать',
#  'с кто',
#  'не пойти',
#  'беречь себя',
#  'да ладный вы ребята',
#  'ага привет',
#  'о что',
#  'мочь я вы кой о чем спросить',
#  'вовсе нет',
#  'эй погодить',
#  'ладный ребята',
#  'да всё быть хорошо',
#  'подождать минутка',
#  'ву',
#  'ничего не мочь поделать',
#  'он здесь',
#  'уходить',
#  'бог мой это',
#  'вы правый извинить',
#  'джудить',
#  'вы уволить',
#  'ты это нравиться',
#  'рад ты видеть',
#  'это не хорошо',
#  'я я',
#  'подождать секунда',
#  'вы я поймать',
#  'сука',
#  'почему ты бы так поступить',
#  'открыть',
#  'я слышать это',
#  'не я',
#  'конец',
#  'что получить',
#  'этот',
#  'звонить',
#  'увидеться завтра',
#  'вы правда так думать',
#  'в чем проблема',
#  'честно',
#  'да всё хорошо',
#  'просто сделать это',
#  'я полностью понимать',
#  'привет эмма',
#  'неправильно',
#  'прикол',
#  'можно с ты поговорить',
#  'вы слышать',
#  'как насчёт ты',
#  'ты прекрасно выглядеть',
#  'сегодня вечером',
#  'я задолбаться',
#  'сработать',
#  'мы не мочь это сделать',
#  'это быть бы прекрасно',
#  'а можно',
#  'фиби и',
#  'это сводить я с ум',
#  'ой бог мой',
#  'выбрать я',
#  'молодец',
#  'понравиться',
#  'и я нет',
#  'как это быть',
#  'надо',
#  'угадать что',
#  'что значит',
#  'не сейчас',
#  'что черта взять ты делать',
#  'я так ты гордиться',
#  'нет а почему',
#  'сорок пять минута',
#  'где ты это взять',
#  'обязательно',
#  'в ванная',
#  'как насчёт',
#  'это ещё не конец',
#  'эм',
#  'у я для ты сюрприз',
#  'у я всё отлично',
#  'я сказать',
#  'как пройти прослушивание',
#  'где всё',
#  'довольно',
#  'о я',
#  'быстрый',
#  'я выигрывать',
#  'нет сэр',
#  'рассказать о это',
#  'это быть хорошо',
#  'да я в порядок',
#  'вы не мочь это сделать',
#  'угу нет',
#  'ничего не произойти',
#  'если вы понимать о чем я',
#  'хорошо увидеться',
#  'у мы медовый месяц',
#  'нет ничего',
#  'я шутить',
#  'привет спасибо',
#  'ох ох ох',
#  'каков шанс',
#  'можно вопрос',
#  'что она сказать',
#  'ни раз',
#  'а вы',
#  'я вернуться',
#  'оставаться здесь',
#  'добро пожаловать',
#  'нет нет нет нет нет',
#  'огромный спасибо',
#  'что думать',
#  'принести',
#  'пора',
#  'ладный как дело',
#  'мальчик',
#  'я хотеть',
#  'беременный',
#  'ты я пугать',
#  'разве это не потрясающе',
#  'она сказать да',
#  'я иметь в вид что',
#  'что что что',
#  'хорошо я быть там',
#  'который сейчас час',
#  'нет ты',
#  'это проблема',
#  'здесь никто нет',
#  'привет дружище',
#  'осторожно',
#  'о нет нет нет нет',
#  'о ух ты',
#  'нет извинить',
#  'я очень жаль я очень жаль',
#  'как ты это делать',
#  'не мочь поверить что ты это сделать',
#  'господь',
#  'хорошо увидеться поздний ребята',
#  'ты смеяться',
#  'хорошо вот и всё',
#  'который из',
#  'это так круто',
#  'женщина',
#  'чем мочь помочь',
#  'без причина',
#  'зелёный',
#  'ладный итак',
#  'кто это быть',
#  'мы делать',
#  'с днм рождение',
#  'ты идти',
#  'нельзя',
#  'хорошо давать сделать это',
#  'он уйти',
#  'ладный хорошо',
#  'ага и знать что',
#  'как долго',
#  'нет знать что',
#  'эй ты',
#  'что у ты',
#  'мой ход',
#  'сумасшедший',
#  'где ты черта взять быть',
#  'это быть я',
#  'что что это',
#  'у я есть план',
#  'хорошо я понять']

# %%
print(f'Cleaning {int(100 * unconfident_phrases["Count"].sum()/(df.shape[0]))}% of sentences')
# Out:
# Cleaning 32% of sentences

# %%
df_clean = df_[~df_["Base_Phrase"].isin(bad_phr)].reset_index(drop=True)
df_clean.columns = ["label", "sentence", "base_sentence"]
df_clean["label"] = df_clean["label"].apply(lambda x: chars_to_labels[x])
df_clean
# Out:
#        label  ...                                      base_sentence
# 0          0  ...              да ладный ты встречаться с это парень
# 1          0  ...                    с они должный быть чтоть не так
# 2          0  ...                                             вместо
# 3          0  ...                          никогда не видеть это сон
# 4          0  ...        этот парень здороваться я хотеть убить себя
# ...      ...  ...                                                ...
# 57188      5  ...                                    ого это странно
# 57189      5  ...                           посмотреть вокруг ребята
# 57190      5  ...                           это быть твой первый дом
# 57191      5  ...  и это быть счастливый место наполнить любовь и...
# 57192      5  ...  но что ещё важный изз контроль за арендный пла...
#
# [57193 rows x 3 columns]

# %%
df = df_clean.sample(frac=1).reset_index(drop=True)
df
# Out:
#        label  ...                                      base_sentence
# 0          5  ...                                            мамочка
# 1          4  ...                                    плюс мой деньга
# 2          5  ...                  там всё твой друг и твой родитель
# 3          2  ...                                 ну да понимать что
# 4          3  ...  нет ребята я иметь в вид что у я клавишный до ...
# ...      ...  ...                                                ...
# 57188      0  ...  да и мы послать бы проверить но вы забрать наш...
# 57189      2  ...            ну так почему бы вы просто не выключить
# 57190      0  ...  видеть ли когда ты играть ты нужно думать о та...
# 57191      3  ...                                           эй а где
# 57192      0  ...   признать самый достоверный нейрохирург по версия
#
# [57193 rows x 3 columns]

# %%
#!g1.1
df.to_csv("only_unique_phrases_ru.csv", index=False)
