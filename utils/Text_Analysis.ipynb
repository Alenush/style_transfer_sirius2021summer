# %%
# !git clone https://github.com/Alenush/style_transfer_sirius2021summer.git
# Out:
# Cloning into 'style_transfer_sirius2021summer'...
# remote: Enumerating objects: 648, done.
# remote: Counting objects: 100% (648/648), done.
# remote: Compressing objects: 100% (630/630), done.
# remote: Total 648 (delta 23), reused 633 (delta 11), pack-reused 0
# Receiving objects: 100% (648/648), 14.53 MiB | 21.13 MiB/s, done.
# Resolving deltas: 100% (23/23), done.

# %%
# %%bash
#
# pip install pymorphy2 pyLDAvis
# Out:
# Requirement already satisfied: pymorphy2 in /usr/local/lib/python3.7/dist-packages (0.9.1)
# Requirement already satisfied: pyLDAvis in /usr/local/lib/python3.7/dist-packages (3.3.1)
# Requirement already satisfied: pymorphy2-dicts-ru<3.0,>=2.4 in /usr/local/lib/python3.7/dist-packages (from pymorphy2) (2.4.417127.4579844)
# Requirement already satisfied: dawg-python>=0.7.1 in /usr/local/lib/python3.7/dist-packages (from pymorphy2) (0.7.2)
# Requirement already satisfied: docopt>=0.6 in /usr/local/lib/python3.7/dist-packages (from pymorphy2) (0.6.2)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.21.0)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (2.7.3)
# Requirement already satisfied: sklearn in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (0.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.4.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.0.1)
# Requirement already satisfied: gensim in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (3.6.0)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (0.16.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (2.11.3)
# Requirement already satisfied: funcy in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.16)
# Requirement already satisfied: pandas>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.3.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (57.0.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (0.22.2.post1)
# Requirement already satisfied: smart-open>=1.2.1 in /usr/local/lib/python3.7/dist-packages (from gensim->pyLDAvis) (5.1.0)
# Requirement already satisfied: six>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from gensim->pyLDAvis) (1.15.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->pyLDAvis) (2.0.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.2.0->pyLDAvis) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.2.0->pyLDAvis) (2018.9)

# %%
import string
import re
import numpy as np
import pandas as pd
from pprint import pprint
# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
# spacy for lemmatization
import spacy
# Plotting tools
import pyLDAvis
import pyLDAvis.gensim_models  # don't skip this
import matplotlib.pyplot as plt
# %matplotlib inline
# Enable logging for gensim - optional
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)
import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)

import nltk

nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
with open("style_transfer_sirius2021summer/data/scripts/russian/РОСС.txt", "r") as f:
    text = f.readlines()[0]
text
# Out:
# 'Привет Я чувствую, будто кто-то потянулся к моему горлу, схватил мою тонкую кишку, вытащил ее изо рта и обвязал вокруг моей шеи  Нет, не надо? Прекратите очищать мою ауру? Нет, просто оставь мою ауру в покое, хорошо? Я буду в порядке, хорошо? На самом деле все Надеюсь, она будет очень счастлива Нет, хрен с ней, она меня бросила? Нет ? Хорошо? Почему все на этом зацикливаются? Она не знала, откуда мне знать? Я не хочу быть холостяком, ладно? Я просто  Я просто хочу снова выйти замуж? Привет Вы видите, где у него проблемы Винный парень Пол, Пол? Он наконец пригласил вас на свидание? Хорошо бы  Нет, продолжай? Это Пол винный парень? Итак, Рэйчел, что ты  что ты делаешь сегодня вечером? Да, у тебя даже медовый месяц не будет, Боже  Нет, нет, хотя, Аруба, в это время года  поговорим о своих  больших ящерицах  В любом случае, если ты не чувствуешь Как будто сегодня побыть одни, Джоуи и Чендлер приходят, чтобы помочь мне собрать мою новую мебель Хорошо, конечно Я должен прикрепить скобу к боковым элементам, используя кучу этих маленьких червячков У меня нет храбрости, я вообще не вижу парней-червяков и  я не чувствую своих ног Любимое пиво Кэрол Я должен был знать, что она всегда пила его из банки Ребята Знаешь, что самое страшное? Что, если на всех есть только одна женщина, понимаешь? Я имею в виду, что если у вас будет одна женщина - и все? К сожалению, в моем случае была только одна женщина - для нее  Честно говоря, не знаю, голоден я или возбужден Возьми ложку Ты знаешь, сколько времени прошло с тех пор, как я схватил ложку? Слова «Билли, не будь героем» что-нибудь значат для тебя? Понимаешь, вот в чем дело Даже если бы я смог собрать это достаточно, чтобы  пригласить женщину на свидание  кого я спрошу? Полагаю, мы ищем ответ более изощренный, чем «уложить в постель» У вас есть работа? Слово, которое вы ищете, - «Все равно»  Давай, режь Вырезать, вырезать, вырезать  Нет Нет, мне пора домой как-нибудь Ага Ммм О, нет- Нет-нет-давай- Разбить? Хорошо Вы знаете, что вы, вероятно, этого не знали, но еще в старшей школе я был  э-э  сильно влюблен в вас Да? Ох  Я всегда думал, что ты просто думаешь, что я старший брат Моники О Послушайте, как вы думаете - и постарайтесь не позволить моей сильной уязвимости стать здесь каким-либо фактором - но как вы думаете, было бы хорошо, если бы я пригласил вас на свидание? Когда-то? Может быть? Хорошо  ладно, может быть  Спокойной ночи Я только что взял ложку Да, и… и дело не в том, что нам не нравится комик, а в том-то… мы не поэтому купили билет Нет, это хорошо, это хорошо, просто  мм  она не кажется немного рассерженной? А она Марша, это пещерные люди Хорошо? У них есть проблемы вроде «Ну и дела, этот ледник уже близко» Видеть? Нет Ладно-ладно, да Как насчет того, что я догоню тебя в ледниковом периоде Привет Отлично выглядишь Я  я ненавижу это А, вот здесь, любой, кто  стоит прямо  Так что нового? И все же  Ну  мало ли Как  как семья? Почему- почему ты здесь, Кэрол? Беременная ?  Привет Кэрол беременна Ага Сделай это еще два часа, возможно, ты будешь там, где я сейчас Что ж, Кэрол говорит, что они со Сьюзен хотят, чтобы я участвовал, но если мне это не нравится, мне не нужно участвовать  в основном это полностью зависит от меня В любом случае, они хотят, чтобы я завтра пошел с ними на сонограмму Понятия не имею Но что бы я ни делал, я все равно буду отцом Я считаю, что они классные? Я действительно люблю Ой, мама  Ага Хорошо? Хорошо Послушайте, я  я понимаю, что вы, ребята, задавались вопросом, что именно произошло между мной и Кэрол, и, так что, вот в чем дело Кэрол лесбиянка Она живет с женщиной по имени Сьюзен Она беременна моим ребенком, и они со Сьюзен собираются вырастить ребенка Ну, знаете, эти люди профи Они знают, что делают, не торопятся и выполняют свою работу Надо пописать  Как долго я там пробыл? Дя  эээ  дя нужна помощь? В любом случае  гм  Итак, вы  э-э  нервничаете из-за завтрашнего Барри? Ммм  Мм Что ж, не стоит употреблять слово «сброшен» Скорее всего, он будет этим, этой слома ...

# %%
import pymorphy2
from nltk.corpus import stopwords

morph = pymorphy2.MorphAnalyzer()
ru_stopwords = stopwords.words('russian')
digits = [str(i) for i in range(10)]
def preprocess(tokens):
    return [morph.normal_forms(word)[0]
            for word in tokens
                if (word[0] not in digits and
                    word not in ru_stopwords)]

# %%
chars = re.escape('[!@"“’«»#$%&\'()*+,/:;<=>?^_`{|}~\[\]]')
text = re.sub(r'['+chars+']', '',text)
text
# Out:
# 'Привет Я чувствую будто кто-то потянулся к моему горлу схватил мою тонкую кишку вытащил ее изо рта и обвязал вокруг моей шеи  Нет не надо Прекратите очищать мою ауру Нет просто оставь мою ауру в покое хорошо Я буду в порядке хорошо На самом деле все Надеюсь она будет очень счастлива Нет хрен с ней она меня бросила Нет  Хорошо Почему все на этом зацикливаются Она не знала откуда мне знать Я не хочу быть холостяком ладно Я просто  Я просто хочу снова выйти замуж Привет Вы видите где у него проблемы Винный парень Пол Пол Он наконец пригласил вас на свидание Хорошо бы  Нет продолжай Это Пол винный парень Итак Рэйчел что ты  что ты делаешь сегодня вечером Да у тебя даже медовый месяц не будет Боже  Нет нет хотя Аруба в это время года  поговорим о своих  больших ящерицах  В любом случае если ты не чувствуешь Как будто сегодня побыть одни Джоуи и Чендлер приходят чтобы помочь мне собрать мою новую мебель Хорошо конечно Я должен прикрепить скобу к боковым элементам используя кучу этих маленьких червячков У меня нет храбрости я вообще не вижу парней-червяков и  я не чувствую своих ног Любимое пиво Кэрол Я должен был знать что она всегда пила его из банки Ребята Знаешь что самое страшное Что если на всех есть только одна женщина понимаешь Я имею в виду что если у вас будет одна женщина - и все К сожалению в моем случае была только одна женщина - для нее  Честно говоря не знаю голоден я или возбужден Возьми ложку Ты знаешь сколько времени прошло с тех пор как я схватил ложку Слова Билли не будь героем что-нибудь значат для тебя Понимаешь вот в чем дело Даже если бы я смог собрать это достаточно чтобы  пригласить женщину на свидание  кого я спрошу Полагаю мы ищем ответ более изощренный чем уложить в постель У вас есть работа Слово которое вы ищете - Все равно  Давай режь Вырезать вырезать вырезать  Нет Нет мне пора домой как-нибудь Ага Ммм О нет- Нет-нет-давай- Разбить Хорошо Вы знаете что вы вероятно этого не знали но еще в старшей школе я был  э-э  сильно влюблен в вас Да Ох  Я всегда думал что ты просто думаешь что я старший брат Моники О Послушайте как вы думаете - и постарайтесь не позволить моей сильной уязвимости стать здесь каким-либо фактором - но как вы думаете было бы хорошо если бы я пригласил вас на свидание Когда-то Может быть Хорошо  ладно может быть  Спокойной ночи Я только что взял ложку Да и… и дело не в том что нам не нравится комик а в том-то… мы не поэтому купили билет Нет это хорошо это хорошо просто  мм  она не кажется немного рассерженной А она Марша это пещерные люди Хорошо У них есть проблемы вроде Ну и дела этот ледник уже близко Видеть Нет Ладно-ладно да Как насчет того что я догоню тебя в ледниковом периоде Привет Отлично выглядишь Я  я ненавижу это А вот здесь любой кто  стоит прямо  Так что нового И все же  Ну  мало ли Как  как семья Почему- почему ты здесь Кэрол Беременная   Привет Кэрол беременна Ага Сделай это еще два часа возможно ты будешь там где я сейчас Что ж Кэрол говорит что они со Сьюзен хотят чтобы я участвовал но если мне это не нравится мне не нужно участвовать  в основном это полностью зависит от меня В любом случае они хотят чтобы я завтра пошел с ними на сонограмму Понятия не имею Но что бы я ни делал я все равно буду отцом Я считаю что они классные Я действительно люблю Ой мама  Ага Хорошо Хорошо Послушайте я  я понимаю что вы ребята задавались вопросом что именно произошло между мной и Кэрол и так что вот в чем дело Кэрол лесбиянка Она живет с женщиной по имени Сьюзен Она беременна моим ребенком и они со Сьюзен собираются вырастить ребенка Ну знаете эти люди профи Они знают что делают не торопятся и выполняют свою работу Надо пописать  Как долго я там пробыл Дя  эээ  дя нужна помощь В любом случае  гм  Итак вы  э-э  нервничаете из-за завтрашнего Барри Ммм  Мм Что ж не стоит употреблять слово сброшен Скорее всего он будет этим этой сломанной оболочкой человека понимаете так что вы должны постараться не выглядеть слишком потрясающе я знаю это будет сложно Или знаешь эй  я пойду туда и верну ...

# %%
from nltk.tokenize import word_tokenize

tokenized_word = word_tokenize(text)
print(tokenized_word)
# Out:
# ['Привет', 'Я', 'чувствую', 'будто', 'кто-то', 'потянулся', 'к', 'моему', 'горлу', 'схватил', 'мою', 'тонкую', 'кишку', 'вытащил', 'ее', 'изо', 'рта', 'и', 'обвязал', 'вокруг', 'моей', 'шеи', 'Нет', 'не', 'надо', 'Прекратите', 'очищать', 'мою', 'ауру', 'Нет', 'просто', 'оставь', 'мою', 'ауру', 'в', 'покое', 'хорошо', 'Я', 'буду', 'в', 'порядке', 'хорошо', 'На', 'самом', 'деле', 'все', 'Надеюсь', 'она', 'будет', 'очень', 'счастлива', 'Нет', 'хрен', 'с', 'ней', 'она', 'меня', 'бросила', 'Нет', 'Хорошо', 'Почему', 'все', 'на', 'этом', 'зацикливаются', 'Она', 'не', 'знала', 'откуда', 'мне', 'знать', 'Я', 'не', 'хочу', 'быть', 'холостяком', 'ладно', 'Я', 'просто', 'Я', 'просто', 'хочу', 'снова', 'выйти', 'замуж', 'Привет', 'Вы', 'видите', 'где', 'у', 'него', 'проблемы', 'Винный', 'парень', 'Пол', 'Пол', 'Он', 'наконец', 'пригласил', 'вас', 'на', 'свидание', 'Хорошо', 'бы', 'Нет', 'продолжай', 'Это', 'Пол', 'винный', 'парень', 'Итак', 'Рэйчел', 'что', 'ты', 'что', 'ты', 'делаешь', 'сегодня', 'вечером', 'Да', 'у', 'тебя', 'даже', 'медовый', 'месяц', 'не', 'будет', 'Боже', 'Нет', 'нет', 'хотя', 'Аруба', 'в', 'это', 'время', 'года', 'поговорим', 'о', 'своих', 'больших', 'ящерицах', 'В', 'любом', 'случае', 'если', 'ты', 'не', 'чувствуешь', 'Как', 'будто', 'сегодня', 'побыть', 'одни', 'Джоуи', 'и', 'Чендлер', 'приходят', 'чтобы', 'помочь', 'мне', 'собрать', 'мою', 'новую', 'мебель', 'Хорошо', 'конечно', 'Я', 'должен', 'прикрепить', 'скобу', 'к', 'боковым', 'элементам', 'используя', 'кучу', 'этих', 'маленьких', 'червячков', 'У', 'меня', 'нет', 'храбрости', 'я', 'вообще', 'не', 'вижу', 'парней-червяков', 'и', 'я', 'не', 'чувствую', 'своих', 'ног', 'Любимое', 'пиво', 'Кэрол', 'Я', 'должен', 'был', 'знать', 'что', 'она', 'всегда', 'пила', 'его', 'из', 'банки', 'Ребята', 'Знаешь', 'что', 'самое', 'страшное', 'Что', 'если', 'на', 'всех', 'есть', 'только', 'одна', 'женщина', 'понимаешь', 'Я', 'имею', 'в', 'виду', 'что', 'если', 'у', 'вас', 'будет', 'одна', 'женщина', '-', 'и', 'все', 'К', 'сожалению', 'в', 'моем', 'случае', 'была', 'только', 'одна', 'женщина', '-', 'для', 'нее', 'Честно', 'говоря', 'не', 'знаю', 'голоден', 'я', 'или', 'возбужден', 'Возьми', 'ложку', 'Ты', 'знаешь', 'сколько', 'времени', 'прошло', 'с', 'тех', 'пор', 'как', 'я', 'схватил', 'ложку', 'Слова', 'Билли', 'не', 'будь', 'героем', 'что-нибудь', 'значат', 'для', 'тебя', 'Понимаешь', 'вот', 'в', 'чем', 'дело', 'Даже', 'если', 'бы', 'я', 'смог', 'собрать', 'это', 'достаточно', 'чтобы', 'пригласить', 'женщину', 'на', 'свидание', 'кого', 'я', 'спрошу', 'Полагаю', 'мы', 'ищем', 'ответ', 'более', 'изощренный', 'чем', 'уложить', 'в', 'постель', 'У', 'вас', 'есть', 'работа', 'Слово', 'которое', 'вы', 'ищете', '-', 'Все', 'равно', 'Давай', 'режь', 'Вырезать', 'вырезать', 'вырезать', 'Нет', 'Нет', 'мне', 'пора', 'домой', 'как-нибудь', 'Ага', 'Ммм', 'О', 'нет-', 'Нет-нет-давай-', 'Разбить', 'Хорошо', 'Вы', 'знаете', 'что', 'вы', 'вероятно', 'этого', 'не', 'знали', 'но', 'еще', 'в', 'старшей', 'школе', 'я', 'был', 'э-э', 'сильно', 'влюблен', 'в', 'вас', 'Да', 'Ох', 'Я', 'всегда', 'думал', 'что', 'ты', 'просто', 'думаешь', 'что', 'я', 'старший', 'брат', 'Моники', 'О', 'Послушайте', 'как', 'вы', 'думаете', '-', 'и', 'постарайтесь', 'не', 'позволить', 'моей', 'сильной', 'уязвимости', 'стать', 'здесь', 'каким-либо', 'фактором', '-', 'но', 'как', 'вы', 'думаете', 'было', 'бы', 'хорошо', 'если', 'бы', 'я', 'пригласил', 'вас', 'на', 'свидание', 'Когда-то', 'Может', 'быть', 'Хорошо', 'ладно', 'может', 'быть', 'Спокойной', 'ночи', 'Я', 'только', 'что', 'взял', 'ложку', 'Да', 'и…', 'и', 'дело', 'не', 'в', 'том', 'что', 'нам', 'не', 'нравится', 'комик', 'а', 'в', 'том-то…', 'мы', 'не', 'поэтому', 'купили', 'билет', 'Нет', 'это', 'хорошо', 'это', 'хорошо', 'просто', 'мм', 'она', 'не', 'кажется', 'немного', 'рассерженной', 'А', 'она', 'Марша', 'это', 'пещерные', 'люди', 'Хорошо', 'У', 'них', 'есть', 'проблемы', 'вроде', 'Ну', 'и', 'дела', 'этот', 'ледник', 'уже', 'близко', 'Видеть', 'Нет', 'Ладно ...

# %%
preprocessed_word_tokens = preprocess(tokenized_word)
preprocessed_word_tokens
# Out:
# ['привет',
#  'я',
#  'чувствовать',
#  'кто-то',
#  'потянуться',
#  'мой',
#  'горло',
#  'схватить',
#  'мой',
#  'тонкий',
#  'кишка',
#  'вытащить',
#  'из',
#  'рот',
#  'обвязать',
#  'вокруг',
#  'мой',
#  'шея',
#  'нет',
#  'прекратить',
#  'очищать',
#  'мой',
#  'аура',
#  'нет',
#  'просто',
#  'оставить',
#  'мой',
#  'аура',
#  'покой',
#  'я',
#  'быть',
#  'порядок',
#  'на',
#  'сам',
#  'дело',
#  'надеяться',
#  'очень',
#  'счастливый',
#  'нет',
#  'хрен',
#  'бросить',
#  'нет',
#  'хорошо',
#  'почему',
#  'зацикливаться',
#  'она',
#  'знать',
#  'откуда',
#  'знать',
#  'я',
#  'хотеть',
#  'холостяк',
#  'ладный',
#  'я',
#  'просто',
#  'я',
#  'просто',
#  'хотеть',
#  'снова',
#  'выйти',
#  'замуж',
#  'привет',
#  'вы',
#  'видеть',
#  'проблема',
#  'винный',
#  'парень',
#  'пол',
#  'пол',
#  'он',
#  'пригласить',
#  'свидание',
#  'хорошо',
#  'нет',
#  'продолжать',
#  'это',
#  'пол',
#  'винный',
#  'парень',
#  'итак',
#  'рэйчел',
#  'делать',
#  'сегодня',
#  'вечером',
#  'да',
#  'медовый',
#  'месяц',
#  'бог',
#  'нет',
#  'хотя',
#  'аруба',
#  'это',
#  'время',
#  'год',
#  'поговорить',
#  'свой',
#  'больший',
#  'ящерица',
#  'в',
#  'любой',
#  'случай',
#  'чувствовать',
#  'как',
#  'сегодня',
#  'побыть',
#  'один',
#  'джоуя',
#  'чендлера',
#  'приходить',
#  'помочь',
#  'собрать',
#  'мой',
#  'новый',
#  'мебель',
#  'хорошо',
#  'я',
#  'должный',
#  'прикрепить',
#  'скоба',
#  'боковой',
#  'элемент',
#  'использовать',
#  'куча',
#  'этот',
#  'маленький',
#  'червячок',
#  'у',
#  'храбрость',
#  'вообще',
#  'видеть',
#  'парень-червяк',
#  'чувствовать',
#  'свой',
#  'нога',
#  'любимый',
#  'пиво',
#  'кэрол',
#  'я',
#  'должный',
#  'знать',
#  'пила',
#  'банк',
#  'ребята',
#  'знать',
#  'самый',
#  'страшный',
#  'что',
#  'один',
#  'женщина',
#  'понимать',
#  'я',
#  'иметь',
#  'вид',
#  'один',
#  'женщина',
#  '-',
#  'к',
#  'сожаление',
#  'мой',
#  'случай',
#  'один',
#  'женщина',
#  '-',
#  'честно',
#  'говорить',
#  'знать',
#  'голодный',
#  'возбудить',
#  'взять',
#  'ложка',
#  'ты',
#  'знать',
#  'сколько',
#  'время',
#  'пройти',
#  'тот',
#  'пора',
#  'схватить',
#  'ложка',
#  'слово',
#  'билли',
#  'быть',
#  'герой',
#  'что-нибудь',
#  'значить',
#  'понимать',
#  'дело',
#  'даже',
#  'смочь',
#  'собрать',
#  'это',
#  'достаточно',
#  'пригласить',
#  'женщина',
#  'свидание',
#  'кто',
#  'спросить',
#  'полагать',
#  'искать',
#  'ответ',
#  'изощрённый',
#  'уложить',
#  'постель',
#  'у',
#  'работа',
#  'слово',
#  'который',
#  'искать',
#  '-',
#  'всё',
#  'равно',
#  'давать',
#  'резать',
#  'вырезать',
#  'вырезать',
#  'вырезать',
#  'нет',
#  'нет',
#  'пора',
#  'домой',
#  'как-нибудь',
#  'ага',
#  'ммм',
#  'о',
#  'нет-',
#  'нет-нет-давай-',
#  'разбить',
#  'хорошо',
#  'вы',
#  'знать',
#  'вероятно',
#  'знать',
#  'старший',
#  'школа',
#  'э-э',
#  'сильно',
#  'влюбить',
#  'да',
#  'ох',
#  'я',
#  'думать',
#  'просто',
#  'думать',
#  'старший',
#  'брат',
#  'моника',
#  'о',
#  'послушать',
#  'думать',
#  '-',
#  'постараться',
#  'позволить',
#  'мой',
#  'сильный',
#  'уязвимость',
#  'стать',
#  'какой-либо',
#  'фактор',
#  '-',
#  'думать',
#  'пригласить',
#  'свидание',
#  'когда-то',
#  'мочь',
#  'хорошо',
#  'ладный',
#  'спокойный',
#  'ночь',
#  'я',
#  'взять',
#  'ложка',
#  'да',
#  'и…',
#  'дело',
#  'мы',
#  'нравиться',
#  'комик',
#  'том-то…',
#  'поэтому',
#  'купить',
#  'билет',
#  'нет',
#  'это',
#  'это',
#  'просто',
#  'мм',
#  'казаться',
#  'немного',
#  'рассердить',
#  'а',
#  'марш',
#  'это',
#  'пещерный',
#  'человек',
#  'хорошо',
#  'у',
#  'проблема',
#  'вроде',
#  'ну',
#  'дело',
#  'ледник',
#  'близко',
#  'видеть',
#  'нет',
#  'ладный-ладный',
#  'как',
#  'насчёт',
#  'догнать',
#  'ледниковый',
#  'период',
#  'привет',
#  'отлично',
#  'выглядеть',
#  'я',
#  'ненавидеть',
#  'это',
#  'а',
#  'любой',
#  'стоить',
#  'прямо',
#  'так',
#  'новый',
#  'и',
#  'ну',
#  'мало',
#  'как',
#  'семья',
#  'почему-',
#  'почему',
#  'кэрол',
#  'беременный',
#  'привет',
#  'кэрол',
#  'беременный',
#  'ага',
#  'сделать',
#  'это',
#  'час',
#  'возможно',
#  'быть',
#  'что',
#  'кэрол',
#  'говорить',
#  'сьюзен',
#  'хотеть',
#  'участвовать',
#  'это',
#  'нравиться',
#  'нужно',
#  'участвовать',
#  'основное',
#  'это',
#  'полностью',
#  'зависеть',
#  'в',
#  'любой',
#  'случай',
#  'хотеть',
#  'завтра',
#  'пойти',
#  'они',
#  'сонограмм',
#  'понятие',
#  'иметь',
#  'но',
#  'делать',
#  'равно',
#  'быть',
#  'отец',
#  'я',
#  'считать',
#  'классный',
#  'я',
#  'действительно',
#  'любить',
#  'ой',
#  'мама',
#  'ага',
#  'хорошо',
#  'хорошо',
#  'послушать',
#  'понимать',
#  'ребята',
#  'задаваться',
#  'вопрос',
#  'именно',
#  'произойти',
#  'я',
#  'кэрол',
#  'дело',
#  'кэрол',
#  'лесбиянка',
#  'она',
#  'жить',
#  'женщина',
#  'имя',
#  'сьюзен',
#  'она',
#  'беременный',
#  'мой',
#  'ребёнок',
#  'сьюзен',
#  'собираться',
#  'вырастить',
#  'ребёнок',
#  'ну',
#  'знать',
#  'человек',
#  'профи',
#  'они',
#  'знать',
#  'делать',
#  'торопиться',
#  'выполнять',
#  'работа',
#  'надо',
#  'пописать',
#  'как',
#  'долго',
#  'пробыть',
#  'дя',
#  'эээ',
#  'дя',
#  'нужный',
#  'помощь',
#  'в',
#  'любой',
#  'случай',
#  'гм',
#  'итак',
#  'э-э',
#  'нервничать',
#  'из-за',
#  'завтрашний',
#  'барри',
#  'ммм',
#  'мм',
#  'что',
#  'стоить',
#  'употреблять',
#  'слово',
#  'сбросить',
#  'скорее',
#  'это',
#  'сломать',
#  'оболочка',
#  'человек',
#  'понимать',
#  'должный',
#  'постараться',
#  'выглядеть',
#  'слишком',
#  'потрясающе',
#  'знать',
#  'это',
#  'сложно',
#  'или',
#  'знать',
#  'эй',
#  'пойти',
#  'туда',
#  'вернуть',
#  'барри',
#  'кольцо',
#  'мочь',
#  'пойти',
#  'кэрол',
#  'сьюзан',
#  'акушерство',
#  'гинеколог',
#  'понять',
#  'ага',
#  'да-да',
#  'я',
#  'извинить',
#  'опоздать',
#  'застрять',
#  'работа',
#  'там',
#  'большой',
#  'динозавр',
#  'всякий',
#  'случай',
#  'как',
#  'мочь',
#  'забыть',
#  'здравствуйте',
#  'сьюзен',
#  'хороший',
#  'коктейль',
#  'хороший',
#  'коктейль',
#  'итак',
#  'просто',
#  'ждать',
#  'dr',
#  'оберман',
#  'хорошо',
#  'а',
#  'он-',
#  '-он',
#  'она-',
#  'знакомый',
#  'наш',
#  'особый',
#  'ситуация',
#  'отлично',
#  'нет',
#  'ой',
#  'кря',
#  'кря',
#  'ну',
#  'это',
#  'это',
#  'работать',
#  'понимать',
#  'мы',
#  'знать',
#  'нужно',
#  'принимать',
#  'важный',
#  'решение',
#  'ну',
#  'знать',
#  'ладный',
#  'ладный',
#  'насчёт',
#  'э',
#  'имя',
#  'ребёнок',
#  'марлон',
#  'как',
#  'мышь',
#  'тем',
#  'менее',
#  'говорить',
#  'минни',
#  'слышать',
#  'маус',
#  'как',
#  'насчёт',
#  'насчёт',
#  'джулия',
#  'смешно',
#  'ммм',
#  'договориться',
#  'провести',
#  'остаток',
#  'жизнь',
#  'вместе',
#  'всё',
#  'меняться',
#  'бросаться',
#  'удар',
#  'я',
#  'считать',
#  'джулия',
#  'стол',
#  'хелен',
#  'геллер',
#  'я',
#  'думать',
#  'спасибо',
#  'что',
#  'это',
#  'хелен',
#  'уиллик',
#  'погодить-ка',
#  'почему',
#  'название',
#  'ну',
#  'смешно',
#  'я',
#  'помнить',
#  'производить',
#  'сперма',
#  'нет-нет-нуть',
#  'получить',
#  'признание',
#  'эй',
#  'конечно',
#  'предлагать',
#  'геллер-виллик-банча',
#  'мой',
#  'путь',
#  'вы',
#  'думать',
#  'это',
#  'путь',
#  'поверьте',
#  'способ',
#  'который',
#  'когда-либо',
#  'представлять',
#  'момент',
#  'свой',
#  'жизнь',
#  'это',
#  'путь',
#  '-',
#  'знать',
#  'эээ',
#  'это',
#  'слишком',
#  'сложно',
#  'нет',
#  'могу-',
#  'ты',
#  'знать',
#  'пойти',
#  'я',
#  'я',
#  'думать',
#  'мочь',
#  'вовлечь',
#  'конкретный',
#  'вещь',
#  'прямо',
#  'бог',
#  'ну',
#  'разве',
#  'это',
#  'потрясающе',
#  'тогда',
#  'делать',
#  'ладный',
#  'моника',
#  'что',
#  'думать',
#  'кто-что',
#  'да',
#  'поправляться',
#  'ты',
#  'быть',
#  'тётя',
#  'привет',
#  'о',
#  'пройти',
#  'забавно',
#  'наш',
#  'родитель',
#  'действительно',
#  'отправить',
#  'наш',
#  'собака',
#  'жить',
#  'ферма',
#  'что',
#  'привет',
#  'ферма',
#  'миллнер',
#  'коннектикут',
#  'миллнера',
#  'этот',
#  'невероятный',
#  'ферма',
#  'лошадь',
#  'кролик',
#  'который',
#  'мочь',
#  'преследовать',
#  'это',
#  'это',
#  'бог',
#  'чи',
#  'чи',
#  'мочь',
#  'использовать',
#  'любой',
#  'большой',
#  'палец',
#  'легко',
#  'что',
#  'это',
#  'подождать',
#  'секунда',
#  'ладный',
#  'просто',
#  'подумать',
#  'пройти',
#  'бросить',
#  'курить',
#  'последний',
#  'ага',
#  'знать',
#  'чи',
#  'чи',
#  'привет',
#  'фибс',
#  'пойти',
#  'начать',
#  'продолжать',
#  'ковырять…',
#  'извинить',
#  'мочь',
#  'сделать',
#  'мочь',
#  'сделать',
#  'мы',
#  'любить',
#  'какой',
#  'башмак',
#  'так',
#  'думать',
#  'алан',
#  'стать',
#  'мерило',
#  'который',
#  'быть',
#  'выступать',
#  'будущий',
#  'бойфренд',
#  'измеряться',
#  'но',
#  'знать',
#  'немой',
#  'нравиться',
#  'то',
#  'заставлять',
#  'думать',
#  'ну',
#  'он',
#  'невероятный',
#  'он',
#  'похожий',
#  'этот-тот-тота',
#  'мультфильм',
#  'багз',
#  'банни',
#  'багз',
#  'разыгрывать',
#  'позиция',
#  'верно',
#  'вместо',
#  'багс',
#  'это',
#  'первый',
#  'база',
#  '-',
#  'алан',
#  'второй',
#  'база',
#  '-',
#  'алан',
#  'третий',
#  'база',
#  'что',
#  'ага',
#  'обожать',
#  'эм',
#  'врождённый',
#  'аланскостя',
#  'большой',
#  'палец',
#  'а',
#  'слушать',
#  'фибс',
#  'казаться',
#  'это',
#  'мило',
#  'знать',
#  'правильно',
#  'говорить',
#  'плохой',
#  'разве',
#  'понимать',
#  'делать',
#  'себя',
#  'если',
#  'женщина',
#  'хорошо',
#  'думать',
#  'пора',
#  'сменить',
#  'никотиновый',
#  'пластырь',
#  'кто-нибудь',
#  'ну',
#  'привет',
#  'фибс',
#  'хотеть',
#  'поп-тарт',
#  'фибс',
#  'а',
#  'есть',
#  'кто-нибудь',
#  'кто-кто',
#  'хотеть',
#  'справедливость',
#  'понимать',
#  'просто',
#  'хотеть',
#  'вернуть',
#  'вещь',
#  'понимать',
#  'какой',
#  'привет',
#  'мы',
#  'просто',
#  'нужно',
#  'немного',
#  'время',
#  'ага',
#  'он',
#  'мочь',
#  'грести',
#  'викинг',
#  'как',
#  'пройти',
#  'у',
#  'тяжёлый',
#  'день',
#  'кончить',
#  'ага',
#  'видеть',
#  'взять',
#  'чендлера',
#  'джоуя',
#  'эм-',
#  'всемогущий',
#  'я',
#  'мочь',
#  'спать',
#  'общественный',
#  'место',
#  'ничего',
#  'страшный',
#  'понимать',
#  'заснуть',
#  'почему',
#  'забавно',
#  'день',
#  'рождение',
#  'семь',
#  'месяц',
#  'назад',
#  'полагать',
#  'лишний',
#  'билет',
#  'мочь',
#  'решить',
#  'должный',
#  'пригласить',
#  'свидание',
#  'бог',
#  'ой-',
#  'сегодня',
#  'двадцатый',
#  'двадцатый',
#  'октябрь',
#  'оххха',
#  'сегодня',
#  'день',
#  'кэрол',
#  'впервые',
#  'завершить',
#  'наш',
#  'физический',
#  'отношение',
#  'секс',
#  'знать',
#  'пройда',
#  'игра',
#  'думать',
#  'просто',
#  'пойти',
#  'домой',
#  'подумать',
#  'свой',
#  'бывший',
#  'жена',
#  'любовник-лесбиянка',
#  'чем',
#  'заниматься',
#  'хорошо',
#  'ладный',
#  'отвлечиться',
#  'вы',
#  'обещать',
#  'купить',
#  'большой',
#  'палец',
#  'вы',
#  'мочь',
#  'жить',
#  'полностью',
#  'полностью',
#  'да',
#  'кстати',
#  'отличный',
#  'обслуживание',
#  'сегодня',
#  'вечером',
#  'кэрол',
#  'ботинок',
#  'точно',
#  'такой',
#  'тот',
#  'ночь',
#  'который',
#  'мы…',
#  'впервые…',
#  'знать',
#  'на',
#  'сам',
#  'дело',
#  'снимать',
#  'мы-мы',
#  'извинить',
#  'простить',
#  'косточка',
#  'персик',
#  'косточка',
#  'персик',
#  'в',
#  'тот',
#  'ночь',
#  'было-',
#  'вообще-то',
#  'нектарин',
#  'основное',
#  'потом',
#  'одеться',
#  'я',
#  'проводить',
#  'до-',
#  'автобусный',
#  'остановка',
#  'я',
#  'порядок',
#  'извинить',
#  'извинить',
#  'ой-ой',
#  'нет',
#  'просто',
#  'сказать',
#  'похоже',
#  'сидеть',
#  'вместе',
#  'но',
#  'упомянуть',
#  'тот',
#  'ночь',
#  'лёд',
#  'это',
#  'первый',
#  'мороз',
#  'брать',
#  'получить',
#  'он',
#  'взять',
#  'get-',
#  'да',
#  'не',
#  'смеяться',
#  'дружище',
#  'передать',
#  'пропустить',
#  'это',
#  'слушать',
#  'хотеть',
#  'создавать',
#  'проблема',
#  'ладный',
#  'очень',
#  'больно',
#  'ладный',
#  'мой',
#  'лицо',
#  'помятый',
#  'привет',
#  'это',
#  'привет',
#  'я',
#  'помнить',
#  'лунный',
#  'свет',
#  'проникать',
#  'окно',
#  'лицо',
#  'сиять',
#  'невероятно',
#  'невероятно',
#  'послушать',
#  'это',
#  'немного',
#  'сложный',
#  'чуть',
#  'громкий',
#  'ладный',
#  'думать',
#  'двенадцатый',
#  'этаж',
#  'кома',
#  'человек',
#  'который',
#  'расслышать',
#  'мой',
#  'первый',
#  'кэрол',
#  ...]

# %%
from nltk.probability import FreqDist
fdist = FreqDist(preprocessed_word_tokens)
print(fdist)
# Out:
# <FreqDist with 6333 samples and 52217 outcomes>

# %%
fdist.most_common(2)
# Out:
# [('это', 1967), ('я', 1521)]

# %%
# Frequency Distribution Plot
import matplotlib.pyplot as plt
fdist.plot(30,cumulative=False)
plt.show()
