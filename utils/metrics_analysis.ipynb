# %%
import re
import json
import requests
import numpy as np
import pandas as pd
import seaborn as sns
from tqdm import tqdm
from bs4 import BeautifulSoup

# %%
main_characters = ['ДЖОУИ', 'МОНИКА', 'РЕЙЧЕЛ', 'РОСС', 'ФИБИ', 'ЧЕНДЛЕР']
texts = {i : "" for i in main_characters}

for name in main_characters:
    url = f'https://raw.githubusercontent.com/Alenush/style_transfer_sirius2021summer/main/data/scripts/russian/{name}.txt'
    req = requests.get(url)
    if req.status_code == requests.codes.ok:
        req = BeautifulSoup(req.text, 'html.parser')
        texts[name] = str(req)
    else:
        print('Content was not found.')

# %%
# разные метрики 
# https://github.com/ivbeg/readability.io/wiki/API

metrics = []
for name in main_characters:
    text = texts[name]
    response = requests.post("http://api.plainrussian.ru/api/1.0/ru/measure/", data={"text":text})
    metrics.append((name, response.json()))
metrics = sorted(metrics, key=lambda x: x[1]['indexes']['index_SMOG'])
# Out:
# 100%|██████████| 6/6 [00:12<00:00,  2.13s/it]
# Wall time: 12.8 s

# %%
metrics_dct = dict(metrics)
complex_words = np.array([(name, int(metrics_dct[name]['metrics']['n_complex_words'])) for name in main_characters])
df_complex_words = pd.DataFrame(complex_words)
df_complex_words.columns = ['name', 'complex_words']
df_complex_words.complex_words = df_complex_words.complex_words.astype(int)

ax = sns.barplot(x="name", y="complex_words", data=df_complex_words)
ax.set(xlabel='Person', ylabel='Number of words', title='Number of complex words')
plt.show()

# %%
metrics
# Out:
# [('РЕЙЧЕЛ',
#   {'metrics': {'wsyllabes': {'60': 1,
#      '26': 1,
#      '12': 1,
#      '16': 1,
#      '30': 1,
#      '31': 1,
#      '45': 1,
#      '1': 28500,
#      '171': 2,
#      '3': 13765,
#      '2': 25509,
#      '5': 1193,
#      '4': 4722,
#      '7': 53,
#      '6': 259,
#      '9': 5,
#      '8': 8,
#      '79': 1,
#      '72': 1},
#     'c_share': 2.065518405943938,
#     'chars': 462647,
#     'avg_slen': 9.366696191319752,
#     'spaces': 82672,
#     'n_syllabes': 148413,
#     'n_words': 74025,
#     'letters': 337472,
#     'n_sentences': 7903,
#     'n_complex_words': 1529,
#     'n_simple_words': 72496,
#     'avg_syl': 2.004903748733536},
#    'status': 0,
#    'lang': 'ru',
#    'debug': '0',
#    'indexes': {'grade_SMOG': '4 - 6-й класс (возраст примерно: 9-11 лет)',
#     'grade_ari': 'неизвестно (0)',
#     'index_fk': 0.9482426208558934,
#     'grade_cl': '1 - 3-й класс (возраст примерно: 6-8 лет)',
#     'grade_fk': '1 - 3-й класс (возраст примерно: 6-8 лет)',
#     'index_cl': 1.007264437689976,
#     'grade_dc': '4 - 6-й класс (возраст примерно: 9-11 лет)',
#     'index_dc': 3.6972742203113462,
#     'index_ari': 0.1260238676158849,
#     'index_SMOG': 3.938809740723307}}),
#  ('МОНИКА',
#   {'metrics': {'wsyllabes': {'11': 1,
#      '10': 1,
#      '12': 1,
#      '49': 1,
#      '46': 1,
#      '18': 1,
#      '28': 1,
#      '50': 1,
#      '1': 22899,
#      '3': 11695,
#      '2': 21685,
#      '5': 1117,
#      '4': 4125,
#      '7': 32,
#      '6': 263,
#      '9': 6,
#      '8': 7,
#      '283': 1},
#     'c_share': 2.3189624502732946,
#     'chars': 390579,
#     'avg_slen': 9.204822863947603,
#     'spaces': 68469,
#     'n_syllabes': 125858,
#     'n_words': 61838,
#     'letters': 287561,
#     'n_sentences': 6718,
#     'n_complex_words': 1434,
#     'n_simple_words': 60404,
#     'avg_syl': 2.0352857466282868},
#    'status': 0,
#    'lang': 'ru',
#    'debug': '0',
#    'indexes': {'grade_SMOG': '4 - 6-й класс (возраст примерно: 9-11 лет)',
#     'grade_ari': '1 - 3-й класс (возраст примерно: 6-8 лет)',
#     'index_fk': 1.3281912728570084,
#     'grade_cl': '1 - 3-й класс (возраст примерно: 6-8 лет)',
#     'grade_fk': '1 - 3-й класс (возраст примерно: 6-8 лет)',
#     'index_cl': 1.443917332384622,
#     'grade_dc': '4 - 6-й класс (возраст примерно: 9-11 лет)',
#     'index_dc': 3.7929839144085546,
#     'index_ari': 0.652400434541093,
#     'index_SMOG': 4.134731552344495}}),
#  ('ДЖОУИ',
#   {'metrics': {'wsyllabes': {'12': 2,
#      '16': 1,
#      '49': 1,
#      '215': 1,
#      '43': 1,
#      '34': 1,
#      '1': 25384,
#      '61': 1,
#      '3': 12660,
#      '2': 23568,
#      '5': 1257,
#      '4': 4319,
#      '7': 59,
#      '6': 331,
#      '9': 5,
#      '8': 12,
#      '85': 1},
#     'c_share': 2.4747056387196023,
#     'chars': 428644,
#     'avg_slen': 9.01987991994663,
#     'spaces': 75090,
#     'n_syllabes': 137128,
#     'n_words': 67604,
#     'letters': 313684,
#     'n_sentences': 7495,
#     'n_complex_words': 1673,
#     'n_simple_words': 65931,
#     'avg_syl': 2.02840068634992},
#    'status': 0,
#    'lang': 'ru',
#    'debug': '0',
#    'indexes': {'grade_SMOG': '4 - 6-й класс (возраст примерно: 9-11 лет)',
#     'grade_ari': '1 - 3-й класс (возраст примерно: 6-8 лет)',
#     'index_fk': 1.171611560711888,
#     'grade_cl': '1 - 3-й класс (возраст примерно: 6-8 лет)',
#     'grade_fk': '1 - 3-й класс (возраст примерно: 6-8 лет)',
#     'index_cl': 1.3097994201526575,
#     'grade_dc': '4 - 6-й класс (возраст примерно: 9-11 лет)',
#     'index_dc': 3.8284647307186503,
#     'index_ari': 0.5366096587674427,
#     'index_SMOG': 4.227063678468722}}),
#  ('ФИБИ',
#   {'metrics': {'wsyllabes': {'11': 1,
#      '10': 2,
#      '12': 1,
#      '17': 1,
#      '22': 1,
#      '16': 1,
#      '42': 1,
#      '1': 23059,
#      '3': 11364,
#      '2': 21102,
#      '5': 1126,
#      '4': 4077,
#      '7': 55,
#      '6': 262,
#      '9': 4,
#      '8': 16,
#      '161': 1},
#     'c_share': 2.4101909159380424,
#     'chars': 385821,
#     'avg_slen': 9.893730763000162,
#     'spaces': 68048,
#     'n_syllabes': 123715,
#     'n_words': 61074,
#     'letters': 282357,
#     'n_sentences': 6173,
#     'n_complex_words': 1472,
#     'n_simple_words': 59602,
#     'avg_syl': 2.0256573992206177},
#    'status': 0,
#    'lang': 'ru',
#    'debug': '0',
#    'indexes': {'grade_SMOG': '4 - 6-й класс (возраст примерно: 9-11 лет)',
#     'grade_ari': '1 - 3-й класс (возраст примерно: 6-8 лет)',
#     'index_fk': 1.4105414515668215,
#     'grade_cl': '1 - 3-й класс (возраст примерно: 6-8 лет)',
#     'grade_fk': '1 - 3-й класс (возраст примерно: 6-8 лет)',
#     'index_cl': 1.5599777319317596,
#     'grade_dc': '4 - 6-й класс (возраст примерно: 9-11 лет)',
#     'index_dc': 4.031413883896844,
#     'index_ari': 0.6763910074624562,
#     'index_SMOG': 4.3673246811419615}}),
#  ('РОСС',
#   {'metrics': {'wsyllabes': {'11': 2,
#      '10': 3,
#      '39': 1,
#      '12': 1,
#      '59': 1,
#      '23': 1,
#      '209': 1,
#      '29': 1,
#      '40': 1,
#      '1': 27516,
#      '3': 13750,
#      '2': 25488,
#      '5': 1439,
#      '4': 4949,
#      '7': 75,
#      '6': 354,
#      '9': 4,
#      '8': 16},
#     'c_share': 2.581416518348437,
#     'chars': 466465,
#     'avg_slen': 10.41945073612684,
#     'spaces': 82234,
#     'n_syllabes': 150009,
#     'n_words': 73603,
#     'letters': 341798,
#     'n_sentences': 7064,
#     'n_complex_words': 1900,
#     'n_simple_words': 71703,
#     'avg_syl': 2.0380826868470034},
#    'status': 0,
#    'lang': 'ru',
#    'debug': '0',
#    'indexes': {'grade_SMOG': '4 - 6-й класс (возраст примерно: 9-11 лет)',
#     'grade_ari': '1 - 3-й класс (возраст примерно: 6-8 лет)',
#     'index_fk': 1.754159487315782,
#     'grade_cl': '1 - 3-й класс (возраст примерно: 6-8 лет)',
#     'grade_fk': '1 - 3-й класс (возраст примерно: 6-8 лет)',
#     'index_cl': 1.8518268277108305,
#     'grade_dc': '4 - 6-й класс (возраст примерно: 9-11 лет)',
#     'index_dc': 4.269451969090965,
#     'index_ari': 0.9528769822559688,
#     'index_SMOG': 4.635222336284215}}),
#  ('ЧЕНДЛЕР',
#   {'metrics': {'wsyllabes': {'25': 1,
#      '26': 1,
#      '12': 4,
#      '15': 1,
#      '14': 1,
#      '18': 1,
#      '42': 2,
#      '13': 1,
#      '35': 1,
#      '41': 3,
#      '1': 24583,
#      '3': 12471,
#      '2': 22616,
#      '5': 1261,
#      '4': 4543,
#      '7': 65,
#      '6': 306,
#      '9': 3,
#      '8': 10,
#      '21': 1},
#     'c_share': 2.5229601518026565,
#     'chars': 416042,
#     'avg_slen': 10.75685826257348,
#     'spaces': 72520,
#     'n_syllabes': 134525,
#     'n_words': 65875,
#     'letters': 307836,
#     'n_sentences': 6124,
#     'n_complex_words': 1662,
#     'n_simple_words': 64213,
#     'avg_syl': 2.0421252371916507},
#    'status': 0,
#    'lang': 'ru',
#    'debug': '0',
#    'indexes': {'grade_SMOG': '4 - 6-й класс (возраст примерно: 9-11 лет)',
#     'grade_ari': '1 - 3-й класс (возраст примерно: 6-8 лет)',
#     'index_fk': 1.9188592956198107,
#     'grade_cl': '1 - 3-й класс (возраст примерно: 6-8 лет)',
#     'grade_fk': '1 - 3-й класс (возраст примерно: 6-8 лет)',
#     'index_cl': 2.117939278937385,
#     'grade_dc': '4 - 6-й класс (возраст примерно: 9-11 лет)',
#     'index_dc': 4.329296309477627,
#     'index_ari': 1.2304806781357343,
#     'index_SMOG': 4.655818956064361}})]
